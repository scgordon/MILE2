# %% [markdown]
# ##  This notebook allows the user to convert a csv to an HDF5 file

# %% [markdown]
# ### Read in data by selecting the organization and collection.

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipykernel import kernelapp as app
from __future__ import print_function
from ipywidgets import *
import ipywidgets as widgets

# %% [markdown]
# ### query the directory for subdirectory names, return them in a list.

# %%
Organizations = []
for (dirpath, dirnames, filenames) in walk('../collection/'):
    Organizations.extend(dirnames)
    break
Organizations
# Out:
# ['BCO-DMO',
#  'DataOne',
#  'IEDA',
#  'LTERthroughTime',
#  'NASA',
#  'NCAR',
#  'ORNL',
#  'USGS']

# %% [markdown]
# ### Create a function to populate a variable used to populate the list for the collection dropdown

# %%
def OrganizationChoices(Organization):
    global OrganizationChoice
    global Collections
    OrganizationChoice=os.path.join('../data',Organization)
    Collections=os.listdir(OrganizationChoice)

# %% [markdown]
# ### Choose the organization you want data from by creating a dropdown with the function that identifies the organizations that have data.

# %%
interactive(OrganizationChoices, Organization=Organizations)

# %% [markdown]
# ### Function that reads the selected csv into a HDF5 file and then into a dataframe

# %%
def CollectionChoices(Collection):
    global CollectionConceptsDF
    global CollectionPath
    global HDFconceptsDF
    global CollectionConnections
    CollectionConnections=Collection
    CollectionPath=os.path.join(os.getcwd()[:-8],'HDF',Collection[:-4]+'.h5')
    CollectionConceptsDF= pd.read_csv(os.path.join(OrganizationChoice, Collection))
    return CollectionConceptsDF

# %% [markdown]
# ### Choose the CSV you want to convert and examine as an HDF dataframe

# %%
interactive(CollectionChoices, Collection=Collections)
# Out:
#        Collection  Dialect                                 Record  \
# 0            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 1            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 2            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 3            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 4            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 5            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 6            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 7            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 8            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 9            DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 10           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 11           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 12           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 13           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 14           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 15           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 16           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 17           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 18           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 19           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 20           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 21           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 22           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 23           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 24           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 25           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 26           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 27           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 28           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# 29           DAAC  Mercury    daac.ornl.gov_mercury_harvest_1.xml
# ...           ...      ...                                    ...
# 265888       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265889       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265890       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265891       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265892       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265893       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265894       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265895       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265896       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265897       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265898       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265899       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265900       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265901       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265902       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265903       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265904       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265905       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265906       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265907       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265908       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265909       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265910       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265911       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265912       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265913       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265914       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265915       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265916       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
# 265917       DAAC  Mercury  daac.ornl.gov_mercury_harvest_999.xml
#
#                                   Concept  \
# 0                                Abstract
# 1                                  Author
# 2                     Author / Originator
# 3                     Author / Originator
# 4       Author / Originator Email Address
# 5                            Bounding Box
# 6                    Distribution Contact
# 7                    Distribution Contact
# 8                    Distribution Contact
# 9                   Easternmost Longitude
# 10                  Easternmost Longitude
# 11                                  Email
# 12                                  Email
# 13                                  Email
# 14                               End Time
# 15                               End Time
# 16                                    Fax
# 17                                    Fax
# 18                                Keyword
# 19                                Keyword
# 20                                Keyword
# 21                                Keyword
# 22                                Keyword
# 23                                Keyword
# 24                                Keyword
# 25                                Keyword
# 26                                Keyword
# 27                                Keyword
# 28                                Keyword
# 29                                Keyword
# ...                                   ...
# 265888                    Temporal Extent
# 265889                Temporal Resolution
# 265890                      Theme Keyword
# 265891                      Theme Keyword
# 265892                      Theme Keyword
# 265893                      Theme Keyword
# 265894                      Theme Keyword
# 265895                      Theme Keyword
# 265896                      Theme Keyword
# 265897                      Theme Keyword
# 265898                      Theme Keyword
# 265899                      Theme Keyword
# 265900                      Theme Keyword
# 265901                      Theme Keyword
# 265902                      Theme Keyword
# 265903                      Theme Keyword
# 265904                      Theme Keyword
# 265905                      Theme Keyword
# 265906                      Theme Keyword
# 265907                      Theme Keyword
# 265908                      Theme Keyword
# 265909                      Theme Keyword
# 265910                                URL
# 265911                                URL
# 265912                                URL
# 265913                                URL
# 265914                                URL
# 265915                                URL
# 265916              Westernmost Longitude
# 265917              Westernmost Longitude
#
#                                                            XPath  \
# 0                             /metadata/idinfo/descript/abstract
# 1                      /metadata/idinfo/citation/citeinfo/origin
# 2                      /metadata/idinfo/citation/citeinfo/origin
# 3                  /metadata/mercury/Principal_Investigator/Name
# 4                 /metadata/mercury/Principal_Investigator/Email
# 5                                /metadata/idinfo/spdom/bounding
# 6                             /metadata/distinfo/distrib/cntinfo
# 7                               /metadata/mercury/Contact_Person
# 8              /metadata/distinfo/distrib/cntinfo/cntperp/cntper
# 9                         /metadata/idinfo/spdom/bounding/eastbc
# 10      /metadata/mercury/Site_Information/Easternmost_Longitude
# 11                   /metadata/distinfo/distrib/cntinfo/cntemail
# 12                      /metadata/metainfo/metc/cntinfo/cntemail
# 13                        /metadata/mercury/Contact_Person/Email
# 14           /metadata/idinfo/timeperd/timeinfo/rngdates/enddate
# 15                                     /metadata/mercury/enddate
# 16                      /metadata/idinfo/ptcontac/cntinfo/cntfax
# 17                     /metadata/distinfo/distrib/cntinfo/cntfax
# 18                      /metadata/idinfo/keywords/theme/themekey
# 19                      /metadata/idinfo/keywords/theme/themekey
# 20                      /metadata/idinfo/keywords/theme/themekey
# 21                      /metadata/idinfo/keywords/theme/themekey
# 22                      /metadata/idinfo/keywords/theme/themekey
# 23                      /metadata/idinfo/keywords/theme/themekey
# 24                      /metadata/idinfo/keywords/theme/themekey
# 25                      /metadata/idinfo/keywords/theme/themekey
# 26                /metadata/mercury/Parameter_Description/Sensor
# 27                /metadata/mercury/Parameter_Description/Sensor
# 28                /metadata/mercury/Parameter_Description/Source
# 29                /metadata/mercury/Parameter_Description/Source
# ...                                                          ...
# 265888                                                       NaN
# 265889                     /metadata/mercury/Temporal_Resolution
# 265890                  /metadata/idinfo/keywords/theme/themekey
# 265891                  /metadata/idinfo/keywords/theme/themekey
# 265892                  /metadata/idinfo/keywords/theme/themekey
# 265893                  /metadata/idinfo/keywords/theme/themekey
# 265894                  /metadata/idinfo/keywords/theme/themekey
# 265895                  /metadata/idinfo/keywords/theme/themekey
# 265896                  /metadata/idinfo/keywords/theme/themekey
# 265897                  /metadata/idinfo/keywords/theme/themekey
# 265898                  /metadata/idinfo/keywords/theme/themekey
# 265899                  /metadata/idinfo/keywords/theme/themekey
# 265900                  /metadata/idinfo/keywords/theme/themekey
# 265901                  /metadata/idinfo/keywords/theme/themekey
# 265902                  /metadata/idinfo/keywords/theme/themekey
# 265903                  /metadata/idinfo/keywords/theme/themekey
# 265904                  /metadata/idinfo/keywords/theme/themekey
# 265905                  /metadata/idinfo/keywords/theme/themekey
# 265906                  /metadata/idinfo/keywords/theme/themekey
# 265907                  /metadata/idinfo/keywords/theme/themekey
# 265908                  /metadata/idinfo/keywords/theme/themekey
# 265909                  /metadata/idinfo/keywords/theme/themekey
# 265910                /metadata/mercury/Documentation_Link/Label
# 265911                  /metadata/mercury/Search_Text_Link/Label
# 265912                       /metadata/mercury/Data_Set_Link/URL
# 265913                 /metadata/idinfo/citation/citeinfo/onlink
# 265914                 /metadata/idinfo/citation/citeinfo/onlink
# 265915                 /metadata/idinfo/citation/citeinfo/onlink
# 265916                    /metadata/idinfo/spdom/bounding/westbc
# 265917  /metadata/mercury/Site_Information/Westernmost_Longitude
#
#                                                                                                                                                                                                         Content
# 0       The Fifteen Minute Stream Flow Data from the USGS Data Set contains 15 minute stream flow data from the USGS station located 2.9 miles upstream from the mouth of Kings Creek. The record extends fr...
# 1                                                                                                                                                                                                    WOOD, E.F.
# 2                                                                                                                                                                                                    WOOD, E.F.
# 3                                                                                                                                                                                                    WOOD, E.F.
# 4                                                                                                                                                                                                           NaN
# 5                                                                                                                                                                                         -96.6 -96.6 39.1 39.1
# 6       The Oak Ridge National Laboratory (ORNL) Distributed Active Archive Center (DAAC) ORNL DAAC User Services Office Oak Ridge National Laboratory Oak Ridge, Tennessee 37831 USA FAX: +1(865)574-4665 +...
# 7                                                            ornldaac@ornl.gov ORNL DAAC User Services Office Oak Ridge National Laboratory Oak Ridge, Tennessee 37831 USA FAX: +1(865)574-4665 +1(865)241-3952
# 8                                                                                              ORNL DAAC User Services Office Oak Ridge National Laboratory Oak Ridge, Tennessee 37831 USA FAX: +1(865)574-4665
# 9                                                                                                                                                                                                         -96.6
# 10                                                                                                                                                                                                        -96.6
# 11                                                                                                                                                                                            ornldaac@ornl.gov
# 12                                                                                                                                                                                            ornldaac@ornl.gov
# 13                                                                                                                                                                                            ornldaac@ornl.gov
# 14                                                                                                                                                                                                     19880304
# 15                                                                                                                                                                                                          NaN
# 16                                                                6.1.10.8 Contact Electronic Mail: INTERNET > xsl:value-of select='x_tags/Data_Originator/Investigator/Email' disable-output-escaping='yes' />
# 17                                                                                                                                                                 6.1.10.8 Contact Electronic Mail: INTERNET >
# 18                                                                                                                                                              DISCHARGE/FLOW|STILLING WELL|SURFACE WATER WEIR
# 19                                                                                                                                                                STAGE HEIGHT|STILLING WELL|SURFACE WATER WEIR
# 20                                                                                                                                                                                               DISCHARGE/FLOW
# 21                                                                                                                                                                                                 STAGE HEIGHT
# 22                                                                                                                                                                                           SURFACE WATER WEIR
# 23                                                                                                                                                                                           SURFACE WATER WEIR
# 24                                                                                                                                                                                                STILLING WELL
# 25                                                                                                                                                                                                STILLING WELL
# 26                                                                                                                                                                                                STILLING WELL
# 27                                                                                                                                                                                                STILLING WELL
# 28                                                                                                                                                                                           SURFACE WATER WEIR
# 29                                                                                                                                                                                           SURFACE WATER WEIR
# ...                                                                                                                                                                                                         ...
# 265888                                                                                                                                                                                                     true
# 265889                                                                                                                                                                                                      NaN
# 265890                                                                                                                                                               INUNDATION|TM (THEMATIC MAPPER)|SATELLITES
# 265891                                                                                                                                                               INUNDATION|TM (THEMATIC MAPPER)|SATELLITES
# 265892                                                                                                                                                                                 DEPTH|ECHO SOUNDERS|BOAT
# 265893                                                                                                                                                                                 DEPTH|ECHO SOUNDERS|BOAT
# 265894                                                                                                                                                                            BATHYMETRY|ECHO SOUNDERS|BOAT
# 265895                                                                                                                                                                                               INUNDATION
# 265896                                                                                                                                                                                               INUNDATION
# 265897                                                                                                                                                                                                    DEPTH
# 265898                                                                                                                                                                                                    DEPTH
# 265899                                                                                                                                                                                               BATHYMETRY
# 265900                                                                                                                                                                                               SATELLITES
# 265901                                                                                                                                                                                               SATELLITES
# 265902                                                                                                                                                                                                     BOAT
# 265903                                                                                                                                                                                                     BOAT
# 265904                                                                                                                                                                                                     BOAT
# 265905                                                                                                                                                                                     TM (THEMATIC MAPPER)
# 265906                                                                                                                                                                                     TM (THEMATIC MAPPER)
# 265907                                                                                                                                                                                            ECHO SOUNDERS
# 265908                                                                                                                                                                                            ECHO SOUNDERS
# 265909                                                                                                                                                                                            ECHO SOUNDERS
# 265910                                                                                                                     LBA-ECO LC-07 Bathymetric Survey of Floodplain Lake, Lago Curuai, Para, Brazil: 2004
# 265911                                                                                                                     LBA-ECO LC-07 Bathymetric Survey of Floodplain Lake, Lago Curuai, Para, Brazil: 2004
# 265912                                                                                                                                                       http://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=999
# 265913                                                                                                                                                       http://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=999
# 265914                                                                                                                                                             http://daac.ornl.gov/mercury_harvest/999.xml
# 265915                                                                                                                                             http://daac.ornl.gov//LBA/guides/LC07_Bathymetry_Curuai.html
# 265916                                                                                                                                                                                                 -55.9531
# 265917                                                                                                                                                                                                 -55.9531
#
# [265918 rows x 6 columns]

# %%
CollectionConceptsDF.to_hdf(CollectionPath, CollectionConnections[:-4], format='table', complevel=9,
            complib='zlib')
HDFconceptsRADdf=pd.read_hdf(CollectionPath, key=CollectionConnections[:-4])
HDFconceptsRADdf
