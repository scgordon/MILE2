# %% [markdown]
# ##  This notebook allows the user to convert a HDF5 file to copy paste into a RAD

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipywidgets import *
import ipywidgets as widgets

# %%
h5 = []
for (dirpath, dirnames, filenames) in walk('../HDF/'):
    h5.extend(filenames)
    break
h5
# Out:
# ['CDL_CSDGM_data.h5',
#  'CLOEBIRD_EML_data.h5',
#  'DAAC_Mercury_data.h5',
#  'EDACGSTORE_CSDGM_data.h5',
#  'GES_DISC_DIF_data.h5',
#  'GHRC_DIF_data.h5',
#  'GHRC_ISO_data.h5',
#  'IIS_MODS_data.h5',
#  'LARC_DIF_data.h5',
#  'LARC_ISO_data.h5',
#  'NSIDC_DIF_data.h5',
#  'OldScienceBase_CSDGM_data.h5',
#  'RDA_RDA-CISL_data.h5']

# %%
def fileChoices(Record):
    global OrganizationChoice
    global Collections
    global HDFconceptsDF
    dataPath=os.path.join('../HDF',Record)
    HDFconceptsDF=pd.read_hdf(dataPath, key=Record[:-3])
    return HDFconceptsDF

# %%
interactive(fileChoices,Record=h5)
# Out:
#       Collection Dialect              Record  \
# 0            CDL   CSDGM  02509-metadata.xml
# 1            CDL   CSDGM  02509-metadata.xml
# 2            CDL   CSDGM  02509-metadata.xml
# 3            CDL   CSDGM  02509-metadata.xml
# 4            CDL   CSDGM  02509-metadata.xml
# 5            CDL   CSDGM  02509-metadata.xml
# 6            CDL   CSDGM  02509-metadata.xml
# 7            CDL   CSDGM  02509-metadata.xml
# 8            CDL   CSDGM  02509-metadata.xml
# 9            CDL   CSDGM  02509-metadata.xml
# 10           CDL   CSDGM  02509-metadata.xml
# 11           CDL   CSDGM  02509-metadata.xml
# 12           CDL   CSDGM  02509-metadata.xml
# 13           CDL   CSDGM  02509-metadata.xml
# 14           CDL   CSDGM  02509-metadata.xml
# 15           CDL   CSDGM  02509-metadata.xml
# 16           CDL   CSDGM  02509-metadata.xml
# 17           CDL   CSDGM  02509-metadata.xml
# 18           CDL   CSDGM  02509-metadata.xml
# 19           CDL   CSDGM  02509-metadata.xml
# ...

# %%
a='NASA'
b='NSIDC'
c='ISO'

# %%
a
# Out:
# 'NASA'

# %%
b
# Out:
# 'NSIDC'

# %%
# %%bash

# %%
# %%bash
# cd ../script
# ./UseRosetta.sh $a $b $c
# Out:
# Error at char 22 in xsl:for-each/@select on line 22 column 70 of Rosetta.xsl:
#   FODC0002: The file or directory file:/Users/scgordon/MILE2/collection////xml does not exist
# The file or directory file:/Users/scgordon/MILE2/collection////xml does not exist

# %%
HDFconceptsDF.drop(['XPath','Content'], axis=1, inplace=True)
HDFconceptsDF
# Out:
#       Collection Dialect              Record                           Concept
# 0            CDL   CSDGM  02509-metadata.xml                          Abstract
# 1            CDL   CSDGM  02509-metadata.xml              Attribute Definition
# 2            CDL   CSDGM  02509-metadata.xml       Attribute Definition Source
# 3            CDL   CSDGM  02509-metadata.xml                   Attribute Label
# 4            CDL   CSDGM  02509-metadata.xml                    Attribute List
# 5            CDL   CSDGM  02509-metadata.xml                            Author
# 6            CDL   CSDGM  02509-metadata.xml               Author / Originator
# 7            CDL   CSDGM  02509-metadata.xml                      Bounding Box
# 8            CDL   CSDGM  02509-metadata.xml             Easternmost Longitude
# 9            CDL   CSDGM  02509-metadata.xml            Entity Type Definition
# 10           CDL   CSDGM  02509-metadata.xml     Entity Type Definition Source
# ...

# %%
Records=HDFconceptsDF.Record.unique()
RecordList=Records.tolist()
RecordList
# Out:
# ['02509-metadata.xml',
#  '02510-metadata.xml',
#  '02511-metadata.xml',
#  '02512-metadata.xml',
#  '02513-metadata.xml',
#  '02514-metadata.xml',
#  '02515-metadata.xml',
#  '02516-metadata.xml',
#  '02517-metadata.xml',
#  '02518-metadata.xml',
#  '02519-metadata.xml',
#  '02520-metadata.xml',
#  '02521-metadata.xml',
#  '02522-metadata.xml',
#  '02523-metadata.xml',
#  '02524-metadata.xml',
#  '02525-metadata.xml',
#  '02526-metadata.xml',
#  '02527-metadata.xml',
#  '02528-metadata.xml',
#  '02529-metadata.xml',
#  '02530-metadata.xml',
#  '02531-metadata.xml',
#  '02532-metadata.xml',
#  '02533-metadata.xml',
#  '02534-metadata.xml',
#  '02535-metadata.xml',
#  '02536-metadata.xml',
#  '02537-metadata.xml',
#  '02538-metadata.xml',
#  '02539-metadata.xml',
#  '02540-metadata.xml',
#  '02541-metadata.xml',
#  '02542-metadata.xml',
#  '02543-metadata.xml',
#  '02544-metadata.xml',
#  '02545-metadata.xml',
#  '02546-metadata.xml',
#  '02547-metadata.xml',
#  '02548-metadata.xml',
# ...

# %% [markdown]
# ### For each item in RecordList, check to see if a row that contains the item contains a list of concepts from a recommendation

# %%
for record in RecordList:
    test=HDFconceptsDF[HDFconceptsDF.isin({'Concept': ['Abstract','Keyword']})]
test
# Out:
#       Collection Dialect Record   Concept
# 0            NaN     NaN    NaN  Abstract
# 1            NaN     NaN    NaN       NaN
# 2            NaN     NaN    NaN       NaN
# 3            NaN     NaN    NaN       NaN
# 4            NaN     NaN    NaN       NaN
# 5            NaN     NaN    NaN       NaN
# 6            NaN     NaN    NaN       NaN
# 7            NaN     NaN    NaN       NaN
# 8            NaN     NaN    NaN       NaN
# 9            NaN     NaN    NaN       NaN
# 10           NaN     NaN    NaN       NaN
# 11           NaN     NaN    NaN       NaN
# 12           NaN     NaN    NaN       NaN
# 13           NaN     NaN    NaN       NaN
# 14           NaN     NaN    NaN   Keyword
# 15           NaN     NaN    NaN   Keyword
# 16           NaN     NaN    NaN   Keyword
# 17           NaN     NaN    NaN   Keyword
# 18           NaN     NaN    NaN   Keyword
# 19           NaN     NaN    NaN   Keyword
# 20           NaN     NaN    NaN       NaN
# ...

# %%
for record in RecordList:
    RAD=HDFconceptsDF[(HDFconceptsDF['Record'] == record)&(HDFconceptsDF['Concept'] == 'Abstract')]
RAD
# Out:
#       Collection Dialect              Record   Concept
# 17430        CDL   CSDGM  02758-metadata.xml  Abstract

# %% [markdown]
# How to turn dataframe into Analysis sheet for a recommendation and recreate visualizations in Notebook, how to integrate awk script into Notebook, how to pass dataframes to other Notebooks.

# %% [markdown]
# How to upload files to server, how to recieve file from server

# %% [markdown]
# Install Anaconda with python 3.6
# Upload Metadata
# download result table as h5 file
# create dataframe
# create dataframe for RAD, give dropdown for collection occurance viz
# create dataframe for QuickE give dropdown for different Concept counts
# Create dataframe for Verticals give dropdown for different concepts
