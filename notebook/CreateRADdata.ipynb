# %% [markdown]
# ##  This notebook allows the user to refine the data.csv created in Metadata2Data by the Evaluator service. The resulting csv can be copy pasted into a Recommedations Analysis Dashboard to analyze the collection for recommendation completeness.

# %% [markdown]
# Import needed python packages

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipywidgets import *
import ipywidgets as widgets

# %% [markdown]
# Create a list of data.csv that are in the MILE2 repository

# %%
DataFiles=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith(".csv")]:
        DataFiles.extend([os.path.join(dirpath, filename)])
DataFiles
# Out:
# ['../data/data.csv',
#  '../data/dataForRAD.csv',
#  '../data/BCO-DMO/GeoTraces_ISO_data.csv',
#  '../data/DataONE/CDL_CSDGM_data.csv',
#  '../data/DataONE/CLOEBIRD_EML_data.csv',
#  '../data/DataONE/Dryad_Dryad_data.csv',
#  '../data/DataONE/EDACGSTORE_CSDGM_data.csv',
#  '../data/DataONE/EDORA_Mercury_data.csv',
#  '../data/DataONE/ESA_EML_data.csv',
#  '../data/DataONE/GLEON_EML_data.csv',
#  '../data/DataONE/GOA_EML_data.csv',
#  '../data/DataONE/IARC_Onedcx_data.csv',
#  '../data/DataONE/IOE_EML_data.csv',
#  '../data/DataONE/KNB_EML_data.csv',
#  '../data/DataONE/KUBI_EML_data.csv',
#  '../data/DataONE/LTER_EML_data.csv',
#  '../data/DataONE/LTER_EUROPE_EML_data.csv',
#  '../data/DataONE/NMEPSCOR_CSDGM_data.csv',
#  '../data/DataONE/ONEShare_EML_data.csv',
#  '../data/DataONE/ORNLDAAC_Mercury_data.csv',
#  '../data/DataONE/PISCO_EML_data.csv',
#  '../data/DataONE/RGD_Mercury_data.csv',
#  '../data/DataONE/SANPARKS_EML_data.csv',
#  '../data/DataONE/SEAD_CSDGM_data.csv',
#  '../data/DataONE/TERN_EML_data.csv',
#  '../data/DataONE/TFRI_EML_data.csv',
#  '../data/DataONE/US_MPC_Onedcx_data.csv',
#  '../data/DataONE/USANPN_EML_data.csv',
#  '../data/DataONE/USGSCSAS_BDP_data.csv',
#  '../data/DataONE/USGSCSAS_CSDGM_data.csv',
#  '../data/IEDA/ECL_DCITE_data.csv',
#  '../data/IEDA/MarineGeoscienceDataSystem_ISO_data.csv',
#  '../data/LTERthroughTime/LTER_2005_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2006_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2007_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2008_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2009_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2010_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2011_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2012_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2013_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2014_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2015_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2016_EML_data.csv',
#  '../data/NASA/GES_DISC_DIF_data.csv',
#  '../data/NASA/GHRC_CSDGM_data.csv',
#  '../data/NASA/GHRC_DIF_data.csv',
#  '../data/NASA/GHRC_ISO_data.csv',
#  '../data/NASA/LARC_DIF_data.csv',
#  '../data/NASA/LARC_ISO_data.csv',
#  '../data/NASA/NSIDC_DIF_data.csv',
#  '../data/NASA/NSIDC_ISO_data.csv',
#  '../data/NASA/test_data.csv',
#  '../data/NCAR/IIS_MODS_data.csv',
#  '../data/NCAR/RDA_RDA-CISL_data.csv',
#  '../data/ORNL/DAAC_Mercury_data.csv',
#  '../data/ORNL/NGEE_CSDGM_data.csv',
#  '../data/ORNL/OLI_ISO_data.csv',
#  '../data/ORNL/USGSC_CSDGM_data.csv',
#  '../data/USGS/OldScienceBase_CSDGM_data.csv',
#  '../data/USGS/ScienceBase_CSDGM_data.csv']

# %% [markdown]
# Create a function that allows us to import the csv contents into a dataframe.

# %%
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(DataFile))
    return CollectionConceptsDF

# %% [markdown]
# Create dropdown to select csv

# %%
interactive(DataChoices,DataFile=DataFiles)

# %% [markdown]
# Drop the columns we don't need

# %%
CollectionConceptsDF.drop(['XPath','Content','DialectDefinition'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#     Collection Dialect              Record                           Concept
# 0     NMEPSCOR   CSDGM  02759-metadata.xml                 Resource Citation
# 1     NMEPSCOR   CSDGM  02759-metadata.xml                          Abstract
# 2     NMEPSCOR   CSDGM  02759-metadata.xml                           Purpose
# 3     NMEPSCOR   CSDGM  02759-metadata.xml                           Unknown
# 4     NMEPSCOR   CSDGM  02759-metadata.xml                   Temporal Extent
# 5     NMEPSCOR   CSDGM  02759-metadata.xml                           Unknown
# 6     NMEPSCOR   CSDGM  02759-metadata.xml                   Resource Status
# 7     NMEPSCOR   CSDGM  02759-metadata.xml                      Bounding Box
# 8     NMEPSCOR   CSDGM  02759-metadata.xml                    Spatial Extent
# 9     NMEPSCOR   CSDGM  02759-metadata.xml                Keyword Vocabulary
# 10    NMEPSCOR   CSDGM  02759-metadata.xml                      Keyword Type
# 11    NMEPSCOR   CSDGM  02759-metadata.xml                     Theme Keyword
# 12    NMEPSCOR   CSDGM  02759-metadata.xml                           Keyword
# 13    NMEPSCOR   CSDGM  02759-metadata.xml                     Theme Keyword
# 14    NMEPSCOR   CSDGM  02759-metadata.xml                           Keyword
# 15    NMEPSCOR   CSDGM  02759-metadata.xml                     Theme Keyword
# 16    NMEPSCOR   CSDGM  02759-metadata.xml                           Keyword
# 17    NMEPSCOR   CSDGM  02759-metadata.xml                Keyword Vocabulary
# 18    NMEPSCOR   CSDGM  02759-metadata.xml                      Keyword Type
# 19    NMEPSCOR   CSDGM  02759-metadata.xml                     Theme Keyword
# 20    NMEPSCOR   CSDGM  02759-metadata.xml                           Keyword
# 21    NMEPSCOR   CSDGM  02759-metadata.xml                Keyword Vocabulary
# 22    NMEPSCOR   CSDGM  02759-metadata.xml                      Keyword Type
# 23    NMEPSCOR   CSDGM  02759-metadata.xml                     Theme Keyword
# 24    NMEPSCOR   CSDGM  02759-metadata.xml                           Keyword
# 25    NMEPSCOR   CSDGM  02759-metadata.xml                     Theme Keyword
# 26    NMEPSCOR   CSDGM  02759-metadata.xml                           Keyword
# 27    NMEPSCOR   CSDGM  02759-metadata.xml                     Theme Keyword
# 28    NMEPSCOR   CSDGM  02759-metadata.xml                           Keyword
# 29    NMEPSCOR   CSDGM  02759-metadata.xml          Place Keyword Vocabulary
# ..         ...     ...                 ...                               ...
# 365   NMEPSCOR   CSDGM  02765-metadata.xml                Keyword Vocabulary
# 366   NMEPSCOR   CSDGM  02765-metadata.xml                      Keyword Type
# 367   NMEPSCOR   CSDGM  02765-metadata.xml                     Theme Keyword
# 368   NMEPSCOR   CSDGM  02765-metadata.xml                           Keyword
# 369   NMEPSCOR   CSDGM  02765-metadata.xml                     Theme Keyword
# 370   NMEPSCOR   CSDGM  02765-metadata.xml                           Keyword
# 371   NMEPSCOR   CSDGM  02765-metadata.xml                     Theme Keyword
# 372   NMEPSCOR   CSDGM  02765-metadata.xml                           Keyword
# 373   NMEPSCOR   CSDGM  02765-metadata.xml          Place Keyword Vocabulary
# 374   NMEPSCOR   CSDGM  02765-metadata.xml                     Place Keyword
# 375   NMEPSCOR   CSDGM  02765-metadata.xml                           Keyword
# 376   NMEPSCOR   CSDGM  02765-metadata.xml                            Rights
# 377   NMEPSCOR   CSDGM  02765-metadata.xml       Resource Access Constraints
# 378   NMEPSCOR   CSDGM  02765-metadata.xml                            Rights
# 379   NMEPSCOR   CSDGM  02765-metadata.xml          Resource Use Constraints
# 380   NMEPSCOR   CSDGM  02765-metadata.xml                  Resource Contact
# 381   NMEPSCOR   CSDGM  02765-metadata.xml                  Contributor Name
# 382   NMEPSCOR   CSDGM  02765-metadata.xml                   Acknowledgement
# 383   NMEPSCOR   CSDGM  02765-metadata.xml                           Unknown
# 384   NMEPSCOR   CSDGM  02765-metadata.xml                 Quality Statement
# 385   NMEPSCOR   CSDGM  02765-metadata.xml      Resource Quality Description
# 386   NMEPSCOR   CSDGM  02765-metadata.xml                           Unknown
# 387   NMEPSCOR   CSDGM  02765-metadata.xml  Entity and Attribute Information
# 388   NMEPSCOR   CSDGM  02765-metadata.xml             Resource Distribution
# 389   NMEPSCOR   CSDGM  02765-metadata.xml            Metadata Modified Date
# 390   NMEPSCOR   CSDGM  02765-metadata.xml                  Metadata Contact
# 391   NMEPSCOR   CSDGM  02765-metadata.xml                 Metadata Language
# 392   NMEPSCOR   CSDGM  02765-metadata.xml        Metadata Standard Citation
# 393   NMEPSCOR   CSDGM  02765-metadata.xml         Metadata Standard Version
# 394   NMEPSCOR   CSDGM  02765-metadata.xml          Metadata Time Convention
#
# [395 rows x 4 columns]

# %% [markdown]
# Remove duplicate rows to increase processing speed in Excel.

# %%
ConceptsDF=CollectionConceptsDF.drop_duplicates()

# %% [markdown]
# Create a new csv with just the information we want in it

# %%
ConceptsDF.to_csv('../data/dataForRAD.csv', mode = 'w', index=False)

# %% [markdown]
# Links to open dataForRAD.csv and the RAD ready for data entry. Copy the cells in the data table we created and paste onto the data worksheet. Then switch to the dashboard worksheet and

# %% [markdown]
# [My data table](../data/dataForRAD.csv)
#
# [Recommendations Analysis Dashboard](../RAD/RAD.xlsx)
