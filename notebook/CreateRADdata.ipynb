# %% [markdown]
# ##  This notebook allows the user to refine the data.csv created in Metadata2Data by the Evaluator service. The resulting csv can be copy pasted into a Recommedations Analysis Dashboard to analyze the collection for recommendation completeness.

# %% [markdown]
# Import needed python packages

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipywidgets import *
import ipywidgets as widgets

# %% [markdown]
# Create a list of data.csv that are in the MILE2 repository

# %%
DataFiles=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith(".csv")]:
        DataFiles.extend([os.path.join(dirpath, filename)])
DataFiles
# Out:
# ['../data/data.csv',
#  '../data/dataForRAD.csv',
#  '../data/BCO-DMO/GeoTraces_ISO_data.csv',
#  '../data/DataONE/CDL_CSDGM_data.csv',
#  '../data/DataONE/CLOEBIRD_EML_data.csv',
#  '../data/DataONE/Dryad_Dryad_data.csv',
#  '../data/DataONE/EDACGSTORE_CSDGM_data.csv',
#  '../data/DataONE/EDORA_Mercury_data.csv',
#  '../data/DataONE/ESA_EML_data.csv',
#  '../data/DataONE/GLEON_EML_data.csv',
#  '../data/DataONE/GOA_EML_data.csv',
#  '../data/DataONE/IARC_Onedcx_data.csv',
#  '../data/DataONE/IOE_EML_data.csv',
#  '../data/DataONE/KNB_EML_data.csv',
#  '../data/DataONE/KUBI_EML_data.csv',
#  '../data/DataONE/LTER_EML_data.csv',
#  '../data/DataONE/LTER_EUROPE_EML_data.csv',
#  '../data/DataONE/NMEPSCOR_CSDGM_data.csv',
#  '../data/DataONE/ONEShare_EML_data.csv',
#  '../data/DataONE/ORNLDAAC_Mercury_data.csv',
#  '../data/DataONE/PISCO_EML_data.csv',
#  '../data/DataONE/RGD_Mercury_data.csv',
#  '../data/DataONE/SANPARKS_EML_data.csv',
#  '../data/DataONE/SEAD_CSDGM_data.csv',
#  '../data/DataONE/TERN_EML_data.csv',
#  '../data/DataONE/TFRI_EML_data.csv',
#  '../data/DataONE/US_MPC_Onedcx_data.csv',
#  '../data/DataONE/USANPN_EML_data.csv',
#  '../data/DataONE/USGSCSAS_BDP_data.csv',
#  '../data/DataONE/USGSCSAS_CSDGM_data.csv',
#  '../data/IEDA/ECL_DCITE_data.csv',
#  '../data/IEDA/MarineGeoscienceDataSystem_ISO_data.csv',
#  '../data/LTERthroughTime/LTER_2005_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2006_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2007_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2008_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2009_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2010_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2011_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2012_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2013_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2014_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2015_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2016_EML_data.csv',
#  '../data/NASA/GES_DISC_DIF_data.csv',
#  '../data/NASA/GHRC_CSDGM_data.csv',
#  '../data/NASA/GHRC_DIF_data.csv',
#  '../data/NASA/GHRC_ISO_data.csv',
#  '../data/NASA/LARC_DIF_data.csv',
#  '../data/NASA/LARC_ISO_data.csv',
#  '../data/NASA/NSIDC_DIF_data.csv',
#  '../data/NASA/NSIDC_ISO_data.csv',
#  '../data/NASA/test_data.csv',
#  '../data/NCAR/IIS_MODS_data.csv',
#  '../data/NCAR/RDA_RDA-CISL_data.csv',
#  '../data/ORNL/DAAC_Mercury_data.csv',
#  '../data/ORNL/NGEE_CSDGM_data.csv',
#  '../data/ORNL/OLI_ISO_data.csv',
#  '../data/ORNL/USGSC_CSDGM_data.csv',
#  '../data/USGS/OldScienceBase_CSDGM_data.csv',
#  '../data/USGS/ScienceBase_CSDGM_data.csv']

# %% [markdown]
# Create a function that allows us to import the csv contents into a dataframe.

# %%
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(DataFile))
    return CollectionConceptsDF

# %% [markdown]
# Create dropdown to select csv

# %%
interactive(DataChoices,DataFile=DataFiles)

# %% [markdown]
# Drop the columns we don't need

# %%
CollectionConceptsDF.drop(['XPath','Content','DialectDefinition'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#            Collection Dialect                        Record     Concept
# 0      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 1      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 2      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 3      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 4      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 5      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 6      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 7      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml  Start Time
# 8      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml    End Time
# 9      OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 10     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 11     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 12     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 13     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 14     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 15     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 16     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 17     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 18     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 19     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 20     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 21     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 22     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 23     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 24     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 25     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 26     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 27     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 28     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# 29     OldScienceBase   CSDGM  4f4e4773e4b07f02db47e241.xml     Unknown
# ...               ...     ...                           ...         ...
# 23420  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23421  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23422  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23423  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23424  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23425  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23426  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23427  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23428  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23429  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23430  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23431  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23432  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23433  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23434  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23435  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23436  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23437  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23438  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23439  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23440  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23441  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23442  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23443  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23444  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23445  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23446  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23447  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23448  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
# 23449  OldScienceBase   CSDGM  54f8f80be4b02419550d9b22.xml     Unknown
#
# [23450 rows x 4 columns]

# %% [markdown]
# Remove duplicate rows to increase processing speed in Excel.

# %%
ConceptsDF=CollectionConceptsDF.drop_duplicates()

# %% [markdown]
# Create a new csv with just the information we want in it

# %%
ConceptsDF.to_csv('../data/dataForRAD.csv', mode = 'w', index=False)

# %% [markdown]
# Links to open dataForRAD.csv and the RAD ready for data entry. Copy the cells in the data table we created and paste onto the data worksheet. Then switch to the dashboard worksheet and

# %% [markdown]
# [My data table](../data/dataForRAD.csv)
#
# [Recommendations Analysis Dashboard](../RAD/RAD.xlsx)
