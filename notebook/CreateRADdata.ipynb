# %% [markdown]
# ##  This notebook allows the user to refine the data.csv created in Metadata2Data by the Evaluator service. The resulting csv can be copied into a Recommedations Analysis Dashboard to analyze the collection for recommendation completeness for about 30 different Earth and Space Science communities recommendations.

# %% [markdown]
# Import needed python packages

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipywidgets import *
import ipywidgets as widgets

# %% [markdown]
# Create a list of data.csv that are in the MILE2 repository

# %%
DataFiles=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith(".csv")]:
        DataFiles.extend([os.path.join(dirpath, filename)])
DataFiles
# Out:
# ['../data/data.csv',
#  '../data/BCO-DMO/GeoTraces_ISO_data.csv',
#  '../data/DataONE/CDL_CSDGM_data.csv',
#  '../data/DataONE/CLOEBIRD_EML_data.csv',
#  '../data/DataONE/Dryad_Dryad_data.csv',
#  '../data/DataONE/EDACGSTORE_CSDGM_data.csv',
#  '../data/DataONE/EDORA_Mercury_data.csv',
#  '../data/DataONE/ESA_EML_data.csv',
#  '../data/DataONE/GLEON_EML_data.csv',
#  '../data/DataONE/GOA_EML_data.csv',
#  '../data/DataONE/IARC_Onedcx_data.csv',
#  '../data/DataONE/IOE_EML_data.csv',
#  '../data/DataONE/KNB_EML_data.csv',
#  '../data/DataONE/KUBI_EML_data.csv',
#  '../data/DataONE/LTER_EML_data.csv',
#  '../data/DataONE/LTER_EUROPE_EML_data.csv',
#  '../data/DataONE/NMEPSCOR_CSDGM_data.csv',
#  '../data/DataONE/ONEShare_EML_data.csv',
#  '../data/DataONE/ORNLDAAC_Mercury_data.csv',
#  '../data/DataONE/PISCO_EML_data.csv',
#  '../data/DataONE/RGD_Mercury_data.csv',
#  '../data/DataONE/SANPARKS_EML_data.csv',
#  '../data/DataONE/SEAD_CSDGM_data.csv',
#  '../data/DataONE/TERN_EML_data.csv',
#  '../data/DataONE/TFRI_EML_data.csv',
#  '../data/DataONE/US_MPC_Onedcx_data.csv',
#  '../data/DataONE/USANPN_EML_data.csv',
#  '../data/DataONE/USGSCSAS_BDP_data.csv',
#  '../data/DataONE/USGSCSAS_CSDGM_data.csv',
#  '../data/IEDA/ECL_DCITE_data.csv',
#  '../data/IEDA/MarineGeoscienceDataSystem_ISO_data.csv',
#  '../data/LTERthroughTime/LTER_2005_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2006_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2007_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2008_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2009_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2010_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2011_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2012_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2013_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2014_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2015_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2016_EML_data.csv',
#  '../data/NASA/GES_DISC_DIF_data.csv',
#  '../data/NASA/GHRC_DIF_data.csv',
#  '../data/NASA/GHRC_ISO_data.csv',
#  '../data/NASA/LARC_DIF_data.csv',
#  '../data/NASA/LARC_ISO_data.csv',
#  '../data/NASA/NSIDC_DIF_data.csv',
#  '../data/NASA/NSIDC_ISO_data.csv',
#  '../data/NCAR/IIS_MODS_data.csv',
#  '../data/NCAR/RDA_RDA-CISL_data.csv',
#  '../data/ORNL/DAAC_Mercury_data.csv',
#  '../data/ORNL/NGEE_CSDGM_data.csv',
#  '../data/ORNL/OLI_ISO_data.csv',
#  '../data/ORNL/USGSC_CSDGM_data.csv',
#  '../data/USGS/OldScienceBase_CSDGM_data.csv',
#  '../data/USGS/ScienceBase_CSDGM_data.csv']

# %% [markdown]
# Create a function that allows us to import the csv contents into a dataframe.

# %%
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(DataFile))
    return CollectionConceptsDF

# %% [markdown]
# Create dropdown to select csv

# %%
interactive(DataChoices,DataFile=DataFiles)

# %% [markdown]
# Drop the columns we don't need in the RAD

# %%
CollectionConceptsDF.drop(['XPath','Content','DialectDefinition'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#     Collection Dialect              Record                          Concept
# 0        GLEON     EML  04050-metadata.xml                          Unknown
# 1        GLEON     EML  04050-metadata.xml                          Unknown
# 2        GLEON     EML  04050-metadata.xml                          Unknown
# 3        GLEON     EML  04050-metadata.xml             Security Constraints
# 4        GLEON     EML  04050-metadata.xml      Resource Access Constraints
# 5        GLEON     EML  04050-metadata.xml      Metadata Access Constraints
# 6        GLEON     EML  04050-metadata.xml         Metadata Use Constraints
# 7        GLEON     EML  04050-metadata.xml                  Resource Status
# 8        GLEON     EML  04050-metadata.xml                   Resource Title
# 9        GLEON     EML  04050-metadata.xml               Resource Long Name
# 10       GLEON     EML  04050-metadata.xml                           Author
# 11       GLEON     EML  04050-metadata.xml              Author / Originator
# 12       GLEON     EML  04050-metadata.xml                           Author
# 13       GLEON     EML  04050-metadata.xml              Author / Originator
# 14       GLEON     EML  04050-metadata.xml                 Metadata Contact
# 15       GLEON     EML  04050-metadata.xml                 Contributor Name
# 16       GLEON     EML  04050-metadata.xml  Resource Creation/Revision Date
# 17       GLEON     EML  04050-metadata.xml                 Publication Date
# 18       GLEON     EML  04050-metadata.xml                         Abstract
# 19       GLEON     EML  04050-metadata.xml                          Keyword
# 20       GLEON     EML  04050-metadata.xml               Keyword Vocabulary
# 21       GLEON     EML  04050-metadata.xml                           Rights
# 22       GLEON     EML  04050-metadata.xml         Resource Use Constraints
# 23       GLEON     EML  04050-metadata.xml            Resource Distribution
# 24       GLEON     EML  04050-metadata.xml                  Temporal Extent
# 25       GLEON     EML  04050-metadata.xml                   Spatial Extent
# 26       GLEON     EML  04050-metadata.xml                 Resource Contact
# 27       GLEON     EML  04050-metadata.xml                          Unknown
# 28       GLEON     EML  04050-metadata.xml                          Unknown
# 29       GLEON     EML  04050-metadata.xml                          Unknown
# ..         ...     ...                 ...                              ...
# 869      GLEON     EML  04062-metadata.xml                          Purpose
# 870      GLEON     EML  04062-metadata.xml                 Resource Contact
# 871      GLEON     EML  04062-metadata.xml                     Process Step
# 872      GLEON     EML  04062-metadata.xml                 Resource Lineage
# 873      GLEON     EML  04062-metadata.xml        Related Resource Citation
# 874      GLEON     EML  04062-metadata.xml              Project Description
# 875      GLEON     EML  04062-metadata.xml                          Unknown
# 876      GLEON     EML  04062-metadata.xml                          Unknown
# 877      GLEON     EML  04062-metadata.xml                          Unknown
# 878      GLEON     EML  04062-metadata.xml                          Unknown
# 879      GLEON     EML  04062-metadata.xml                          Unknown
# 880      GLEON     EML  04062-metadata.xml                          Unknown
# 881      GLEON     EML  04062-metadata.xml                          Unknown
# 882      GLEON     EML  04062-metadata.xml                          Unknown
# 883      GLEON     EML  04062-metadata.xml                          Unknown
# 884      GLEON     EML  04062-metadata.xml                          Unknown
# 885      GLEON     EML  04062-metadata.xml                          Unknown
# 886      GLEON     EML  04062-metadata.xml                  Resource Format
# 887      GLEON     EML  04062-metadata.xml              Distribution Format
# 888      GLEON     EML  04062-metadata.xml                          Unknown
# 889      GLEON     EML  04062-metadata.xml                          Unknown
# 890      GLEON     EML  04062-metadata.xml                          Unknown
# 891      GLEON     EML  04062-metadata.xml                   Attribute List
# 892      GLEON     EML  04062-metadata.xml                          Unknown
# 893      GLEON     EML  04062-metadata.xml                          Unknown
# 894      GLEON     EML  04062-metadata.xml                          Unknown
# 895      GLEON     EML  04062-metadata.xml                          Unknown
# 896      GLEON     EML  04062-metadata.xml                          Unknown
# 897      GLEON     EML  04062-metadata.xml                          Unknown
# 898      GLEON     EML  04062-metadata.xml                          Unknown
#
# [899 rows x 4 columns]

# %% [markdown]
# Remove duplicate rows to increase processing speed in Excel.

# %%
ConceptsDF=CollectionConceptsDF.drop_duplicates()

# %% [markdown]
# Create a new csv with just the information we want in it

# %%
ConceptsDF.to_csv('../data/dataForRAD.csv', mode = 'w', index=False)

# %% [markdown]
# Links to open dataForRAD.csv and the RAD ready for data entry. Copy the cells in the data table we created and paste onto the data worksheet. Then switch to the dashboard worksheet and select the recommendation you are interested in evaluating the metadata with.

# %% [markdown]
# [My data table](../data/dataForRAD.csv)
#
# [Recommendations Analysis Dashboard](../RAD/RAD.xlsx)
