# %% [markdown]
# ##  This notebook allows the user to look at all the content a specific concept contains, collection wide.

# %% [markdown]
# ### Read in a csv that the user selects by selecting the organization and collection.

# %%
import pandas as pd


import os
from os import walk
import fnmatch
from ipywidgets import *
import ipywidgets as widgets
from bokeh.charts import output_notebook, show, Bar
from bokeh.plotting import figure
from bokeh.models import Range1d, HoverTool, ResizeTool
from bokeh.charts import defaults
from bokeh.models import Legend
pd.options.display.max_colwidth=200
defaults.width = 1800
defaults.height = 1000
output_notebook()
#from ipywidgets import Button, Layout
#from glob import glob
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="82316199-6302-464a-9a5f-56413b18edd9">Loading BokehJS ...</span>
#     </div>

# %%
#subprocess()

# %% [markdown]
# ### query the directory for data files

# %%
DataFiles=[]
for path, subdirectories, filenames in os.walk('../data/'):
    for filename in filenames:
        if fnmatch.fnmatch(filename, '*.csv'):
            DataFiles.append(os.path.join(path,filename).split("../data/", 1)[-1])
DataFiles
# Out:
# ['data.csv',
#  'BCO-DMO/GeoTraces_ISO_data.csv',
#  'DataONE/CDL_CSDGM_data.csv',
#  'DataONE/CLOEBIRD_EML_data.csv',
#  'DataONE/Dryad_Dryad_data.csv',
#  'DataONE/EDACGSTORE_CSDGM_data.csv',
#  'DataONE/EDORA_Mercury_data.csv',
#  'DataONE/ESA_EML_data.csv',
#  'DataONE/GLEON_EML_data.csv',
#  'DataONE/GOA_EML_data.csv',
#  'DataONE/IARC_Onedcx_data.csv',
#  'DataONE/IOE_EML_data.csv',
#  'DataONE/KNB_EML_data.csv',
#  'DataONE/KUBI_EML_data.csv',
#  'DataONE/LTER_EML_data.csv',
#  'DataONE/LTER_EUROPE_EML_data.csv',
#  'DataONE/NMEPSCOR_CSDGM_data.csv',
#  'DataONE/ONEShare_EML_data.csv',
#  'DataONE/ORNLDAAC_Mercury_data.csv',
#  'DataONE/PISCO_EML_data.csv',
#  'DataONE/RGD_Mercury_data.csv',
#  'DataONE/SANPARKS_EML_data.csv',
#  'DataONE/SEAD_CSDGM_data.csv',
#  'DataONE/TERN_EML_data.csv',
#  'DataONE/TFRI_EML_data.csv',
#  'DataONE/US_MPC_Onedcx_data.csv',
#  'DataONE/USANPN_EML_data.csv',
#  'DataONE/USGSCSAS_BDP_data.csv',
#  'DataONE/USGSCSAS_CSDGM_data.csv',
#  'IEDA/ECL_DCITE_data.csv',
#  'LTERthroughTime/LTER_2005_EML_data.csv',
#  'LTERthroughTime/LTER_2006_EML_data.csv',
#  'LTERthroughTime/LTER_2007_EML_data.csv',
#  'LTERthroughTime/LTER_2008_EML_data.csv',
#  'LTERthroughTime/LTER_2009_EML_data.csv',
#  'LTERthroughTime/LTER_2010_EML_data.csv',
#  'LTERthroughTime/LTER_2011_EML_data.csv',
#  'LTERthroughTime/LTER_2012_EML_data.csv',
#  'LTERthroughTime/LTER_2013_EML_data.csv',
#  'LTERthroughTime/LTER_2014_EML_data.csv',
#  'LTERthroughTime/LTER_2015_EML_data.csv',
#  'LTERthroughTime/LTER_2016_EML_data.csv',
#  'NASA/GES_DISC_DIF_data.csv',
#  'NASA/GHRC_DIF_data.csv',
#  'NASA/GHRC_ISO_data.csv',
#  'NASA/LARC_DIF_data.csv',
#  'NASA/LARC_ISO_data.csv',
#  'NASA/NSIDC_DIF_data.csv',
#  'NASA/NSIDC_ISO_data.csv',
#  'NCAR/IIS_MODS_data.csv',
#  'NCAR/RDA_RDA-CISL_data.csv',
#  'ORNL/DAAC_Mercury_data.csv',
#  'ORNL/NGEE_CSDGM_data.csv',
#  'ORNL/OLI_ISO_data.csv',
#  'ORNL/USGSC_CSDGM_data.csv',
#  'USGS/OldScienceBase_CSDGM_data.csv',
#  'USGS/ScienceBase_CSDGM_data.csv']

# %% [markdown]
# ### Choose the data you want to look at by creating a dropdown with a function that uses the list of files

# %% [markdown]
# ### Function that reads the selected csv into a dataframe

# %%
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join('../data', DataFile))
    return CollectionConceptsDF

# %% [markdown]
# ### Choose the CSV you want to examine

# %%
interactive(DataChoices, DataFile=DataFiles)
# Out:
#        Unnamed: 0  Collection Dialect              Record  \
# 0               0  EDACGSTORE   CSDGM  02225-metadata.xml
# 1               1  EDACGSTORE   CSDGM  02225-metadata.xml
# 2               2  EDACGSTORE   CSDGM  02225-metadata.xml
# 3               3  EDACGSTORE   CSDGM  02225-metadata.xml
# 4               4  EDACGSTORE   CSDGM  02225-metadata.xml
# 5               5  EDACGSTORE   CSDGM  02225-metadata.xml
# 6               6  EDACGSTORE   CSDGM  02225-metadata.xml
# 7               7  EDACGSTORE   CSDGM  02225-metadata.xml
# 8               8  EDACGSTORE   CSDGM  02225-metadata.xml
# 9               9  EDACGSTORE   CSDGM  02225-metadata.xml
# 10             10  EDACGSTORE   CSDGM  02225-metadata.xml
# 11             11  EDACGSTORE   CSDGM  02225-metadata.xml
# 12             12  EDACGSTORE   CSDGM  02225-metadata.xml
# 13             13  EDACGSTORE   CSDGM  02225-metadata.xml
# 14             14  EDACGSTORE   CSDGM  02225-metadata.xml
# 15             15  EDACGSTORE   CSDGM  02225-metadata.xml
# 16             16  EDACGSTORE   CSDGM  02225-metadata.xml
# 17             17  EDACGSTORE   CSDGM  02225-metadata.xml
# 18             18  EDACGSTORE   CSDGM  02225-metadata.xml
# 19             19  EDACGSTORE   CSDGM  02225-metadata.xml
# 20             20  EDACGSTORE   CSDGM  02225-metadata.xml
# 21             21  EDACGSTORE   CSDGM  02225-metadata.xml
# 22             22  EDACGSTORE   CSDGM  02225-metadata.xml
# 23             23  EDACGSTORE   CSDGM  02225-metadata.xml
# 24             24  EDACGSTORE   CSDGM  02225-metadata.xml
# 25             25  EDACGSTORE   CSDGM  02225-metadata.xml
# 26             26  EDACGSTORE   CSDGM  02225-metadata.xml
# 27             27  EDACGSTORE   CSDGM  02225-metadata.xml
# 28             28  EDACGSTORE   CSDGM  02225-metadata.xml
# 29             29  EDACGSTORE   CSDGM  02225-metadata.xml
# ...           ...         ...     ...                 ...
# 15445       15445  EDACGSTORE   CSDGM  02040-metadata.xml
# 15446       15446  EDACGSTORE   CSDGM  02040-metadata.xml
# 15447       15447  EDACGSTORE   CSDGM  02040-metadata.xml
# 15448       15448  EDACGSTORE   CSDGM  02040-metadata.xml
# 15449       15449  EDACGSTORE   CSDGM  02040-metadata.xml
# 15450       15450  EDACGSTORE   CSDGM  02040-metadata.xml
# 15451       15451  EDACGSTORE   CSDGM  02040-metadata.xml
# 15452       15452  EDACGSTORE   CSDGM  02040-metadata.xml
# 15453       15453  EDACGSTORE   CSDGM  02040-metadata.xml
# 15454       15454  EDACGSTORE   CSDGM  02040-metadata.xml
# 15455       15455  EDACGSTORE   CSDGM  02040-metadata.xml
# 15456       15456  EDACGSTORE   CSDGM  02040-metadata.xml
# 15457       15457  EDACGSTORE   CSDGM  02040-metadata.xml
# 15458       15458  EDACGSTORE   CSDGM  02040-metadata.xml
# 15459       15459  EDACGSTORE   CSDGM  02040-metadata.xml
# 15460       15460  EDACGSTORE   CSDGM  02040-metadata.xml
# 15461       15461  EDACGSTORE   CSDGM  02040-metadata.xml
# 15462       15462  EDACGSTORE   CSDGM  02040-metadata.xml
# 15463       15463  EDACGSTORE   CSDGM  02040-metadata.xml
# 15464       15464  EDACGSTORE   CSDGM  02040-metadata.xml
# 15465       15465  EDACGSTORE   CSDGM  02040-metadata.xml
# 15466       15466  EDACGSTORE   CSDGM  02040-metadata.xml
# 15467       15467  EDACGSTORE   CSDGM  02040-metadata.xml
# 15468       15468  EDACGSTORE   CSDGM  02040-metadata.xml
# 15469       15469  EDACGSTORE   CSDGM  02040-metadata.xml
# 15470       15470  EDACGSTORE   CSDGM  02040-metadata.xml
# 15471       15471  EDACGSTORE   CSDGM  02040-metadata.xml
# 15472       15472  EDACGSTORE   CSDGM  02040-metadata.xml
# 15473       15473  EDACGSTORE   CSDGM  02040-metadata.xml
# 15474       15474  EDACGSTORE   CSDGM  02040-metadata.xml
#
#                                 Concept  \
# 0                               Unknown
# 1                     Resource Citation
# 2                              Abstract
# 3                               Purpose
# 4                               Unknown
# 5                       Temporal Extent
# 6                               Unknown
# 7                       Resource Status
# 8                          Bounding Box
# 9                        Spatial Extent
# 10                   Keyword Vocabulary
# 11                         Keyword Type
# 12                        Theme Keyword
# 13                              Keyword
# 14                   Keyword Vocabulary
# 15                         Keyword Type
# 16                        Theme Keyword
# 17                              Keyword
# 18                        Theme Keyword
# 19                              Keyword
# 20                        Theme Keyword
# 21                              Keyword
# 22                        Theme Keyword
# 23                              Keyword
# 24             Place Keyword Vocabulary
# 25                        Place Keyword
# 26                              Keyword
# 27                        Place Keyword
# 28                              Keyword
# 29             Place Keyword Vocabulary
# ...                                 ...
# 15445                     Place Keyword
# 15446                           Keyword
# 15447                     Place Keyword
# 15448                           Keyword
# 15449                     Place Keyword
# 15450                           Keyword
# 15451                            Rights
# 15452       Resource Access Constraints
# 15453                            Rights
# 15454          Resource Use Constraints
# 15455                  Resource Contact
# 15456                 Quality Statement
# 15457      Resource Quality Description
# 15458                           Unknown
# 15459                           Unknown
# 15460                           Unknown
# 15461                           Unknown
# 15462                Spatial Resolution
# 15463                           Unknown
# 15464                           Unknown
# 15465                           Unknown
# 15466                           Unknown
# 15467  Entity and Attribute Information
# 15468             Resource Distribution
# 15469            Metadata Modified Date
# 15470                  Metadata Contact
# 15471                 Metadata Language
# 15472        Metadata Standard Citation
# 15473         Metadata Standard Version
# 15474          Metadata Time Convention
#
#                                                                                                                                                                                                        Content  \
# 0                                                                                                                                                           http://www.fgdc.gov/metadata/fgdc-std-001-1998.xsd
# 1      John Wilson 20140116 NMT Valles Caldera Air Temperature Data, Site T1 (Sep 11, 2010 - Nov 18, 2011) vector digital data http://nmepscor.org/dataportal https://gstore.unm.edu/dataone/v1/object/9679...
# 2      With growing concerns about declining snowpack, warmer temperatures, and land use changes, it is becoming increasingly important to determine the sources that contribute to surface water. In weste...
# 3                                                                                                                                                                      Water well data collection information.
# 4      Funding Source is NM EPSCoR. Principal Investigator is John Wilson at New Mexico Tech. The main researcher for this project is Jesus Gomez at New Mexico Tech. This file is made available through N...
# 5                                                                                                                                                                                     20100911 000000 20111118
# 6                                                                                                                                                                                             Ground condition
# 7                                                                                                                                                                                           Complete As needed
# 8                                                                                                                                                                  -106.501177 -106.501177 35.841591 35.841591
# 9                                                                                                                                                                  -106.501177 -106.501177 35.841591 35.841591
# 10                                                                                                                                                                                  ISO 19115 Topic Categories
# 11                                                                                                                                                                                  ISO 19115 Topic Categories
# 12                                                                                                                                                                                                  atmosphere
# 13                                                                                                                                                                                                  atmosphere
# 14                                                                                                                                                                                                 John Wilson
# 15                                                                                                                                                                                                 John Wilson
# 16                                                                                                                                                                                           EPSCoR Track 1 R3
# 17                                                                                                                                                                                           EPSCoR Track 1 R3
# 18                                                                                                                                                                          Snow-dominated Mountain Watersheds
# 19                                                                                                                                                                          Snow-dominated Mountain Watersheds
# 20                                                                                                                                                                                           Groundwater Wells
# 21                                                                                                                                                                                           Groundwater Wells
# 22                                                                                                                                                                                                         Air
# 23                                                                                                                                                                                                         Air
# 24                                                                                                                                                                        Spatial Reference System Identifiers
# 25                                                                                                                                                                                                   EPSG:4326
# 26                                                                                                                                                                                                   EPSG:4326
# 27                                                                                                                                                                                                   EPSG:4326
# 28                                                                                                                                                                                                   EPSG:4326
# 29                                                                                                                                                                                                        GNIS
# ...                                                                                                                                                                                                        ...
# 15445                                                                                                                                                                                    East Fork Jemez River
# 15446                                                                                                                                                                                    East Fork Jemez River
# 15447                                                                                                                                                                                             Valle Grande
# 15448                                                                                                                                                                                             Valle Grande
# 15449                                                                                                                                                                                          Sandoval County
# 15450                                                                                                                                                                                          Sandoval County
# 15451                                                                                                                                                                                                     None
# 15452                                                                                                                                                                                                     None
# 15453                                                                                                                                                                                                     None
# 15454                                                                                                                                                                                                     None
# 15455                              Department of Biology, University of New Mexico Cliff Dahm mailing address 167 Castetter Hall MSC03 2020 Albuquerque NM 87131-0001 USA 505-277-3411 cdahm@sevilleta.unm.edu
# 15456  Not provided Completed Field collection. Unknown University of New Mexico, Department of Biology Virginia Thompson mailing address MSC03 2020 1 University of New Mexico Albuquerque NM 87131-0001 U...
# 15457  Not provided Completed Field collection. Unknown University of New Mexico, Department of Biology Virginia Thompson mailing address MSC03 2020 1 University of New Mexico Albuquerque NM 87131-0001 U...
# 15458                                                                                                                                                                                           Valles Caldera
# 15459                                                                                                                                                                                                   Vector
# 15460                                                                                                                                                                                                    Point
# 15461                                                                                                                                                                                                       75
# 15462                                                                                                                                                                    0.00000001 0.00000001 Decimal degrees
# 15463                                                                                                                                                                                               D_WGS_1984
# 15464                                                                                                                                                                                                 WGS_1984
# 15465                                                                                                                                                                                           6378137.000000
# 15466                                                                                                                                                                                               298.257224
# 15467  Macrophyte Data 2012 Aquatic Macrophyte Data EDAC Date Sample collection date UNM Sample collection date Site Site identifier UNM Site identifier Transect Transect identifier UNM Transect identifi...
# 15468  Earth Data Analysis Center Clearinghouse Manager mailing and physical address MSC01 1110 1 University of New Mexico Albuquerque NM 87131-0001 USA 505-277-3622 ext. 230 505-277-3614 clearinghouse@e...
# 15469                                                                                                                                                                                                 20140325
# 15470  Earth Data Analysis Center Clearinghouse Manager mailing and physical address MSC01 1110 1 University of New Mexico Albuquerque NM 87131-0001 USA 505-277-3622 ext. 230 505-277-3614 clearinghouse@e...
# 15471                                                                                                                                                   FGDC Content Standards for Digital Geospatial Metadata
# 15472                                                                                                                                                   FGDC Content Standards for Digital Geospatial Metadata
# 15473                                                                                                                                                                                        FGDC-STD-001-1998
# 15474                                                                                                                                                                                               local time
#
#                                                XPath  \
# 0           /metadata/@xsi:noNamespaceSchemaLocation
# 1                 /metadata/idinfo/citation/citeinfo
# 2                 /metadata/idinfo/descript/abstract
# 3                  /metadata/idinfo/descript/purpose
# 4                 /metadata/idinfo/descript/supplinf
# 5        /metadata/idinfo/timeperd/timeinfo/rngdates
# 6                  /metadata/idinfo/timeperd/current
# 7                            /metadata/idinfo/status
# 8                    /metadata/idinfo/spdom/bounding
# 9                    /metadata/idinfo/spdom/bounding
# 10           /metadata/idinfo/keywords/theme/themekt
# 11           /metadata/idinfo/keywords/theme/themekt
# 12          /metadata/idinfo/keywords/theme/themekey
# 13          /metadata/idinfo/keywords/theme/themekey
# 14           /metadata/idinfo/keywords/theme/themekt
# 15           /metadata/idinfo/keywords/theme/themekt
# 16          /metadata/idinfo/keywords/theme/themekey
# 17          /metadata/idinfo/keywords/theme/themekey
# 18          /metadata/idinfo/keywords/theme/themekey
# 19          /metadata/idinfo/keywords/theme/themekey
# 20          /metadata/idinfo/keywords/theme/themekey
# 21          /metadata/idinfo/keywords/theme/themekey
# 22          /metadata/idinfo/keywords/theme/themekey
# 23          /metadata/idinfo/keywords/theme/themekey
# 24           /metadata/idinfo/keywords/place/placekt
# 25          /metadata/idinfo/keywords/place/placekey
# 26          /metadata/idinfo/keywords/place/placekey
# 27          /metadata/idinfo/keywords/place/placekey
# 28          /metadata/idinfo/keywords/place/placekey
# 29           /metadata/idinfo/keywords/place/placekt
# ...                                              ...
# 15445       /metadata/idinfo/keywords/place/placekey
# 15446       /metadata/idinfo/keywords/place/placekey
# 15447       /metadata/idinfo/keywords/place/placekey
# 15448       /metadata/idinfo/keywords/place/placekey
# 15449       /metadata/idinfo/keywords/place/placekey
# 15450       /metadata/idinfo/keywords/place/placekey
# 15451                      /metadata/idinfo/accconst
# 15452                      /metadata/idinfo/accconst
# 15453                      /metadata/idinfo/useconst
# 15454                      /metadata/idinfo/useconst
# 15455                      /metadata/idinfo/ptcontac
# 15456                             /metadata/dataqual
# 15457                             /metadata/dataqual
# 15458                    /metadata/spdoinfo/indspref
# 15459                      /metadata/spdoinfo/direct
# 15460  /metadata/spdoinfo/ptvctinf/sdtsterm/sdtstype
# 15461  /metadata/spdoinfo/ptvctinf/sdtsterm/ptvctcnt
# 15462              /metadata/spref/horizsys/geograph
# 15463      /metadata/spref/horizsys/geodetic/horizdn
# 15464       /metadata/spref/horizsys/geodetic/ellips
# 15465     /metadata/spref/horizsys/geodetic/semiaxis
# 15466      /metadata/spref/horizsys/geodetic/denflat
# 15467                               /metadata/eainfo
# 15468                             /metadata/distinfo
# 15469                        /metadata/metainfo/metd
# 15470                /metadata/metainfo/metc/cntinfo
# 15471                     /metadata/metainfo/metstdn
# 15472                     /metadata/metainfo/metstdn
# 15473                     /metadata/metainfo/metstdv
# 15474                       /metadata/metainfo/mettc
#
#                                                                DialectDefinition  \
# 0                                                                      Undefined
# 1                     /csdgm:metadata/csdgm:idinfo/csdgm:citation/csdgm:citeinfo
# 2                     /csdgm:metadata/csdgm:idinfo/csdgm:descript/csdgm:abstract
# 3                      /csdgm:metadata/csdgm:idinfo/csdgm:descript/csdgm:purpose
# 4                                                                      Undefined
# 5      /csdgm:metadata/csdgm:idinfo/csdgm:timeperd/csdgm:timeinfo/csdgm:rngdates
# 6                                                                      Undefined
# 7                                      /csdgm:metadata/csdgm:idinfo/csdgm:status
# 8                        /csdgm:metadata/csdgm:idinfo/csdgm:spdom/csdgm:bounding
# 9                        /csdgm:metadata/csdgm:idinfo/csdgm:spdom/csdgm:bounding
# 10         /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekt
# 11         /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekt
# 12        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 13        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 14         /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekt
# 15         /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekt
# 16        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 17        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 18        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 19        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 20        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 21        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 22        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 23        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:theme/csdgm:themekey
# 24         /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekt
# 25        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 26        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 27        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 28        /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 29         /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekt
# ...                                                                          ...
# 15445     /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 15446     /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 15447     /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 15448     /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 15449     /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 15450     /csdgm:metadata/csdgm:idinfo/csdgm:keywords/csdgm:place/csdgm:placekey
# 15451                                /csdgm:metadata/csdgm:idinfo/csdgm:accconst
# 15452                                /csdgm:metadata/csdgm:idinfo/csdgm:accconst
# 15453                                /csdgm:metadata/csdgm:idinfo/csdgm:useconst
# 15454                                /csdgm:metadata/csdgm:idinfo/csdgm:useconst
# 15455                                /csdgm:metadata/csdgm:idinfo/csdgm:ptcontac
# 15456                                             /csdgm:metadata/csdgm:dataqual
# 15457                                             /csdgm:metadata/csdgm:dataqual
# 15458                                                                  Undefined
# 15459                                                                  Undefined
# 15460                                                                  Undefined
# 15461                                                                  Undefined
# 15462                  /csdgm:metadata/csdgm:spref/csdgm:horizsys/csdgm:geograph
# 15463                                                                  Undefined
# 15464                                                                  Undefined
# 15465                                                                  Undefined
# 15466                                                                  Undefined
# 15467                                               /csdgm:metadata/csdgm:eainfo
# 15468                                             /csdgm:metadata/csdgm:distinfo
# 15469                                  /csdgm:metadata/csdgm:metainfo/csdgm:metd
# 15470                    /csdgm:metadata/csdgm:metainfo/csdgm:metc/csdgm:cntinfo
# 15471                               /csdgm:metadata/csdgm:metainfo/csdgm:metstdn
# 15472                               /csdgm:metadata/csdgm:metainfo/csdgm:metstdn
# 15473                               /csdgm:metadata/csdgm:metainfo/csdgm:metstdv
# 15474                                 /csdgm:metadata/csdgm:metainfo/csdgm:mettc
#
#                                                 DocumentLocation
# 0                       /metadata/@xsi:noNamespaceSchemaLocation
# 1                    /metadata/idinfo[1]/citation[1]/citeinfo[1]
# 2                    /metadata/idinfo[1]/descript[1]/abstract[1]
# 3                     /metadata/idinfo[1]/descript[1]/purpose[1]
# 4                    /metadata/idinfo[1]/descript[1]/supplinf[1]
# 5        /metadata/idinfo[1]/timeperd[1]/timeinfo[1]/rngdates[1]
# 6                     /metadata/idinfo[1]/timeperd[1]/current[1]
# 7                                  /metadata/idinfo[1]/status[1]
# 8                       /metadata/idinfo[1]/spdom[1]/bounding[1]
# 9                       /metadata/idinfo[1]/spdom[1]/bounding[1]
# 10           /metadata/idinfo[1]/keywords[1]/theme[1]/themekt[1]
# 11           /metadata/idinfo[1]/keywords[1]/theme[1]/themekt[1]
# 12          /metadata/idinfo[1]/keywords[1]/theme[1]/themekey[1]
# 13          /metadata/idinfo[1]/keywords[1]/theme[1]/themekey[1]
# 14           /metadata/idinfo[1]/keywords[1]/theme[2]/themekt[1]
# 15           /metadata/idinfo[1]/keywords[1]/theme[2]/themekt[1]
# 16          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[1]
# 17          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[1]
# 18          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[2]
# 19          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[2]
# 20          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[3]
# 21          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[3]
# 22          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[4]
# 23          /metadata/idinfo[1]/keywords[1]/theme[2]/themekey[4]
# 24           /metadata/idinfo[1]/keywords[1]/place[1]/placekt[1]
# 25          /metadata/idinfo[1]/keywords[1]/place[1]/placekey[1]
# 26          /metadata/idinfo[1]/keywords[1]/place[1]/placekey[1]
# 27          /metadata/idinfo[1]/keywords[1]/place[1]/placekey[2]
# 28          /metadata/idinfo[1]/keywords[1]/place[1]/placekey[2]
# 29           /metadata/idinfo[1]/keywords[1]/place[2]/placekt[1]
# ...                                                          ...
# 15445       /metadata/idinfo[1]/keywords[1]/place[2]/placekey[3]
# 15446       /metadata/idinfo[1]/keywords[1]/place[2]/placekey[3]
# 15447       /metadata/idinfo[1]/keywords[1]/place[2]/placekey[4]
# 15448       /metadata/idinfo[1]/keywords[1]/place[2]/placekey[4]
# 15449       /metadata/idinfo[1]/keywords[1]/place[2]/placekey[5]
# 15450       /metadata/idinfo[1]/keywords[1]/place[2]/placekey[5]
# 15451                            /metadata/idinfo[1]/accconst[1]
# 15452                            /metadata/idinfo[1]/accconst[1]
# 15453                            /metadata/idinfo[1]/useconst[1]
# 15454                            /metadata/idinfo[1]/useconst[1]
# 15455                            /metadata/idinfo[1]/ptcontac[1]
# 15456                                      /metadata/dataqual[1]
# 15457                                      /metadata/dataqual[1]
# 15458                          /metadata/spdoinfo[1]/indspref[1]
# 15459                            /metadata/spdoinfo[1]/direct[1]
# 15460  /metadata/spdoinfo[1]/ptvctinf[1]/sdtsterm[1]/sdtstype[1]
# 15461  /metadata/spdoinfo[1]/ptvctinf[1]/sdtsterm[1]/ptvctcnt[1]
# 15462                 /metadata/spref[1]/horizsys[1]/geograph[1]
# 15463      /metadata/spref[1]/horizsys[1]/geodetic[1]/horizdn[1]
# 15464       /metadata/spref[1]/horizsys[1]/geodetic[1]/ellips[1]
# 15465     /metadata/spref[1]/horizsys[1]/geodetic[1]/semiaxis[1]
# 15466      /metadata/spref[1]/horizsys[1]/geodetic[1]/denflat[1]
# 15467                                        /metadata/eainfo[1]
# 15468                                      /metadata/distinfo[1]
# 15469                              /metadata/metainfo[1]/metd[1]
# 15470                   /metadata/metainfo[1]/metc[1]/cntinfo[1]
# 15471                           /metadata/metainfo[1]/metstdn[1]
# 15472                           /metadata/metainfo[1]/metstdn[1]
# 15473                           /metadata/metainfo[1]/metstdv[1]
# 15474                             /metadata/metainfo[1]/mettc[1]
#
# [15475 rows x 9 columns]

# %% [markdown]
# ###  Let's get rid of the columns we won't use for this analysis. We already know the organization and dialect after we have selected the organization and collection. The xpaths aren't needed either.

# %%
CollectionConceptsDF.drop(['Collection','Dialect', 'XPath', 'DialectDefinition','DocumentLocation'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#        Unnamed: 0              Record                           Concept  \
# 0               0  02225-metadata.xml                           Unknown
# 1               1  02225-metadata.xml                 Resource Citation
# 2               2  02225-metadata.xml                          Abstract
# 3               3  02225-metadata.xml                           Purpose
# 4               4  02225-metadata.xml                           Unknown
# 5               5  02225-metadata.xml                   Temporal Extent
# 6               6  02225-metadata.xml                           Unknown
# 7               7  02225-metadata.xml                   Resource Status
# 8               8  02225-metadata.xml                      Bounding Box
# 9               9  02225-metadata.xml                    Spatial Extent
# 10             10  02225-metadata.xml                Keyword Vocabulary
# 11             11  02225-metadata.xml                      Keyword Type
# 12             12  02225-metadata.xml                     Theme Keyword
# 13             13  02225-metadata.xml                           Keyword
# 14             14  02225-metadata.xml                Keyword Vocabulary
# 15             15  02225-metadata.xml                      Keyword Type
# 16             16  02225-metadata.xml                     Theme Keyword
# 17             17  02225-metadata.xml                           Keyword
# 18             18  02225-metadata.xml                     Theme Keyword
# 19             19  02225-metadata.xml                           Keyword
# 20             20  02225-metadata.xml                     Theme Keyword
# 21             21  02225-metadata.xml                           Keyword
# 22             22  02225-metadata.xml                     Theme Keyword
# 23             23  02225-metadata.xml                           Keyword
# 24             24  02225-metadata.xml          Place Keyword Vocabulary
# 25             25  02225-metadata.xml                     Place Keyword
# 26             26  02225-metadata.xml                           Keyword
# 27             27  02225-metadata.xml                     Place Keyword
# 28             28  02225-metadata.xml                           Keyword
# 29             29  02225-metadata.xml          Place Keyword Vocabulary
# ...           ...                 ...                               ...
# 15445       15445  02040-metadata.xml                     Place Keyword
# 15446       15446  02040-metadata.xml                           Keyword
# 15447       15447  02040-metadata.xml                     Place Keyword
# 15448       15448  02040-metadata.xml                           Keyword
# 15449       15449  02040-metadata.xml                     Place Keyword
# 15450       15450  02040-metadata.xml                           Keyword
# 15451       15451  02040-metadata.xml                            Rights
# 15452       15452  02040-metadata.xml       Resource Access Constraints
# 15453       15453  02040-metadata.xml                            Rights
# 15454       15454  02040-metadata.xml          Resource Use Constraints
# 15455       15455  02040-metadata.xml                  Resource Contact
# 15456       15456  02040-metadata.xml                 Quality Statement
# 15457       15457  02040-metadata.xml      Resource Quality Description
# 15458       15458  02040-metadata.xml                           Unknown
# 15459       15459  02040-metadata.xml                           Unknown
# 15460       15460  02040-metadata.xml                           Unknown
# 15461       15461  02040-metadata.xml                           Unknown
# 15462       15462  02040-metadata.xml                Spatial Resolution
# 15463       15463  02040-metadata.xml                           Unknown
# 15464       15464  02040-metadata.xml                           Unknown
# 15465       15465  02040-metadata.xml                           Unknown
# 15466       15466  02040-metadata.xml                           Unknown
# 15467       15467  02040-metadata.xml  Entity and Attribute Information
# 15468       15468  02040-metadata.xml             Resource Distribution
# 15469       15469  02040-metadata.xml            Metadata Modified Date
# 15470       15470  02040-metadata.xml                  Metadata Contact
# 15471       15471  02040-metadata.xml                 Metadata Language
# 15472       15472  02040-metadata.xml        Metadata Standard Citation
# 15473       15473  02040-metadata.xml         Metadata Standard Version
# 15474       15474  02040-metadata.xml          Metadata Time Convention
#
#                                                                                                                                                                                                        Content
# 0                                                                                                                                                           http://www.fgdc.gov/metadata/fgdc-std-001-1998.xsd
# 1      John Wilson 20140116 NMT Valles Caldera Air Temperature Data, Site T1 (Sep 11, 2010 - Nov 18, 2011) vector digital data http://nmepscor.org/dataportal https://gstore.unm.edu/dataone/v1/object/9679...
# 2      With growing concerns about declining snowpack, warmer temperatures, and land use changes, it is becoming increasingly important to determine the sources that contribute to surface water. In weste...
# 3                                                                                                                                                                      Water well data collection information.
# 4      Funding Source is NM EPSCoR. Principal Investigator is John Wilson at New Mexico Tech. The main researcher for this project is Jesus Gomez at New Mexico Tech. This file is made available through N...
# 5                                                                                                                                                                                     20100911 000000 20111118
# 6                                                                                                                                                                                             Ground condition
# 7                                                                                                                                                                                           Complete As needed
# 8                                                                                                                                                                  -106.501177 -106.501177 35.841591 35.841591
# 9                                                                                                                                                                  -106.501177 -106.501177 35.841591 35.841591
# 10                                                                                                                                                                                  ISO 19115 Topic Categories
# 11                                                                                                                                                                                  ISO 19115 Topic Categories
# 12                                                                                                                                                                                                  atmosphere
# 13                                                                                                                                                                                                  atmosphere
# 14                                                                                                                                                                                                 John Wilson
# 15                                                                                                                                                                                                 John Wilson
# 16                                                                                                                                                                                           EPSCoR Track 1 R3
# 17                                                                                                                                                                                           EPSCoR Track 1 R3
# 18                                                                                                                                                                          Snow-dominated Mountain Watersheds
# 19                                                                                                                                                                          Snow-dominated Mountain Watersheds
# 20                                                                                                                                                                                           Groundwater Wells
# 21                                                                                                                                                                                           Groundwater Wells
# 22                                                                                                                                                                                                         Air
# 23                                                                                                                                                                                                         Air
# 24                                                                                                                                                                        Spatial Reference System Identifiers
# 25                                                                                                                                                                                                   EPSG:4326
# 26                                                                                                                                                                                                   EPSG:4326
# 27                                                                                                                                                                                                   EPSG:4326
# 28                                                                                                                                                                                                   EPSG:4326
# 29                                                                                                                                                                                                        GNIS
# ...                                                                                                                                                                                                        ...
# 15445                                                                                                                                                                                    East Fork Jemez River
# 15446                                                                                                                                                                                    East Fork Jemez River
# 15447                                                                                                                                                                                             Valle Grande
# 15448                                                                                                                                                                                             Valle Grande
# 15449                                                                                                                                                                                          Sandoval County
# 15450                                                                                                                                                                                          Sandoval County
# 15451                                                                                                                                                                                                     None
# 15452                                                                                                                                                                                                     None
# 15453                                                                                                                                                                                                     None
# 15454                                                                                                                                                                                                     None
# 15455                              Department of Biology, University of New Mexico Cliff Dahm mailing address 167 Castetter Hall MSC03 2020 Albuquerque NM 87131-0001 USA 505-277-3411 cdahm@sevilleta.unm.edu
# 15456  Not provided Completed Field collection. Unknown University of New Mexico, Department of Biology Virginia Thompson mailing address MSC03 2020 1 University of New Mexico Albuquerque NM 87131-0001 U...
# 15457  Not provided Completed Field collection. Unknown University of New Mexico, Department of Biology Virginia Thompson mailing address MSC03 2020 1 University of New Mexico Albuquerque NM 87131-0001 U...
# 15458                                                                                                                                                                                           Valles Caldera
# 15459                                                                                                                                                                                                   Vector
# 15460                                                                                                                                                                                                    Point
# 15461                                                                                                                                                                                                       75
# 15462                                                                                                                                                                    0.00000001 0.00000001 Decimal degrees
# 15463                                                                                                                                                                                               D_WGS_1984
# 15464                                                                                                                                                                                                 WGS_1984
# 15465                                                                                                                                                                                           6378137.000000
# 15466                                                                                                                                                                                               298.257224
# 15467  Macrophyte Data 2012 Aquatic Macrophyte Data EDAC Date Sample collection date UNM Sample collection date Site Site identifier UNM Site identifier Transect Transect identifier UNM Transect identifi...
# 15468  Earth Data Analysis Center Clearinghouse Manager mailing and physical address MSC01 1110 1 University of New Mexico Albuquerque NM 87131-0001 USA 505-277-3622 ext. 230 505-277-3614 clearinghouse@e...
# 15469                                                                                                                                                                                                 20140325
# 15470  Earth Data Analysis Center Clearinghouse Manager mailing and physical address MSC01 1110 1 University of New Mexico Albuquerque NM 87131-0001 USA 505-277-3622 ext. 230 505-277-3614 clearinghouse@e...
# 15471                                                                                                                                                   FGDC Content Standards for Digital Geospatial Metadata
# 15472                                                                                                                                                   FGDC Content Standards for Digital Geospatial Metadata
# 15473                                                                                                                                                                                        FGDC-STD-001-1998
# 15474                                                                                                                                                                                               local time
#
# [15475 rows x 4 columns]

# %% [markdown]
# ### Now that we have the data we want, what are the understood concepts that exist in the collection?

# %%
ConceptVerticals=CollectionConceptsDF.Concept.unique()
Verticals=ConceptVerticals.tolist()
Verticals
# Out:
# ['Unknown',
#  'Resource Citation',
#  'Abstract',
#  'Purpose',
#  'Temporal Extent',
#  'Resource Status',
#  'Bounding Box',
#  'Spatial Extent',
#  'Keyword Vocabulary',
#  'Keyword Type',
#  'Theme Keyword',
#  'Keyword',
#  'Place Keyword Vocabulary',
#  'Place Keyword',
#  'Rights',
#  'Resource Access Constraints',
#  'Resource Use Constraints',
#  'Resource Contact',
#  'Quality Statement',
#  'Resource Quality Description',
#  'Spatial Resolution',
#  'Entity and Attribute Information',
#  'Resource Distribution',
#  'Metadata Modified Date',
#  'Metadata Contact',
#  'Metadata Language',
#  'Metadata Standard Citation',
#  'Metadata Standard Version',
#  'Metadata Time Convention',
#  'Contributor Name',
#  'Acknowledgement',
#  'Browse File Name',
#  'Browse Description',
#  'Browse Format',
#  'Coordinate Reference System (CRS)',
#  'Metadata Profile Citation']

# %% [markdown]
# ### Create function that allows us to call up metadata vertical content for a concept

# %%
def ConceptVerticalTable(Concept):
    global VerticalTable
    VerticalTable = CollectionConceptsDF[CollectionConceptsDF.Concept == Concept]
    return VerticalTable

# %% [markdown]
# ### Create a dropdown using the function that allows us to create a dataframe of the concept you want as a metadata vertical.

# %%
interact(ConceptVerticalTable, Concept=Verticals)
# Out:
#        Unnamed: 0              Record          Concept                Content
# 7               7  02225-metadata.xml  Resource Status     Complete As needed
# 67             67  02051-metadata.xml  Resource Status  Complete None planned
# 139           139  02168-metadata.xml  Resource Status      In work As needed
# 185           185  02142-metadata.xml  Resource Status       Complete Unknown
# 244           244  02111-metadata.xml  Resource Status     Complete As needed
# 304           304  02028-metadata.xml  Resource Status     Complete As needed
# 362           362  02143-metadata.xml  Resource Status     Complete As Needed
# 414           414  02029-metadata.xml  Resource Status     Complete As Needed
# 466           466  02110-metadata.xml  Resource Status     Complete As Needed
# 518           518  02224-metadata.xml  Resource Status      In work As needed
# 562           562  02169-metadata.xml  Resource Status     Complete As needed
# 622           622  02050-metadata.xml  Resource Status      In work As needed
# 668           668  02112-metadata.xml  Resource Status     Complete As needed
# 728           728  02141-metadata.xml  Resource Status     Complete As needed
# 788           788  02078-metadata.xml  Resource Status     Complete As needed
# 848           848  02052-metadata.xml  Resource Status  Complete None planned
# 920           920  02138-metadata.xml  Resource Status     Complete As needed
# 980           980  02226-metadata.xml  Resource Status     Complete As needed
# 1040         1040  02053-metadata.xml  Resource Status     Complete As Needed
# 1125         1125  02227-metadata.xml  Resource Status     Complete As needed
# 1185         1185  02139-metadata.xml  Resource Status     Complete As Needed
# 1253         1253  02113-metadata.xml  Resource Status     Complete As needed
# 1313         1313  02079-metadata.xml  Resource Status     Complete As Needed
# 1398         1398  02140-metadata.xml  Resource Status     Complete As Needed
# 1466         1466  02222-metadata.xml  Resource Status    In work Continually
# 1524         1524  02089-metadata.xml  Resource Status      In work As needed
# 1568         1568  02056-metadata.xml  Resource Status      In work As needed
# 1612         1612  02145-metadata.xml  Resource Status     Complete As needed
# 1672         1672  02116-metadata.xml  Resource Status     Complete As needed
# 1732         1732  02208-metadata.xml  Resource Status     Complete As Needed
# ...           ...                 ...              ...                    ...
# 13698       13698  02047-metadata.xml  Resource Status     Complete As Needed
# 13759       13759  02098-metadata.xml  Resource Status     Complete As needed
# 13819       13819  02102-metadata.xml  Resource Status      In work As needed
# 13867       13867  02151-metadata.xml  Resource Status       Complete Unknown
# 13910       13910  02068-metadata.xml  Resource Status     Complete As Needed
# 13995       13995  02042-metadata.xml  Resource Status     Complete As needed
# 14055       14055  02011-metadata.xml  Resource Status     Complete As needed
# 14115       14115  02236-metadata.xml  Resource Status     Complete As needed
# 14175       14175  02128-metadata.xml  Resource Status       Complete Unknown
# 14239       14239  02043-metadata.xml  Resource Status  Complete None planned
# 14311       14311  02129-metadata.xml  Resource Status      In work As needed
# 14357       14357  02237-metadata.xml  Resource Status     Complete As Needed
# 14425       14425  02010-metadata.xml  Resource Status      In work As needed
# 14469       14469  02103-metadata.xml  Resource Status          Complete None
# 14517       14517  02069-metadata.xml  Resource Status     Complete As needed
# 14577       14577  02150-metadata.xml  Resource Status     Complete As needed
# 14637       14637  02012-metadata.xml  Resource Status     Complete As needed
# 14697       14697  02235-metadata.xml  Resource Status     Complete As Needed
# 14752       14752  02041-metadata.xml  Resource Status     Complete As needed
# 14812       14812  02178-metadata.xml  Resource Status    In work Continually
# 14870       14870  02152-metadata.xml  Resource Status     Complete As needed
# 14930       14930  02101-metadata.xml  Resource Status          Complete None
# 14978       14978  02038-metadata.xml  Resource Status       Complete Unknown
# 15042       15042  02153-metadata.xml  Resource Status     Complete As needed
# 15102       15102  02039-metadata.xml  Resource Status     Complete As Needed
# 15187       15187  02100-metadata.xml  Resource Status      In work As needed
# 15235       15235  02234-metadata.xml  Resource Status      In work As needed
# 15282       15282  02013-metadata.xml  Resource Status     Complete As Needed
# 15350       15350  02179-metadata.xml  Resource Status     Complete As needed
# 15410       15410  02040-metadata.xml  Resource Status  Complete None planned
#
# [250 rows x 4 columns]

# %% [markdown]
# ### Let's group the unique values in the content column and count them up.

# %%
VerticalTable.groupby('Content').size()
# Out:
# Content
# Complete As Needed       78
# Complete As needed       91
# Complete Irregular        2
# Complete None             6
# Complete None planned    16
# Complete Unknown         24
# In work As needed        28
# In work Continually       5
# dtype: int64

# %% [markdown]
# ### Remove colons from the values so there are no Bokeh Label errors. Use Bokeh to plot a bar chart of the unique values.

# %%
data = VerticalTable.Content.str.replace(':','.')

p = Bar(data, 'Content', title="Vertical Value Occurance Count", legend=False)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4876a50b-85e9-43cd-86b5-ca8673c7f437"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4876a50b-85e9-43cd-86b5-ca8673c7f437").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4876a50b-85e9-43cd-86b5-ca8673c7f437");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4876a50b-85e9-43cd-86b5-ca8673c7f437' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"27215904-9455-4301-acb0-88e64fca5cec":{"roots":{"references":[{"attributes":{"data_source":{"id":"bf2801ee-76e9-49b5-9630-bb925aa79850","type":"ColumnDataSource"},"glyph":{"id":"8e676df4-5620-4bb9-a9ef-33468d089bc0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"41963561-712a-4e56-96e5-59536e6dd266","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"86e7fbe4-420f-41c5-8165-4e52018f68a8","subtype":"Chart","type":"Plot"}},"id":"17a05ca3-ab50-434e-8c88-d16a0e42108b","type":"SaveTool"},{"attributes":{},"id":"6a296805-6953-4178-afde-92e591d529ed","type":"BasicTicker"},{"attributes":{"axis_label":"Count( Content )","formatter":{"id":"ae2b3088-e873-4d77-b03c-eade3a9a5e6f","type":"BasicTickFormatter"},"plot":{"id":"86e7fbe4-420f-41c5-8165-4e52018f68a8","subtype":"Chart","type":"Plot"},"ticker":{"id":"6a296805-6953-4178-afde-92e591d529ed","type":"BasicTicker"}},"id":"1fcf0a7c-c293-4a14-8dd4-9ce6f1598769","type":"LinearAxis"},{"attributes":{"callback":null,"factors":["Complete As Needed","Complete As needed","Complete Irregular","Complete None","Complete None planned","Complete Unknown","In work As needed","In work Continually"]},"id":"a1352a55-9d52-4295-9bec-fc66b373a1b7","type":"FactorRange"},{"attributes":{"plot":{"id":"86e7fbe4-420f-41c5-8165-4e52018f68a8","subtype":"Chart","type":"Plot"}},"id":"823236fb-631d-4d0c-85d2-a21f7e4075ab","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"86e7fbe4-420f-41c5-8165-4e52018f68a8","subtype":"Chart","type":"Plot"}},"id":"038d0338-07c4-4222-a18f-acfe73becd77","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["Complete Unknown"],"chart_index":[{"Content":"Complete Unknown"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[24.0],"label":[{"Content":"Complete Unknown"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Complete Unknown"],"y":[12.0]}},"id":"bf2801ee-76e9-49b5-9630-bb925aa79850","type":"ColumnDataSource"},{"attributes":{},"id":"9ababe35-ac9f-4652-acbe-aa19c040c1f8","type":"CategoricalTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"86e7fbe4-420f-41c5-8165-4e52018f68a8","subtype":"Chart","type":"Plot"},"ticker":{"id":"6a296805-6953-4178-afde-92e591d529ed","type":"BasicTicker"}},"id":"5b341c7c-6d12-491c-89f7-31cda781c828","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e5d17f5-d445-4902-8e3f-e3b167dbe766","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["Complete As Needed"],"chart_index":[{"Content":"Complete As Needed"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[78.0],"label":[{"Content":"Complete As Needed"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Complete As Needed"],"y":[39.0]}},"id":"e0ad1848-c6d7-4d3c-9c8b-efde151216a5","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e0ad1848-c6d7-4d3c-9c8b-efde151216a5","type":"ColumnDataSource"},"glyph":{"id":"0e5d17f5-d445-4902-8e3f-e3b167dbe766","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a3202c7f-ae16-4275-80a0-987e687a6a3d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"34eac373-69cc-4702-a904-df3bc50ad711","type":"Rect"},{"attributes":{},"id":"3c291a8d-bea1-49f9-a312-29de572f47e6","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":" ...
