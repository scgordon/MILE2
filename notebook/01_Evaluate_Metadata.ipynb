# %% [raw]
# This notebook allows the user to select XML collections and zip them up to send to a service that runs a transform on them and returns a simple data table. The data included is the Organization, Collection, Dialect, Record, Concept, Content, XPath.
#
# The notebook utilizes Bash and Python with the default packages contained in the Mac build of Anaconda with Python 3.6.
#
# Saxon, Java, XSLT, and Python form the evaluation web service on a NCEAS virtual machine.
#
# This table contains a row for each concept that is found, so some elements may fulfill multiple concepts. A good example of this are the concepts Keyword and Place Keyword. Every Place Keyword is also a Keyword, so the row would repeat with a different Concept name. It also contains a row for each undefined node that contains text, marking these rows with an Unknown in the Concept column.
#
# This data can be used in a variety of analyses including RAD and QuickE as well as Concept Verticals. Quality checks of the content can be  It can also be used to teach the system dialect definitions for concepts that are currently unknown by exposing all of the content at undefined nodes.

# %% [markdown]
# ### First we need to call all of the libraries we need to perform in our metadata wrangle

# %%
import pandas as pd
pd.options.display.width = 180
#import os
from os import walk
import shutil
import ipywidgets as widgets
from ipywidgets import *
import requests
import csv
import io

# %% [markdown]
# ### Now let's select some metadata.

# %% [markdown]
# If you have prepared metadata\* on your computer that you want to add, it is possible to upload into the repository locally using the [Add Metadata](00AddMetadata.ipynb) Notebook before completing the following cells in this notebook. Otherwise, follow along and use some of the sample metadata the following steps will help you to select.
#
# \* Prepared metadata contains a root element that has a standardized namespace and namespace prefix. Many dialects such as ISO and DIF are consistently written this way, but some dialects such as CSDGM are often written by organizations as only well-formed XML.

# %% [markdown]
# #### Choose an Organization

# %%
#Create a list of subdirectories in the collection directory of MILE2 to select metadata for evaluation
Organizations = []
for (dirpath, dirnames, filenames) in walk('../collection/'):
    Organizations.extend(dirnames)
    break  

#Create a function to select the organization the metadata comes from
def OrganizationChoices(organization):
    global OrganizationChoice
    global Organization
    Organization=organization
    print("Organization of the collection is", Organization)

#organization selector dropdown    
interactive(OrganizationChoices, organization=Organizations)

# %% [markdown]
# #### Choose a collection

# %%
# Create a list of collections in the organization directory selected in the dropdown above
Collections = []
for (dirpath, dirnames, filenames) in walk(os.path.join('../collection',Organization)):
    Collections.extend(dirnames)
    break 
    
# Create a function to select the collection the metadata comes from
def CollectionChoices(collection):
    global CollectionChoice
    global Collection
    Collection=collection 
    
#Create a dropdown using the Collections list and the organization selector function. This sets the Collection variable.    
interactive(CollectionChoices, collection=Collections)

# %% [markdown]
# Many organizations support multiple metadata dialects, and share their collections in more than one dialect. This list is created the same way the others are. It adds the different dialects the collection is shared in to a list.

# %%
# Many organizations support multiple metadata dialects, and share their collections in more than one dialect. 
# This list is created the same way the others are. It lists the different dialects the collection is shared in.
Dialects = []
for (dirpath, dirnames, filenames) in walk(os.path.join('../collection',Organization,Collection)):
    Dialects.extend(dirnames)
    break 
dialectList=Dialects

#Create a function to select the dialect you want to send to the evaluator service.
def dialectChoice(dialect):
    global Dialect
    Dialect=dialect
    print("Dialect of the collection is", Dialect)

# Create a dropdown using the Dialects list and the dialect selector function. This sets the Dialect variable. 
interactive(dialectChoice,dialect=dialectList)

# %% [markdown]
# #### Create the package to send to the Evaluator

# %%
# change to the zip directory 
# %cd ../zip

# Combine the Organization, Collection, and Dialect variables with the string 'xml' as a relative path 
# and save the string to a variable
MetadataDestination=os.path.join(Organization,Collection,Dialect,'xml')

#Use the path to create a directory structure in the zip directory
os.makedirs(MetadataDestination, exist_ok=True)

# Create a path to the metadata you selected earlier and save the string to a variable, 'MetadataLocation'.
MetadataLocation=os.path.join('../collection/',Organization,Collection,Dialect,'xml')

# copy the metadata to the new directory structure.
src_files = os.listdir(MetadataLocation)
for file_name in src_files:
    full_file_name = os.path.join(MetadataLocation, file_name)
    if (os.path.isfile(full_file_name)):
        shutil.copy(full_file_name, MetadataDestination)
        
# Make a zip file to upload to the evaluator service
shutil.make_archive('../upload/metadata', 'zip', os.getcwd())
# Out:
# /Users/scgordon/MILE2/zip
# '/Users/scgordon/MILE2/upload/metadata.zip'

# %% [markdown]
# #### Evaluate metadata
#
# Send metadata to the Evaluator. Get the responses with csv encoding. This step can take up to a minute and doesn't track progress, but a dataframe or an error message will be returned.

# %%
# Switch to upload directory
# %cd ../upload 

# Send metadata package, read the response into a dataframe
url = 'http://metadig.nceas.ucsb.edu/metadata/evaluator'
files = {'zipxml': open('metadata.zip', 'rb')}
r = requests.post(url, files=files, headers={"Accept-Encoding": "gzip"})
r.raise_for_status()
EvaluatedMetadataDF = pd.read_csv(io.StringIO(r.text), quotechar='"')

#build filepaths, directories and file names. Create gzipped archive with collection organization and dialect information
Filedirectory=os.path.join('../data/',Organization)
os.makedirs(Filedirectory, exist_ok=True)
Filename='/'+Collection+'_'+Dialect+'_Evaluated.csv.gz'
SimplfiedFilename='/'+Collection+'_'+Dialect+'_SimplifiedEvaluated.csv.gz'
FilePath=Filedirectory+Filename
SimplifiedFilePath=Filedirectory+SimplfiedFilename
EvaluatedMetadataDF.insert(3, 'Collection', Organization+'_'+Collection+'_'+Dialect)
EvaluatedMetadataDF.to_csv(FilePath, mode = 'w', compression='gzip', index=False)

#Change directories, delete upload directory and zip. Delete copied metadata.
# %cd ../
shutil.rmtree('upload')
# %cd zip
shutil.rmtree(Organization)
# %cd ../data

#Create a simplified XPath output and archive it
EvaluatedSimplifiedMetadataDF = EvaluatedMetadataDF.copy()
EvaluatedSimplifiedMetadataDF['XPath']=EvaluatedSimplifiedMetadataDF['XPath'].str.replace('/gco:CharacterString', '')
EvaluatedSimplifiedMetadataDF['XPath']=EvaluatedSimplifiedMetadataDF['XPath'].str.replace('/[a-z]+:+?', '/')
EvaluatedSimplifiedMetadataDF['XPath']=EvaluatedSimplifiedMetadataDF['XPath'].str.replace('/[A-Z]+_[A-Za-z]+/?', '/')
EvaluatedSimplifiedMetadataDF['XPath']=EvaluatedSimplifiedMetadataDF['XPath'].str.replace('//', '/')
EvaluatedSimplifiedMetadataDF['XPath']=EvaluatedSimplifiedMetadataDF['XPath'].str.rstrip('//')
EvaluatedSimplifiedMetadataDF.to_csv(SimplifiedFilePath, mode = 'w', compression='gzip', index=False)
EvaluatedSimplifiedMetadataDF
# Out:
# /Users/scgordon/MILE2/upload
# /Users/scgordon/MILE2
# /Users/scgordon/MILE2/zip
# /Users/scgordon/MILE2/data
#                          Concept                                            Content                                             Record        Collection  \
# 0                       Abstract  These are measurements of Active Layer Thickne...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 1                Acknowledgement                                      Susan Hubbard  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 2                         Author                 John Peterson (JEPeterson@lbl.gov)  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 3            Author / Originator                 John Peterson (JEPeterson@lbl.gov)  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 4                   Bounding Box        -156.670518 -156.401514 71.324601 71.260956  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 5               Contributor Name                                      Susan Hubbard  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 6           Distribution Contact  Data Center Support Next-Generation Ecosystem ...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 7          Easternmost Longitude                                        -156.401514  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 8                        Keyword                     moisture content of soil layer  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 9                        Keyword                                   Intensive Site 1  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 10                  Keyword Type                                       active layer  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 11            Keyword Vocabulary                                       active layer  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 12             Lineage Statement  field These active layer thickness measurement...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 13                   Maintenance                                          as needed  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 14              Metadata Contact  John Peterson Lawrence Berkeley National Labor...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 15             Metadata Language  FDGC Content Standard for Digital Geospatial M...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 16        Metadata Modified Date                                           20150507  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 17    Metadata Standard Citation  FDGC Content Standard for Digital Geospatial M...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 18     Metadata Standard Version                                  FDGC-STD-001-1998  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 19         Northernmost Latitude                                          71.324601  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 20             Organization Name                 John Peterson (JEPeterson@lbl.gov)  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 21      Originating Organization                 John Peterson (JEPeterson@lbl.gov)  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 22                         Phone                                            Unknown  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 23                         Phone                                       510-590-2917  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 24                 Place Keyword                                   Intensive Site 1  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 25             Presentation Form                         In situ Field Measurements  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 26      Process Step Description  These active layer thickness measurements are ...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 27             Process Step Time                                           20110925  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 28          Project Website Link                  http://dx.doi.org/10.5440/1177857  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# 29          Project Website Link  ftp://ngee.ornl.gov/data/outgoing/site_charact...  ftp___ngee.ornl.gov_data_outgoing_metadata_Act...  DataONE_KUBI_EML
# ...                          ...                                                ...                                                ...               ...
# 6217                     Unknown                                          Fairbanks  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6218                     Unknown                                             Alaska  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6219                     Unknown                                              99775  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6220                     Unknown                                                USA  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6221                     Unknown                                    +1-907-474-2444  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6222                     Unknown                                giwahana@alaska.edu  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6223                     Unknown                               mailing and physical  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6224                     Unknown  There were data gaps in mid-August at the Meth...  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6225                     Unknown                                              field  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6226                     Unknown                                Data Center Support  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6227                     Unknown  Next-Generation Ecosystem Experiments (NGEE) A...  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6228                     Unknown                               mailing and physical  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6229                     Unknown                               1 Bethel Valley Road  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6230                     Unknown                                          Oak Ridge  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6231                     Unknown                                                 TN  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6232                     Unknown                                         37831-6290  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6233                     Unknown                                                USA  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6234                     Unknown                              support@ngee.ornl.gov  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6235                     Unknown                                         Go Iwahana  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6236                     Unknown                     University of Alaska Fairbanks  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6237                     Unknown                               mailing and physical  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6238                     Unknown                         930 Koyukuk Dr. IARC / UAF  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6239                     Unknown                                          Fairbanks  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6240                     Unknown                                             Alaska  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6241                     Unknown                                              99775  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6242                     Unknown                                                 US  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6243                     Unknown                                giwahana@alaska.edu  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6244                     Unknown  Information about cameras' locations and heigh...  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6245                     Unknown                                           approved  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
# 6246                     Unknown                                                  S  ftp___ngee.ornl.gov_data_outgoing_metadata_Tim...  DataONE_KUBI_EML
#
#                                                   XPath
# 0                    /metadata/idinfo/descript/abstract
# 1                             /metadata/idinfo/datacred
# 2             /metadata/idinfo/citation/citeinfo/origin
# 3             /metadata/idinfo/citation/citeinfo/origin
# 4                       /metadata/idinfo/spdom/bounding
# 5                             /metadata/idinfo/datacred
# 6                    /metadata/distinfo/distrib/cntinfo
# 7                /metadata/idinfo/spdom/bounding/eastbc
# 8              /metadata/idinfo/keywords/theme/themekey
# 9              /metadata/idinfo/keywords/place/placekey
# 10              /metadata/idinfo/keywords/theme/themekt
# 11              /metadata/idinfo/keywords/theme/themekt
# 12                           /metadata/dataqual/lineage
# 13                       /metadata/idinfo/status/update
# 14                      /metadata/metainfo/metc/cntinfo
# 15                           /metadata/metainfo/metstdn
# 16                              /metadata/metainfo/metd
# 17                           /metadata/metainfo/metstdn
# 18                           /metadata/metainfo/metstdv
# 19              /metadata/idinfo/spdom/bounding/northbc
# 20            /metadata/idinfo/citation/citeinfo/origin
# 21            /metadata/idinfo/citation/citeinfo/origin
# 22          /metadata/distinfo/distrib/cntinfo/cntvoice
# 23             /metadata/metainfo/metc/cntinfo/cntvoice
# 24             /metadata/idinfo/keywords/place/placekey
# 25           /metadata/idinfo/citation/citeinfo/geoform
# 26         /metadata/dataqual/lineage/procstep/procdesc
# 27         /metadata/dataqual/lineage/procstep/procdate
# 28            /metadata/idinfo/citation/citeinfo/onlink
# 29            /metadata/idinfo/citation/citeinfo/onlink
# ...                                                 ...
# 6217     /metadata/idinfo/ptcontac/cntinfo/cntaddr/city
# 6218    /metadata/idinfo/ptcontac/cntinfo/cntaddr/state
# 6219   /metadata/idinfo/ptcontac/cntinfo/cntaddr/postal
# 6220  /metadata/idinfo/ptcontac/cntinfo/cntaddr/country
# 6221         /metadata/idinfo/ptcontac/cntinfo/cntvoice
# 6222         /metadata/idinfo/ptcontac/cntinfo/cntemail
# 6223  /metadata/idinfo/tool/toolcont/cntinfo/cntaddr...
# 6224                        /metadata/dataqual/complete
# 6225         /metadata/dataqual/lineage/method/methtype
# 6226  /metadata/distinfo/distrib/cntinfo/cntperp/cntper
# 6227  /metadata/distinfo/distrib/cntinfo/cntperp/cntorg
# 6228  /metadata/distinfo/distrib/cntinfo/cntaddr/add...
# 6229  /metadata/distinfo/distrib/cntinfo/cntaddr/add...
# 6230    /metadata/distinfo/distrib/cntinfo/cntaddr/city
# 6231   /metadata/distinfo/distrib/cntinfo/cntaddr/state
# 6232  /metadata/distinfo/distrib/cntinfo/cntaddr/postal
# 6233  /metadata/distinfo/distrib/cntinfo/cntaddr/cou...
# 6234        /metadata/distinfo/distrib/cntinfo/cntemail
# 6235     /metadata/metainfo/metc/cntinfo/cntperp/cntper
# 6236     /metadata/metainfo/metc/cntinfo/cntperp/cntorg
# 6237   /metadata/metainfo/metc/cntinfo/cntaddr/addrtype
# 6238    /metadata/metainfo/metc/cntinfo/cntaddr/address
# 6239       /metadata/metainfo/metc/cntinfo/cntaddr/city
# 6240      /metadata/metainfo/metc/cntinfo/cntaddr/state
# 6241     /metadata/metainfo/metc/cntinfo/cntaddr/postal
# 6242    /metadata/metainfo/metc/cntinfo/cntaddr/country
# 6243           /metadata/metainfo/metc/cntinfo/cntemail
# 6244                              /metadata/ome/datause
# 6245                           /metadata/ome/ome_status
# 6246                             /metadata/ome/taskname
#
# [6247 rows x 5 columns]

# %% [markdown]
# ### Select the notebook that prepares the data for different types of analysis
#
# * [Create RAD Data](02RADdf.ipynb)
# * [Cross Collection Comparisons](03CrossCollectionComparisons.ipynb)
# * [Concept Content Consistency](04ConceptVerticals.ipynb)
# * [Exploring Unknown Concepts](05ExploringUnknownConcepts.ipynb)
# * [Adding Quality tests](05ExploringUnknownConcepts.ipynb)
