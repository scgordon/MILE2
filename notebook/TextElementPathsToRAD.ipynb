# %% [markdown]
# ##  This notebook allows the user to choose a collection of XML, run a XSL transform using Saxon and Java through BASH, import the resultant CSV and use Python to determine what concepts are present, which records are missing what content which elements are undefined and what the metadata vertical for each undefined element is.
#
# ### The intent here is to create a python framework that allows new collections of xml (would LOVE to read in json and fits) to be added to a directory structure via direct upload or entering url(s) then analyzing the collections, allowing the workflow to be initiated with dropdowns and text boxes and returning the visualizations that characterize collection completeness.
#
# ### This allows us to use what we know to expose what we don't have defined conceptually for a dialect as well as what we know about that element's content. With these results and a room full of 'native speakers of each dialect, it should be possible to accelerate the pace to which we would be able to arrive at a point when we can translate 100% into every public earth science and library science dialect, we can provide a container for the data that should be understandable by all of the communities in play. We can even go further, creating space in the container for the notebooks, code, libraries, etc that the provenance references so that the environment the science was created in can be replicated and reproduce the results or open them to scrutiny. (okay maybe leave that last part out...)
#
# ### Perhaps the biggest advantage this approach has over a Docker instance is that it can be objectized and then parts can be pulled out as needed or performed online to provide the output a scientist needs.

# %% [markdown]
# ### Read in a csv that the user selects by selecting the organization and collection.

# %%
import pandas as pd
import os
from os import walk
import numpy as np
from ipykernel import kernelapp as app
from __future__ import print_function
from ipywidgets import *
import ipywidgets as widgets
from bokeh.charts import output_notebook, output_file, show, Bar, Scatter, Histogram, TimeSeries
from bokeh.plotting import figure
from bokeh.models import Range1d, HoverTool, ResizeTool
from bokeh.charts import defaults
from bokeh.models import Legend
defaults.width = 1200
defaults.height = 800
output_notebook()
#from ipywidgets import Button, Layout
#from glob import glob
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f1eda693-0e45-4c69-b6be-a4bf8a1c2e08">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### query the directory for subdirectory names, return them in a list.

# %%
Organizations = []
for (dirpath, dirnames, filenames) in walk('/Users/scgordon/ConceptMining/data/'):
    Organizations.extend(dirnames)
    break
Organizations
# Out:
# ['BCO-DMO',
#  'DataOne',
#  'IEDA',
#  'LTERthroughTime',
#  'NASA',
#  'NCAR',
#  'ORNL',
#  'USGS']

# %% [markdown]
# ### Create a function to populate a variable used to populate the list for the collection dropdown

# %%
def OrganizationChoices(Organization):
    global OrganizationChoice
    global Collections
    OrganizationChoice=os.path.join('/Users/scgordon/ConceptMining/data',Organization)
    Collections=os.listdir(OrganizationChoice)

# %% [markdown]
# ### Choose the organization you want to look at by creating a dropdown with the function that identifies the organizations that have data.

# %%
interactive(OrganizationChoices, Organization=Organizations)

# %% [markdown]
# ### Function that reads the selected csv into a dataframe

# %%
def CollectionChoices(Collection):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(OrganizationChoice, Collection))
    return CollectionConceptsDF

# %% [markdown]
# ### Choose the CSV you want to examine

# %%
interactive(CollectionChoices, Collection=Collections)
# Out:
#       Collection Dialect         Record  \
# 0           GHRC     ISO     lohrac.xml
# 1           GHRC     ISO     lohrac.xml
# 2           GHRC     ISO     lohrac.xml
# 3           GHRC     ISO     lohrac.xml
# 4           GHRC     ISO     lohrac.xml
# 5           GHRC     ISO     lohrac.xml
# 6           GHRC     ISO     lohrac.xml
# 7           GHRC     ISO     lohrac.xml
# 8           GHRC     ISO     lohrac.xml
# 9           GHRC     ISO     lohrac.xml
# 10          GHRC     ISO     lohrac.xml
# 11          GHRC     ISO     lohrac.xml
# 12          GHRC     ISO     lohrac.xml
# 13          GHRC     ISO     lohrac.xml
# 14          GHRC     ISO     lohrac.xml
# 15          GHRC     ISO     lohrac.xml
# 16          GHRC     ISO     lohrac.xml
# 17          GHRC     ISO     lohrac.xml
# 18          GHRC     ISO     lohrac.xml
# 19          GHRC     ISO     lohrac.xml
# 20          GHRC     ISO     lohrac.xml
# 21          GHRC     ISO     lohrac.xml
# 22          GHRC     ISO     lohrac.xml
# 23          GHRC     ISO     lohrac.xml
# 24          GHRC     ISO     lohrac.xml
# 25          GHRC     ISO     lohrac.xml
# 26          GHRC     ISO     lohrac.xml
# 27          GHRC     ISO     lohrac.xml
# 28          GHRC     ISO     lohrac.xml
# 29          GHRC     ISO     lohrac.xml
# ...          ...     ...            ...
# 43740       GHRC     ISO  rssmif17w.xml
# 43741       GHRC     ISO  rssmif17w.xml
# 43742       GHRC     ISO  rssmif17w.xml
# 43743       GHRC     ISO  rssmif17w.xml
# 43744       GHRC     ISO  rssmif17w.xml
# 43745       GHRC     ISO  rssmif17w.xml
# 43746       GHRC     ISO  rssmif17w.xml
# 43747       GHRC     ISO  rssmif17w.xml
# 43748       GHRC     ISO  rssmif17w.xml
# 43749       GHRC     ISO  rssmif17w.xml
# 43750       GHRC     ISO  rssmif17w.xml
# 43751       GHRC     ISO  rssmif17w.xml
# 43752       GHRC     ISO  rssmif17w.xml
# 43753       GHRC     ISO  rssmif17w.xml
# 43754       GHRC     ISO  rssmif17w.xml
# 43755       GHRC     ISO  rssmif17w.xml
# 43756       GHRC     ISO  rssmif17w.xml
# 43757       GHRC     ISO  rssmif17w.xml
# 43758       GHRC     ISO  rssmif17w.xml
# 43759       GHRC     ISO  rssmif17w.xml
# 43760       GHRC     ISO  rssmif17w.xml
# 43761       GHRC     ISO  rssmif17w.xml
# 43762       GHRC     ISO  rssmif17w.xml
# 43763       GHRC     ISO  rssmif17w.xml
# 43764       GHRC     ISO  rssmif17w.xml
# 43765       GHRC     ISO  rssmif17w.xml
# 43766       GHRC     ISO  rssmif17w.xml
# 43767       GHRC     ISO  rssmif17w.xml
# 43768       GHRC     ISO  rssmif17w.xml
# 43769       GHRC     ISO  rssmif17w.xml
#
#                                             Concept  \
# 0                                          Abstract
# 1      Additional Attributes - Descriptive Keywords
# 2      Additional Attributes - Descriptive Keywords
# 3      Additional Attributes - Descriptive Keywords
# 4      Additional Attributes - Descriptive Keywords
# 5      Additional Attributes - Descriptive Keywords
# 6      Additional Attributes - Descriptive Keywords
# 7      Additional Attributes - Descriptive Keywords
# 8      Additional Attributes - Descriptive Keywords
# 9      Additional Attributes - Descriptive Keywords
# 10                                          Address
# 11                                          Address
# 12                                Ancillary Keyword
# 13                                Ancillary Keyword
# 14                                Ancillary Keyword
# 15                                Ancillary Keyword
# 16                                Ancillary Keyword
# 17                                Ancillary Keyword
# 18                                Ancillary Keyword
# 19                                Ancillary Keyword
# 20                                Ancillary Keyword
# 21                                     Bounding Box
# 22                                     Bounding Box
# 23                                     Bounding Box
# 24                                     Bounding Box
# 25                                     Bounding Box
# 26                                     Bounding Box
# 27                                     Bounding Box
# 28                                     Bounding Box
# 29                               Browse Description
# ...                                             ...
# 43740                                           URL
# 43741                                           URL
# 43742                                           URL
# 43743                                           URL
# 43744                                           URL
# 43745                                           URL
# 43746                                           URL
# 43747                                           URL
# 43748                                           URL
# 43749                                           URL
# 43750                                           URL
# 43751                                           URL
# 43752                                           URL
# 43753                                           URL
# 43754                                           URL
# 43755                                           URL
# 43756                                           URL
# 43757                                      Web Page
# 43758                                      Web Page
# 43759                                      Web Page
# 43760                                      Web Page
# 43761                                      Web Page
# 43762                                      Web Page
# 43763                                      Web Page
# 43764                                      Web Page
# 43765                                      Web Page
# 43766                                      Web Page
# 43767                                      Web Page
# 43768                                      Web Page
# 43769                         Westernmost Longitude
#
#                                                    XPath  \
# 0            /*/gmd:identificationInfo/*/gmd:abstract//*
# 1      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 2      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 3      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 4      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 5      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 6      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 7      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 8      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 9      /gmi:MI_Metadata/gmd:identificationInfo/*/gmd:...
# 10     //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 11     //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 12     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 13     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 14     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 15     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 16     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 17     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 18     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 19     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 20     /*/gmd:identificationInfo/*/gmd:descriptiveKey...
# 21     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 22     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 23     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 24     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 25     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 26     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 27     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 28     /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
# 29     /*/gmd:identificationInfo/*/gmd:graphicOvervie...
# ...                                                  ...
# 43740        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43741        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43742        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43743        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43744        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43745        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43746        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43747        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43748        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43749        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43750        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43751        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43752        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43753        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43754        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43755        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43756        //gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 43757  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43758  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43759  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43760  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43761  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43762  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43763  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43764  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43765  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43766  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43767  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43768  //gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:...
# 43769  /*/gmd:identificationInfo/*/gmd:extent/gmd:EX_...
#
#                                                  Content
# 0      The product is a 0.5 deg x 0.5 deg gridded com...
# 1      EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC ELECTRICI...
# 2                                                 GLOBAL
# 3                                                 ANNUAL
# 4                                                   GHRC
# 5                                                   TRMM
# 6                                MICROLAB-1 > MICROLAB-1
# 7                                            TRMM > TRMM
# 8                                                    OTD
# 9                                                    LIS
# 10     NASA Global Change Master Directory, Goddard S...
# 11     NASA Global Change Master Directory, Goddard S...
# 12     EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC ELECTRICI...
# 13                                                GLOBAL
# 14                                                ANNUAL
# 15                                                  GHRC
# 16                                                  TRMM
# 17                               MICROLAB-1 > MICROLAB-1
# 18                                           TRMM > TRMM
# 19                                                   OTD
# 20                                                   LIS
# 21                                                  -180
# 22                                                  -180
# 23                                                   180
# 24                                                   180
# 25                                                   -90
# 26                                                   -90
# 27                                                    90
# 28                                                    90
# 29                                                   NaN
# ...                                                  ...
# 43740             http://gcmd.nasa.gov/Resources/valids/
# 43741  http://gcmd.nasa.gov/MailComments/MailComments...
# 43742             http://gcmd.nasa.gov/Resources/valids/
# 43743  ftp://ghrc.nsstc.nasa.gov/pub/ssmis/f17/weekly...
# 43744  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43745  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43746  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43747  ftp://ghrc.nsstc.nasa.gov/pub/ssmis/f17/weekly...
# 43748  http://ghrc.nsstc.nasa.gov/uso/ds_docs/ssmi_ne...
# 43749  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43750  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43751  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43752  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43753  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43754  http://ghrc.nsstc.nasa.gov/opendap/ssmis/f17/w...
# 43755  http://dx.doi.org/10.5067/MEASURES/DMSP-F17/SS...
# 43756       http://ghrc.nsstc.nasa.gov/uso/citation.html
# 43757  http://gcmd.nasa.gov/MailComments/MailComments...
# 43758  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43759  http://gcmd.nasa.gov/index.html http web brows...
# 43760  http://gcmd.nasa.gov/Resources/valids/ http we...
# 43761  http://gcmd.nasa.gov/MailComments/MailComments...
# 43762  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43763  http://gcmd.nasa.gov/MailComments/MailComments...
# 43764  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43765  http://gcmd.nasa.gov/MailComments/MailComments...
# 43766  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43767  http://gcmd.nasa.gov/MailComments/MailComments...
# 43768  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43769                                               -180
#
# [43770 rows x 6 columns]

# %% [markdown]
# ### We don't really need to know the organization and dialect after we have selected the organization and collection. The xpaths aren't needed as they are the xpaths that were looked for and in many cases are relative rather than the actual location within the record itself. Let's get rid of the columns we don't need.

# %%
CollectionConceptsDF.drop(['Collection','Dialect', 'XPath'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#               Record                                       Concept  \
# 0         lohrac.xml                                      Abstract
# 1         lohrac.xml  Additional Attributes - Descriptive Keywords
# 2         lohrac.xml  Additional Attributes - Descriptive Keywords
# 3         lohrac.xml  Additional Attributes - Descriptive Keywords
# 4         lohrac.xml  Additional Attributes - Descriptive Keywords
# 5         lohrac.xml  Additional Attributes - Descriptive Keywords
# 6         lohrac.xml  Additional Attributes - Descriptive Keywords
# 7         lohrac.xml  Additional Attributes - Descriptive Keywords
# 8         lohrac.xml  Additional Attributes - Descriptive Keywords
# 9         lohrac.xml  Additional Attributes - Descriptive Keywords
# 10        lohrac.xml                                       Address
# 11        lohrac.xml                                       Address
# 12        lohrac.xml                             Ancillary Keyword
# 13        lohrac.xml                             Ancillary Keyword
# 14        lohrac.xml                             Ancillary Keyword
# 15        lohrac.xml                             Ancillary Keyword
# 16        lohrac.xml                             Ancillary Keyword
# 17        lohrac.xml                             Ancillary Keyword
# 18        lohrac.xml                             Ancillary Keyword
# 19        lohrac.xml                             Ancillary Keyword
# 20        lohrac.xml                             Ancillary Keyword
# 21        lohrac.xml                                  Bounding Box
# 22        lohrac.xml                                  Bounding Box
# 23        lohrac.xml                                  Bounding Box
# 24        lohrac.xml                                  Bounding Box
# 25        lohrac.xml                                  Bounding Box
# 26        lohrac.xml                                  Bounding Box
# 27        lohrac.xml                                  Bounding Box
# 28        lohrac.xml                                  Bounding Box
# 29        lohrac.xml                            Browse Description
# ...              ...                                           ...
# 43740  rssmif17w.xml                                           URL
# 43741  rssmif17w.xml                                           URL
# 43742  rssmif17w.xml                                           URL
# 43743  rssmif17w.xml                                           URL
# 43744  rssmif17w.xml                                           URL
# 43745  rssmif17w.xml                                           URL
# 43746  rssmif17w.xml                                           URL
# 43747  rssmif17w.xml                                           URL
# 43748  rssmif17w.xml                                           URL
# 43749  rssmif17w.xml                                           URL
# 43750  rssmif17w.xml                                           URL
# 43751  rssmif17w.xml                                           URL
# 43752  rssmif17w.xml                                           URL
# 43753  rssmif17w.xml                                           URL
# 43754  rssmif17w.xml                                           URL
# 43755  rssmif17w.xml                                           URL
# 43756  rssmif17w.xml                                           URL
# 43757  rssmif17w.xml                                      Web Page
# 43758  rssmif17w.xml                                      Web Page
# 43759  rssmif17w.xml                                      Web Page
# 43760  rssmif17w.xml                                      Web Page
# 43761  rssmif17w.xml                                      Web Page
# 43762  rssmif17w.xml                                      Web Page
# 43763  rssmif17w.xml                                      Web Page
# 43764  rssmif17w.xml                                      Web Page
# 43765  rssmif17w.xml                                      Web Page
# 43766  rssmif17w.xml                                      Web Page
# 43767  rssmif17w.xml                                      Web Page
# 43768  rssmif17w.xml                                      Web Page
# 43769  rssmif17w.xml                         Westernmost Longitude
#
#                                                  Content
# 0      The product is a 0.5 deg x 0.5 deg gridded com...
# 1      EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC ELECTRICI...
# 2                                                 GLOBAL
# 3                                                 ANNUAL
# 4                                                   GHRC
# 5                                                   TRMM
# 6                                MICROLAB-1 > MICROLAB-1
# 7                                            TRMM > TRMM
# 8                                                    OTD
# 9                                                    LIS
# 10     NASA Global Change Master Directory, Goddard S...
# 11     NASA Global Change Master Directory, Goddard S...
# 12     EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC ELECTRICI...
# 13                                                GLOBAL
# 14                                                ANNUAL
# 15                                                  GHRC
# 16                                                  TRMM
# 17                               MICROLAB-1 > MICROLAB-1
# 18                                           TRMM > TRMM
# 19                                                   OTD
# 20                                                   LIS
# 21                                                  -180
# 22                                                  -180
# 23                                                   180
# 24                                                   180
# 25                                                   -90
# 26                                                   -90
# 27                                                    90
# 28                                                    90
# 29                                                   NaN
# ...                                                  ...
# 43740             http://gcmd.nasa.gov/Resources/valids/
# 43741  http://gcmd.nasa.gov/MailComments/MailComments...
# 43742             http://gcmd.nasa.gov/Resources/valids/
# 43743  ftp://ghrc.nsstc.nasa.gov/pub/ssmis/f17/weekly...
# 43744  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43745  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43746  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43747  ftp://ghrc.nsstc.nasa.gov/pub/ssmis/f17/weekly...
# 43748  http://ghrc.nsstc.nasa.gov/uso/ds_docs/ssmi_ne...
# 43749  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43750  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43751  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43752  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43753  ftp://ghrc.nsstc.nasa.gov/pub/doc/ssmi_netcdf/...
# 43754  http://ghrc.nsstc.nasa.gov/opendap/ssmis/f17/w...
# 43755  http://dx.doi.org/10.5067/MEASURES/DMSP-F17/SS...
# 43756       http://ghrc.nsstc.nasa.gov/uso/citation.html
# 43757  http://gcmd.nasa.gov/MailComments/MailComments...
# 43758  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43759  http://gcmd.nasa.gov/index.html http web brows...
# 43760  http://gcmd.nasa.gov/Resources/valids/ http we...
# 43761  http://gcmd.nasa.gov/MailComments/MailComments...
# 43762  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43763  http://gcmd.nasa.gov/MailComments/MailComments...
# 43764  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43765  http://gcmd.nasa.gov/MailComments/MailComments...
# 43766  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43767  http://gcmd.nasa.gov/MailComments/MailComments...
# 43768  http://gcmd.nasa.gov/Resources/valids/ GCMD Ke...
# 43769                                               -180
#
# [43770 rows x 3 columns]

# %% [markdown]
# ### Now that we have the data we want, what are the understood concepts that exist in the collection?

# %%
ConceptVerticals=CollectionConceptsDF.Concept.unique()
Verticals=ConceptVerticals.tolist()
Verticals
# Out:
# ['Abstract',
#  'Additional Attributes - Descriptive Keywords',
#  'Address',
#  'Ancillary Keyword',
#  'Bounding Box',
#  'Browse Description',
#  'Browse File Name',
#  'Browse URL',
#  'Cited Resource Identifier',
#  'Cited Resource Title',
#  'City',
#  'Contact Instructions',
#  'Coordinate Reference System (CRS)',
#  'Country',
#  'Data Dates',
#  'Data Quality Scope',
#  'Distribution Contact',
#  'Easternmost Longitude',
#  'Email',
#  'End Time',
#  'Enumerated Domain Value',
#  'Enumerated Domain Value Definition Source',
#  'Format of the Online Resource',
#  'Geographic Description',
#  'Instrument',
#  'Instrument Keyword',
#  'Instrument Keyword Vocabulary',
#  'Instrument Short Name',
#  'Instrument Type',
#  'Keyword',
#  'Keyword Type',
#  'Keyword Vocabulary',
#  'Keyword Vocabulary Citation',
#  'Metadata Contact',
#  'Metadata Dates',
#  'Metadata Identifier',
#  'Metadata Language',
#  'Metadata Modified Date',
#  'Metadata Standard Citation',
#  'Metadata Standard Version',
#  'Northernmost Latitude',
#  'Online Resource',
#  'Online Resource Description',
#  'Online Resource Name/Title',
#  'Organization Name',
#  'Other Citation Details',
#  'Paleo Temporal Coverage',
#  'Party',
#  'Place Keyword',
#  'Place Keyword Vocabulary',
#  'Platform',
#  'Platform Description',
#  'Platform Keyword',
#  'Platform Keyword Vocabulary',
#  'Platform Long Name',
#  'Platform Short Name',
#  'Position Name',
#  'Postal_Code',
#  'Process Step Description',
#  'Processing Level',
#  'Product Link',
#  'Project Keyword',
#  'Project Name',
#  'Project Website Link',
#  'Province or State',
#  'Publication Date',
#  'Publication Information',
#  'Related Resource Identifier',
#  'Related URL',
#  'Reprocessing Plan Note',
#  'Resource Access Constraints',
#  'Resource Citation',
#  'Resource Contact',
#  'Resource Cost or Fees',
#  'Resource Creation Date',
#  'Resource Creation/Revision Date',
#  'Resource Identifier',
#  'Resource Language',
#  'Resource Lineage',
#  'Resource Long Name',
#  'Resource Revision Date',
#  'Resource Title',
#  'Resource Type',
#  'Resource Use Constraints',
#  'Resource Version',
#  'Resource on-line Link',
#  'Responsibility',
#  'Rights',
#  'Role',
#  'Sensor Short Name',
#  'Southernmost Latitude',
#  'Spatial Extent',
#  'Spatial Representation',
#  'Standard Name Vocabulary',
#  'Start Time',
#  'Temporal Extent',
#  'Temporal Keyword',
#  'Theme Keyword',
#  'URL',
#  'Web Page',
#  'Westernmost Longitude']

# %% [markdown]
# ### Create function that allows us to call up metadata vertical content for a concept

# %%
def ConceptVerticalTable(Concept):
    global VerticalTable
    VerticalTable = CollectionConceptsDF[CollectionConceptsDF.Concept == Concept]
    return VerticalTable

# %% [markdown]
# ### Create a dropdown using the function that allows us to create a dataframe of the concept you want as a metadata vertical.

# %%
interact(ConceptVerticalTable, Concept=Verticals)
# Out:
#                 Record   Concept                   Content
# 66          lohrac.xml  End Time  2012-12-31T23:59:59.000Z
# 983         lohrfc.xml  End Time  2012-12-31T23:59:59.000Z
# 1900        lohrmc.xml  End Time  2012-12-31T23:59:59.000Z
# 2817        lolrac.xml  End Time  2012-12-31T23:59:59.000Z
# 3734      lolracts.xml  End Time  2012-12-31T23:59:59.000Z
# 4651       lolradc.xml  End Time  2012-12-31T23:59:59.000Z
# 5568        lolrdc.xml  End Time  2012-12-31T23:59:59.000Z
# 6485        lolrfc.xml  End Time  2012-12-31T23:59:59.000Z
# 7402       lolrmts.xml  End Time  2012-12-31T23:59:59.000Z
# 8319        lolrts.xml  End Time  2012-12-31T23:59:59.000Z
# 9341         msut2.xml  End Time                       NaN
# 10749      msut2lt.xml  End Time                       NaN
# 12157        msut4.xml  End Time                       NaN
# 13504    rssm1tpwn.xml  End Time                       NaN
# 14618    rssmif08d.xml  End Time  1991-12-31T23:59:59.000Z
# 15531  rssmif08d3d.xml  End Time  1991-12-31T23:59:59.000Z
# 16444    rssmif08m.xml  End Time  1991-12-31T23:59:59.000Z
# 17357    rssmif08w.xml  End Time  1992-01-04T23:59:59.000Z
# 18270    rssmif10d.xml  End Time  1997-11-14T23:59:59.000Z
# 19183  rssmif10d3d.xml  End Time  1997-11-14T23:59:59.000Z
# 20096    rssmif10m.xml  End Time  1997-11-30T23:59:59.000Z
# 21009    rssmif10w.xml  End Time  1997-11-15T23:59:59.000Z
# 21922    rssmif11d.xml  End Time  2000-05-16T23:59:59.000Z
# 22835  rssmif11d3d.xml  End Time  2000-05-16T23:59:59.000Z
# 23748    rssmif11m.xml  End Time  2000-05-31T23:59:59.000Z
# 24661    rssmif11w.xml  End Time  2000-05-20T23:59:59.000Z
# 25574    rssmif13d.xml  End Time  2009-11-04T23:59:59.000Z
# 26487  rssmif13d3d.xml  End Time  2009-11-04T23:59:59.000Z
# 27400    rssmif13m.xml  End Time  2009-11-30T23:59:59.000Z
# 28313    rssmif13w.xml  End Time  2009-11-07T23:59:59.000Z
# 29226    rssmif14d.xml  End Time  2008-08-08T23:59:59.000Z
# 30139  rssmif14d3d.xml  End Time  2008-08-08T23:59:59.000Z
# 31052    rssmif14m.xml  End Time  2008-08-31T23:59:59.000Z
# 31965    rssmif14w.xml  End Time  2008-08-09T23:59:59.000Z
# 32878    rssmif15d.xml  End Time  2011-12-31T23:59:59.000Z
# 33791  rssmif15d3d.xml  End Time  2011-12-31T23:59:59.000Z
# 34704    rssmif15m.xml  End Time  2011-12-31T23:59:59.000Z
# 35617    rssmif15w.xml  End Time  2011-12-31T23:59:59.000Z
# 36530    rssmif16d.xml  End Time                       NaN
# 37443  rssmif16d3d.xml  End Time                       NaN
# 38356    rssmif16m.xml  End Time                       NaN
# 39269    rssmif16w.xml  End Time                       NaN
# 40182    rssmif17d.xml  End Time                       NaN
# 41095  rssmif17d3d.xml  End Time                       NaN
# 42008    rssmif17m.xml  End Time                       NaN
# 42921    rssmif17w.xml  End Time                       NaN

# %% [markdown]
# ### Let's group the unique values in the content column and count them up.

# %%
VerticalTable.groupby('Content').size()
# Out:
# Content
# 1991-12-31T23:59:59.000Z     3
# 1992-01-04T23:59:59.000Z     1
# 1997-11-14T23:59:59.000Z     2
# 1997-11-15T23:59:59.000Z     1
# 1997-11-30T23:59:59.000Z     1
# 2000-05-16T23:59:59.000Z     2
# 2000-05-20T23:59:59.000Z     1
# 2000-05-31T23:59:59.000Z     1
# 2008-08-08T23:59:59.000Z     2
# 2008-08-09T23:59:59.000Z     1
# 2008-08-31T23:59:59.000Z     1
# 2009-11-04T23:59:59.000Z     2
# 2009-11-07T23:59:59.000Z     1
# 2009-11-30T23:59:59.000Z     1
# 2011-12-31T23:59:59.000Z     4
# 2012-12-31T23:59:59.000Z    10
# dtype: int64

# %% [markdown]
# ### Remove colons from the values so there are no Bokeh Label errors. Use Bokeh to plot a bar chart of the unique values.

# %%
data = VerticalTable.Content.str.replace(':','.')

p = Bar(data, 'Content', title="Vertical Value Occurance Count", legend=False)

output_file("bar.html")

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'bar.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b776881d-8de3-4988-98ef-ec3bb16327db"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b776881d-8de3-4988-98ef-ec3bb16327db").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b776881d-8de3-4988-98ef-ec3bb16327db");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b776881d-8de3-4988-98ef-ec3bb16327db' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8cc744c4-3583-4675-ab7f-fc784bd62742":{"roots":{"references":[{"attributes":{"plot":{"id":"a725d327-d89d-4c58-a9e9-7c5faae63d0f","subtype":"Chart","type":"Plot"}},"id":"6c9c2bbc-79fe-4c31-965d-f2660742304b","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["2000-05-20T23.59.59.000Z"],"chart_index":[{"Content":"2000-05-20T23.59.59.000Z"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"2000-05-20T23.59.59.000Z"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2000-05-20T23.59.59.000Z"],"y":[0.5]}},"id":"7f3d750e-5f63-49ed-8620-4b9fb215d02c","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"a725d327-d89d-4c58-a9e9-7c5faae63d0f","subtype":"Chart","type":"Plot"}},"id":"3684fa50-bf9d-4060-b3f1-b7a99867f120","type":"HelpTool"},{"attributes":{"plot":{"id":"a725d327-d89d-4c58-a9e9-7c5faae63d0f","subtype":"Chart","type":"Plot"}},"id":"66ec305e-a319-4b56-af85-9938c7fea330","type":"ResetTool"},{"attributes":{"data_source":{"id":"7f3d750e-5f63-49ed-8620-4b9fb215d02c","type":"ColumnDataSource"},"glyph":{"id":"5d77a4db-1d67-45c1-9c78-4e9fbac7e7ab","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0ce55ad9-da7b-488a-b02e-5a3d9b71ec08","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a725d327-d89d-4c58-a9e9-7c5faae63d0f","subtype":"Chart","type":"Plot"}},"id":"f399303c-424a-4b4c-893f-34bc3c4fef5e","type":"SaveTool"},{"attributes":{"data_source":{"id":"eca01cf5-8fb6-47c2-8aa2-44037d93e4d5","type":"ColumnDataSource"},"glyph":{"id":"5fec0799-1d3f-4596-a7c8-f89bf2a9449d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a2602757-aed8-4ea8-9816-a0e373c45a2b","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"3e784274-ddf9-4c79-b816-54164c5855d3","type":"BoxAnnotation"},"plot":{"id":"a725d327-d89d-4c58-a9e9-7c5faae63d0f","subtype":"Chart","type":"Plot"}},"id":"f63d0baa-6418-48e8-84aa-6632927b4a51","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["1997-11-15T23.59.59.000Z"],"chart_index":[{"Content":"1997-11-15T23.59.59.000Z"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"1997-11-15T23.59.59.000Z"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1997-11-15T23.59.59.000Z"],"y":[0.5]}},"id":"eca01cf5-8fb6-47c2-8aa2-44037d93e4d5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["2000-05-31T23.59.59.000Z"],"chart_index":[{"Content":"2000-05-31T23.59.59.000Z"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"2000-05-31T23.59.59.000Z"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2000-05-31T23.59.59.000Z"],"y":[0.5]}},"id":"c9b7aaef-c5bc-41be-ac6b-7684d3f21a63","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"881ff426-746c-4b1f-a3ae-012c04b88ce0","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["1992-01-04T23.59.59.000Z"],"chart_index":[{"Content":"1992-01-04T23.59.59.000Z"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"1992-01-04T23.59.59.000Z"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1992-01-04T23.59.59.000Z"],"y":[0.5]}},"id":"dd64bedd-3fec-4c67-aad0-00b3871b79d5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height ...
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: NASA/GCMD Instrument Keywords NASA GCMD User Support Office gcmduso@gcmd.gsfc.nasa.gov http://gcmd.nasa.gov/MailComments/MailComments.jsf?rcpt=gcmduso GCMD Feedback Form Have a Comment for the GCMD? information custodian http://gcmd.nasa.gov/Resources/valids/ GCMD Keywords Page This page describes the NASA GCMD Keywords, how to reference those keywords and provides download instructions. information custodian] [renderer: Chart(id='b15b37c3-01db-4970-8fd6-e8e467d239c6', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: NASA Global Change Master Directory, Goddard Space Flight Center Greenbelt MD 20771 USA gcmduso@gcmd.gsfc.nasa.gov http://gcmd.nasa.gov/Resources/valids/ http web browser NASA Global Change Master Directory (GCMD) Keyword Page This page describes the NASA GCMD Keywords, how to reference those keywords and provides download instructions. download http://gcmd.nasa.gov/MailComments/MailComments.jsf?rcpt=gcmduso] [renderer: Chart(id='c8a9f467-b999-4bdd-a251-b6a56b889b9d', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: 1978-01-01T00:00:00.000Z] [renderer: Chart(id='e84099c3-b624-4813-b4f6-f488d7f113d6', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: 1978-01-01T00:00:00.000Z] [renderer: Chart(id='3e405044-1040-416d-bd88-50ca5a3918c6', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: 1978-01-01T00:00:00.000Z] [renderer: Chart(id='45ae3e5f-c3de-4d33-974e-5470698a04f1', ...)]
