# %% [markdown]
# ##  This notebook allows the user to look at all the content a specific concept contains, collection wide.

# %% [markdown]
# ### Read in a csv that the user selects by selecting the organization and collection.

# %%
import pandas as pd


import os
from os import walk
import fnmatch
from ipywidgets import *
import ipywidgets as widgets
from bokeh.charts import output_notebook, show, Bar
from bokeh.plotting import figure
from bokeh.models import Range1d, HoverTool, ResizeTool
from bokeh.charts import defaults
from bokeh.models import Legend
pd.options.display.max_colwidth=200
defaults.width = 1800
defaults.height = 1000
output_notebook()
#from ipywidgets import Button, Layout
#from glob import glob
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9bb0856a-1b9c-4247-a508-898eb6e2ff59">Loading BokehJS ...</span>
#     </div>

# %%
#subprocess()

# %% [markdown]
# ### query the directory for data files

# %%
DataFiles=[]
for path, subdirectories, filenames in os.walk('../data/'):
    for filename in filenames:
        if fnmatch.fnmatch(filename, '*.csv'):
            DataFiles.append(os.path.join(path,filename).split("../data/", 1)[-1])
DataFiles
# Out:
# ['data.csv',
#  'BCO-DMO/GeoTraces_ISO_data.csv',
#  'DataONE/CDL_CSDGM_data.csv',
#  'DataONE/CLOEBIRD_EML_data.csv',
#  'DataONE/Dryad_Dryad_data.csv',
#  'DataONE/EDACGSTORE_CSDGM_data.csv',
#  'DataONE/EDORA_Mercury_data.csv',
#  'DataONE/ESA_EML_data.csv',
#  'DataONE/GLEON_EML_data.csv',
#  'DataONE/GOA_EML_data.csv',
#  'DataONE/IARC_Onedcx_data.csv',
#  'DataONE/IOE_EML_data.csv',
#  'DataONE/KNB_EML_data.csv',
#  'DataONE/KUBI_EML_data.csv',
#  'DataONE/LTER_EML_data.csv',
#  'DataONE/LTER_EUROPE_EML_data.csv',
#  'DataONE/NMEPSCOR_CSDGM_data.csv',
#  'DataONE/ONEShare_EML_data.csv',
#  'DataONE/ORNLDAAC_Mercury_data.csv',
#  'DataONE/PISCO_EML_data.csv',
#  'DataONE/RGD_Mercury_data.csv',
#  'DataONE/SANPARKS_EML_data.csv',
#  'DataONE/SEAD_CSDGM_data.csv',
#  'DataONE/TERN_EML_data.csv',
#  'DataONE/TFRI_EML_data.csv',
#  'DataONE/US_MPC_Onedcx_data.csv',
#  'DataONE/USANPN_EML_data.csv',
#  'DataONE/USGSCSAS_BDP_data.csv',
#  'DataONE/USGSCSAS_CSDGM_data.csv',
#  'IEDA/ECL_DCITE_data.csv',
#  'LTERthroughTime/LTER_2005_EML_data.csv',
#  'LTERthroughTime/LTER_2006_EML_data.csv',
#  'LTERthroughTime/LTER_2007_EML_data.csv',
#  'LTERthroughTime/LTER_2008_EML_data.csv',
#  'LTERthroughTime/LTER_2009_EML_data.csv',
#  'LTERthroughTime/LTER_2010_EML_data.csv',
#  'LTERthroughTime/LTER_2011_EML_data.csv',
#  'LTERthroughTime/LTER_2012_EML_data.csv',
#  'LTERthroughTime/LTER_2013_EML_data.csv',
#  'LTERthroughTime/LTER_2014_EML_data.csv',
#  'LTERthroughTime/LTER_2015_EML_data.csv',
#  'LTERthroughTime/LTER_2016_EML_data.csv',
#  'NASA/GES_DISC_DIF_data.csv',
#  'NASA/GHRC_DIF_data.csv',
#  'NASA/GHRC_ISO_data.csv',
#  'NASA/LARC_DIF_data.csv',
#  'NASA/LARC_ISO_data.csv',
#  'NASA/NSIDC_DIF_data.csv',
#  'NASA/NSIDC_ISO_data.csv',
#  'NCAR/IIS_MODS_data.csv',
#  'NCAR/RDA_RDA-CISL_data.csv',
#  'ORNL/DAAC_Mercury_data.csv',
#  'ORNL/NGEE_CSDGM_data.csv',
#  'ORNL/OLI_ISO_data.csv',
#  'ORNL/USGSC_CSDGM_data.csv',
#  'USGS/OldScienceBase_CSDGM_data.csv',
#  'USGS/ScienceBase_CSDGM_data.csv']

# %% [markdown]
# ### Choose the data you want to look at by creating a dropdown with a function that uses the list of files

# %% [markdown]
# ### Function that reads the selected csv into a dataframe

# %%
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join('../data', DataFile))
    return CollectionConceptsDF

# %% [markdown]
# ### Choose the CSV you want to examine

# %%
interactive(DataChoices, DataFile=DataFiles)
# Out:
#       Collection Dialect            Record                      Concept  \
# 0      GeoTraces     ISO  dataset_3687.xml                      Unknown
# 1      GeoTraces     ISO  dataset_3687.xml          Metadata Identifier
# 2      GeoTraces     ISO  dataset_3687.xml            Metadata Language
# 3      GeoTraces     ISO  dataset_3687.xml                      Unknown
# 4      GeoTraces     ISO  dataset_3687.xml                      Unknown
# 5      GeoTraces     ISO  dataset_3687.xml                      Unknown
# 6      GeoTraces     ISO  dataset_3687.xml                Resource Type
# 7      GeoTraces     ISO  dataset_3687.xml                      Unknown
# 8      GeoTraces     ISO  dataset_3687.xml             Metadata Contact
# 9      GeoTraces     ISO  dataset_3687.xml       Metadata Modified Date
# 10     GeoTraces     ISO  dataset_3687.xml               Metadata Dates
# 11     GeoTraces     ISO  dataset_3687.xml   Metadata Standard Citation
# 12     GeoTraces     ISO  dataset_3687.xml    Metadata Standard Version
# 13     GeoTraces     ISO  dataset_3687.xml                      Unknown
# 14     GeoTraces     ISO  dataset_3687.xml                      Unknown
# 15     GeoTraces     ISO  dataset_3687.xml      Publication Information
# 16     GeoTraces     ISO  dataset_3687.xml                     Abstract
# 17     GeoTraces     ISO  dataset_3687.xml              Acknowledgement
# 18     GeoTraces     ISO  dataset_3687.xml              Acknowledgement
# 19     GeoTraces     ISO  dataset_3687.xml              Resource Status
# 20     GeoTraces     ISO  dataset_3687.xml             Resource Contact
# 21     GeoTraces     ISO  dataset_3687.xml    Resource Update Frequency
# 22     GeoTraces     ISO  dataset_3687.xml                      Unknown
# 23     GeoTraces     ISO  dataset_3687.xml                Theme Keyword
# 24     GeoTraces     ISO  dataset_3687.xml                      Keyword
# 25     GeoTraces     ISO  dataset_3687.xml                Theme Keyword
# 26     GeoTraces     ISO  dataset_3687.xml                      Keyword
# 27     GeoTraces     ISO  dataset_3687.xml                Theme Keyword
# 28     GeoTraces     ISO  dataset_3687.xml                      Keyword
# 29     GeoTraces     ISO  dataset_3687.xml                Theme Keyword
# ...          ...     ...               ...                          ...
# 58769  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58770  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58771  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58772  GeoTraces     ISO  dataset_3826.xml         Cited Resource Title
# 58773  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58774  GeoTraces     ISO  dataset_3826.xml               Responsibility
# 58775  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58776  GeoTraces     ISO  dataset_3826.xml  Related Resource Identifier
# 58777  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58778  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58779  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58780  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58781  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58782  GeoTraces     ISO  dataset_3826.xml         Cited Resource Title
# 58783  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58784  GeoTraces     ISO  dataset_3826.xml         Cited Resource Title
# 58785  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58786  GeoTraces     ISO  dataset_3826.xml         Cited Resource Title
# 58787  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58788  GeoTraces     ISO  dataset_3826.xml          Platform Short Name
# 58789  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58790  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58791  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58792  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58793  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58794  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58795  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58796  GeoTraces     ISO  dataset_3826.xml         Cited Resource Title
# 58797  GeoTraces     ISO  dataset_3826.xml                      Unknown
# 58798  GeoTraces     ISO  dataset_3826.xml               Responsibility
#
#                                                                                                                                                                                                        Content  \
# 0                                                                                                                  http://www.isotc211.org/2005/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd
# 1                                                                                                                                                                       http://lod.bco-dmo.org/id/dataset/3687
# 2                                                                                                                                                                                                     eng; USA
# 3                                                                                                                                                                                                         utf8
# 4                                                                                                                         http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_CharacterSetCode
# 5                                                                                                                                                                                                         utf8
# 6                                                                                                                                                                                                      dataset
# 7                                                                                  Highest level of data collection, from a common set of sensors or instrumentation, usually within the same research project
# 8      Biological and Chemical Oceanography Data Management Office (BCO-DMO) Unavailable 508-289-2009 WHOI MS#36 Woods Hole MA 02543 USA info@bco-dmo.org http://www.bco-dmo.org Monday - Friday 8:00am - 5...
# 9                                                                                                                                                                                                   2012-08-01
# 10                                                                                                                                                                                                  2012-08-01
# 11                                                                                                             ISO 19115-2 Geographic Information - Metadata - Part 2: Extensions for Imagery and Gridded Data
# 12                                                                                                                                                                                         ISO 19115-2:2009(E)
# 13                                                                                                                                     https://www.ngdc.noaa.gov/docucomp/895cc120-95ed-11e0-aa80-0800200c9a66
# 14                                                                                                                                                                                     WGS 84 / World Mercator
# 15     GT11 - CTD - GT-C Bottle from the U.S. GEOTRACES NAT project of the U.S. GEOTRACES program 2013-01-30 publication Dr Edward A. Boyle Massachusetts Institute of Technology principalInvestigator doc...
# 16     CTD - GT-C Bottle Dataset Description: &lt;p&gt;CTD bottle data from GT-C (GEOTRACES Carousel) for GT11 Transect&lt;/p&gt;&lt;p&gt;&amp;nbsp;&lt;/p&gt; Acquisition Description: &lt;p&gt;Refer to &...
# 17                                                       Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926423 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926423
# 18                                                       Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926092 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926092
# 19                                                                                                                                                                                                   completed
# 20            Dr Edward A. Boyle Massachusetts Institute of Technology 617-253-3388 Chemical Oceanography, Trace Metal Group MIT E25-619, 45 Carleton St Cambridge MA 02142 USA eaboyle@mit.edu pointOfContact
# 21                                                                                                                                                                                                    asNeeded
# 22                                                                                                                                                                            Dataset Version: 30 January 2013
# 23                                                                                                                                                                                                 cruise_part
# 24                                                                                                                                                                                                 cruise_part
# 25                                                                                                                                                                                                  dataset_id
# 26                                                                                                                                                                                                  dataset_id
# 27                                                                                                                                                                                                  dataset_id
# 28                                                                                                                                                                                                  dataset_id
# 29                                                                                                                                                                                                     station
# ...                                                                                                                                                                                                        ...
# 58769                                                                                                                                                                                                  unknown
# 58770                                                                                                                         http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 58771                                                                                                                                                                                                completed
# 58772                                                                                                                                                                                                 KN199-04
# 58773                                                                                                                                                                                                  unknown
# 58774                      Dr William J. Jenkins Woods Hole Oceanographic Institution http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/Cruise_Report_for_Knorr_199_Final_v3.pdf Report describing KN199-04
# 58775                                                                                                                                                                                         Cruise: KN204-01
# 58776                                                                                                                                                                                                 KN204-01
# 58777                                                                                               http://www.ngdc.noaa.gov/metadata/published/xsd/schema/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 58778                                                                                                                                                                                                completed
# 58779                                                                                          http://www.ngdc.noaa.gov/metadata/published/xsd/schema/resources/Codelist/gmxCodelists.xml#MI_OperationTypeCode
# 58780                                                                                                                                                                                                     real
# 58781                                                                                                                                                                                             inapplicable
# 58782                                                                                                                                                                                                R/V Knorr
# 58783                                                                                                                                                                                                  unknown
# 58784                                                                                                                                                                           Community Standard Description
# 58785                                                                                                                                                                                                  unknown
# 58786                                                                                                                                                     International Council for the Exploration of the Sea
# 58787                                                                                                                                                                                                  unknown
# 58788                                                                                                                                                                                                R/V Knorr
# 58789                                                                                                                                                                                                   vessel
# 58790                                                                                                                                                             http://lod.bco-dmo.org/id/platform/53994.rdf
# 58791                                                                                                                                                                                                R/V Knorr
# 58792                                                                                                                                                                                                onRequest
# 58793                                                                                                                                                                                                  unknown
# 58794                                                                                                                         http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 58795                                                                                                                                                                                                completed
# 58796                                                                                                                                                                                                 KN204-01
# 58797                                                                                                                                                                                                  unknown
# 58798                                         Dr Edward A. Boyle Massachusetts Institute of Technology http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/STS_Prelim_GT11_Doc.pdf Report describing KN204-01
#
#                                                                                                                                                                                                          XPath  \
# 0                                                                                                                                                                         /gmi:MI_Metadata/@xsi:schemaLocation
# 1                                                                                                                                                                          /gmi:MI_Metadata/gmd:fileIdentifier
# 2                                                                                                                                                                                /gmi:MI_Metadata/gmd:language
# 3                                                                                                                                                    /gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode
# 4                                                                                                                                          /gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode/@codeList
# 5                                                                                                                                     /gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode/@codeListValue
# 6                                                                                                                                                         /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_ScopeCode
# 7                                                                                                                                                  /gmi:MI_Metadata/gmd:hierarchyLevelName/gco:CharacterString
# 8                                                                                                                                                                                 /gmi:MI_Metadata/gmd:contact
# 9                                                                                                                                                                      /gmi:MI_Metadata/gmd:dateStamp/gco:Date
# 10                                                                                                                                                                     /gmi:MI_Metadata/gmd:dateStamp/gco:Date
# 11                                                                                                                                                                   /gmi:MI_Metadata/gmd:metadataStandardName
# 12                                                                                                                                                                /gmi:MI_Metadata/gmd:metadataStandardVersion
# 13                                                                                                                                                        /gmi:MI_Metadata/gmd:referenceSystemInfo/@xlink:href
# 14                                                                                                                                                       /gmi:MI_Metadata/gmd:referenceSystemInfo/@xlink:title
# 15                                                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:citation/gmd:CI_Citation
# 16                                                                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:abstract
# 17                                                                                                                                /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:credit
# 18                                                                                                                                /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:credit
# 19                                                                                                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:status/gmd:MD_ProgressCode
# 20                                                                                                                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:pointOfContact
# 21                   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceAndUpdateFrequency/gmd:MD_MaintenanceFrequencyCode
# 22                                             /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 23                                                                                       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 24                                                                                       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 25                                                                                       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 26                                                                                       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 27                                                                                       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 28                                                                                       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 29                                                                                       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# ...                                                                                                                                                                                                        ...
# 58769                                      /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:instrument/@gco:nilReason
# 58770                                   /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_ProgressCode/@codeList
# 58771                              /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_ProgressCode/@codeListValue
# 58772                                     /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_Citation/gmd:title
# 58773                       /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_Citation/gmd:date/@gco:nilReason
# 58774  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_Citation/gmd:citedResponsibleParty/gmd:CI_Responsi...
# 58775                                                             /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:description/gco:CharacterString
# 58776                                                       /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:identifier/gmd:MD_Identifier/gmd:code
# 58777                                                        /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:status/gmd:MD_ProgressCode/@codeList
# 58778                                                   /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:status/gmd:MD_ProgressCode/@codeListValue
# 58779                                                     /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:type/gmi:MI_OperationTypeCode/@codeList
# 58780                                                /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:type/gmi:MI_OperationTypeCode/@codeListValue
# 58781                                                              /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:parentOperation/@gco:nilReason
# 58782                             /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:citation/gmd:CI_Citation/gmd:title
# 58783               /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:citation/gmd:CI_Citation/gmd:date/@gco:nilReason
# 58784                             /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:citation/gmd:CI_Citation/gmd:title
# 58785               /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:citation/gmd:CI_Citation/gmd:date/@gco:nilReason
# 58786  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifier/gmd:MD_Identifier/gmd:authority/gmd:CI_Citation...
# 58787  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifier/gmd:MD_Identifier/gmd:authority/gmd:CI_Citation...
# 58788                          /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifier/gmd:MD_Identifier/gmd:code
# 58789                                         /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor
# 58790                             /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor/@xlink:href
# 58791                            /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor/@xlink:title
# 58792                          /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor/@xlink:actuate
# 58793                                      /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:instrument/@gco:nilReason
# 58794                                   /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_ProgressCode/@codeList
# 58795                              /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_ProgressCode/@codeListValue
# 58796                                     /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_Citation/gmd:title
# 58797                       /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_Citation/gmd:date/@gco:nilReason
# 58798  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_Citation/gmd:citedResponsibleParty/gmd:CI_Responsi...
#
#                                                                                                                                          DialectDefinition  \
# 0                                                                                                                                                Undefined
# 1                                                                                                                                    /*/gmd:fileIdentifier
# 2                                                                                                                                          /*/gmd:language
# 3                                                                                                                                                Undefined
# 4                                                                                                                                                Undefined
# 5                                                                                                                                                Undefined
# 6                                                                                                                   /*/gmd:hierarchyLevel/gmd:MD_ScopeCode
# 7                                                                                                                                                Undefined
# 8                                                                                                                                           /*/gmd:contact
# 9                                                                                                                                /*/gmd:dateStamp/gco:Date
# 10                                                                                                                               /*/gmd:dateStamp/gco:Date
# 11                                                                                                                             /*/gmd:metadataStandardName
# 12                                                                                                                          /*/gmd:metadataStandardVersion
# 13                                                                                                                                               Undefined
# 14                                                                                                                                               Undefined
# 15                                                                                                /*/gmd:identificationInfo/*/gmd:citation/gmd:CI_Citation
# 16                                                                                                                /*/gmd:identificationInfo/*/gmd:abstract
# 17                                                                                                                  /*/gmd:identificationInfo/*/gmd:credit
# 18                                                                                                                  /*/gmd:identificationInfo/*/gmd:credit
# 19                                                                                              /*/gmd:identificationInfo/*/gmd:status/gmd:MD_ProgressCode
# 20                                                                                                          /*/gmd:identificationInfo/*/gmd:pointOfContact
# 21     /*/gmd:identificationInfo/*/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceAndUpdateFrequency/gmd:MD_MaintenanceFrequencyCode
# 22                                                                                                                                               Undefined
# 23                      /*/gmd:identificationInfo/*/gmd:descriptiveKeywords/gmd:MD_Keywords[contains(gmd:type/gmd:MD_KeywordTypeCode,'theme')]/gmd:keyword
# 24                      /*/gmd:identificationInfo/*/gmd:descriptiveKeywords/gmd:MD_Keywords[contains(gmd:type/gmd:MD_KeywordTypeCode,'theme')]/gmd:keyword
# 25                      /*/gmd:identificationInfo/*/gmd:descriptiveKeywords/gmd:MD_Keywords[contains(gmd:type/gmd:MD_KeywordTypeCode,'theme')]/gmd:keyword
# 26                      /*/gmd:identificationInfo/*/gmd:descriptiveKeywords/gmd:MD_Keywords[contains(gmd:type/gmd:MD_KeywordTypeCode,'theme')]/gmd:keyword
# 27                      /*/gmd:identificationInfo/*/gmd:descriptiveKeywords/gmd:MD_Keywords[contains(gmd:type/gmd:MD_KeywordTypeCode,'theme')]/gmd:keyword
# 28                      /*/gmd:identificationInfo/*/gmd:descriptiveKeywords/gmd:MD_Keywords[contains(gmd:type/gmd:MD_KeywordTypeCode,'theme')]/gmd:keyword
# 29                      /*/gmd:identificationInfo/*/gmd:descriptiveKeywords/gmd:MD_Keywords[contains(gmd:type/gmd:MD_KeywordTypeCode,'theme')]/gmd:keyword
# ...                                                                                                                                                    ...
# 58769                                                                                                                                            Undefined
# 58770                                                                                                                                            Undefined
# 58771                                                                                                                                            Undefined
# 58772                                                                                                                          //gmd:CI_Citation/gmd:title
# 58773                                                                                                                                            Undefined
# 58774                                                                                                                            //gmd:CI_ResponsibleParty
# 58775                                                                                                                                            Undefined
# 58776   /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:identifier/gmd:MD_Identifier/gmd:code
# 58777                                                                                                                                            Undefined
# 58778                                                                                                                                            Undefined
# 58779                                                                                                                                            Undefined
# 58780                                                                                                                                            Undefined
# 58781                                                                                                                                            Undefined
# 58782                                                                                                                          //gmd:CI_Citation/gmd:title
# 58783                                                                                                                                            Undefined
# 58784                                                                                                                          //gmd:CI_Citation/gmd:title
# 58785                                                                                                                                            Undefined
# 58786                                                                                                                          //gmd:CI_Citation/gmd:title
# 58787                                                                                                                                            Undefined
# 58788                                                                                           //gmi:platform/*/gmi:identifier/gmd:MD_Identifier/gmd:code
# 58789                                                                                                                                            Undefined
# 58790                                                                                                                                            Undefined
# 58791                                                                                                                                            Undefined
# 58792                                                                                                                                            Undefined
# 58793                                                                                                                                            Undefined
# 58794                                                                                                                                            Undefined
# 58795                                                                                                                                            Undefined
# 58796                                                                                                                          //gmd:CI_Citation/gmd:title
# 58797                                                                                                                                            Undefined
# 58798                                                                                                                            //gmd:CI_ResponsibleParty
#
#                                                                                                                                                                                               DocumentLocation
# 0                                                                                                                                                                         /gmi:MI_Metadata/@xsi:schemaLocation
# 1                                                                                                                                                                       /gmi:MI_Metadata/gmd:fileIdentifier[1]
# 2                                                                                                                                                                             /gmi:MI_Metadata/gmd:language[1]
# 3                                                                                                                                              /gmi:MI_Metadata/gmd:characterSet[1]/gmd:MD_CharacterSetCode[1]
# 4                                                                                                                                    /gmi:MI_Metadata/gmd:characterSet[1]/gmd:MD_CharacterSetCode[1]/@codeList
# 5                                                                                                                               /gmi:MI_Metadata/gmd:characterSet[1]/gmd:MD_CharacterSetCode[1]/@codeListValue
# 6                                                                                                                                                   /gmi:MI_Metadata/gmd:hierarchyLevel[1]/gmd:MD_ScopeCode[1]
# 7                                                                                                                                            /gmi:MI_Metadata/gmd:hierarchyLevelName[1]/gco:CharacterString[1]
# 8                                                                                                                                                                              /gmi:MI_Metadata/gmd:contact[1]
# 9                                                                                                                                                                /gmi:MI_Metadata/gmd:dateStamp[1]/gco:Date[1]
# 10                                                                                                                                                               /gmi:MI_Metadata/gmd:dateStamp[1]/gco:Date[1]
# 11                                                                                                                                                                /gmi:MI_Metadata/gmd:metadataStandardName[1]
# 12                                                                                                                                                             /gmi:MI_Metadata/gmd:metadataStandardVersion[1]
# 13                                                                                                                                                     /gmi:MI_Metadata/gmd:referenceSystemInfo[1]/@xlink:href
# 14                                                                                                                                                    /gmi:MI_Metadata/gmd:referenceSystemInfo[1]/@xlink:title
# 15                                                                                                  /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:citation[1]/gmd:CI_Citation[1]
# 16                                                                                                                     /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:abstract[1]
# 17                                                                                                                       /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:credit[1]
# 18                                                                                                                       /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:credit[2]
# 19                                                                                                /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:status[1]/gmd:MD_ProgressCode[1]
# 20                                                                                                               /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:pointOfContact[1]
# 21     /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:resourceMaintenance[1]/gmd:MD_MaintenanceInformation[1]/gmd:maintenanceAndUpdateFrequency[1]/gmd:MD_MaintenanceFrequency...
# 22                           /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:resourceMaintenance[1]/gmd:MD_MaintenanceInformation[1]/gmd:maintenanceNote[1]/gco:CharacterString[1]
# 23                                                                        /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:descriptiveKeywords[1]/gmd:MD_Keywords[1]/gmd:keyword[1]
# 24                                                                        /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:descriptiveKeywords[1]/gmd:MD_Keywords[1]/gmd:keyword[1]
# 25                                                                        /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:descriptiveKeywords[1]/gmd:MD_Keywords[1]/gmd:keyword[2]
# 26                                                                        /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:descriptiveKeywords[1]/gmd:MD_Keywords[1]/gmd:keyword[2]
# 27                                                                        /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:descriptiveKeywords[1]/gmd:MD_Keywords[1]/gmd:keyword[3]
# 28                                                                        /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:descriptiveKeywords[1]/gmd:MD_Keywords[1]/gmd:keyword[3]
# 29                                                                        /gmi:MI_Metadata/gmd:identificationInfo[1]/gmd:MD_DataIdentification[1]/gmd:descriptiveKeywords[1]/gmd:MD_Keywords[1]/gmd:keyword[4]
# ...                                                                                                                                                                                                        ...
# 58769                 /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[1]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:instrument[1]/@gco:nilReason
# 58770           /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[1]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:status[1]/gmd:MD_ProgressCode[1]/@codeList
# 58771      /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[1]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:status[1]/gmd:MD_ProgressCode[1]/@codeListValue
# 58772          /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[1]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:title[1]
# 58773  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[1]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:date[1]/@gco:...
# 58774  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[1]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:citedResponsi...
# 58775                                           /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:description[1]/gco:CharacterString[1]
# 58776                                  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:identifier[1]/gmd:MD_Identifier[1]/gmd:code[1]
# 58777                                      /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:status[1]/gmd:MD_ProgressCode[1]/@codeList
# 58778                                 /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:status[1]/gmd:MD_ProgressCode[1]/@codeListValue
# 58779                                   /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:type[1]/gmi:MI_OperationTypeCode[1]/@codeList
# 58780                              /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:type[1]/gmi:MI_OperationTypeCode[1]/@codeListValue
# 58781                                               /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:parentOperation[1]/@gco:nilReason
# 58782  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:title[1]
# 58783  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:date[...
# 58784  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:citation[2]/gmd:CI_Citation[1]/gmd:title[1]
# 58785  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:citation[2]/gmd:CI_Citation[1]/gmd:date[...
# 58786  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:identifier[1]/gmd:MD_Identifier[1]/gmd:a...
# 58787  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:identifier[1]/gmd:MD_Identifier[1]/gmd:a...
# 58788  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:identifier[1]/gmd:MD_Identifier[1]/gmd:c...
# 58789                 /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:description[1]/gmx:Anchor[1]
# 58790     /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:description[1]/gmx:Anchor[1]/@xlink:href
# 58791    /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:description[1]/gmx:Anchor[1]/@xlink:title
# 58792  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:description[1]/gmx:Anchor[1]/@xlink:actuate
# 58793                 /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:platform[1]/gmi:MI_Platform[1]/gmi:instrument[1]/@gco:nilReason
# 58794           /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:status[1]/gmd:MD_ProgressCode[1]/@codeList
# 58795      /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:status[1]/gmd:MD_ProgressCode[1]/@codeListValue
# 58796          /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:title[1]
# 58797  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:date[1]/@gco:...
# 58798  /gmi:MI_Metadata/gmi:acquisitionInformation[1]/gmi:MI_AcquisitionInformation[1]/gmi:operation[2]/gmi:MI_Operation[1]/gmi:plan[1]/gmi:MI_Plan[1]/gmi:citation[1]/gmd:CI_Citation[1]/gmd:citedResponsi...
#
# [58799 rows x 8 columns]

# %% [markdown]
# ###  Let's get rid of the columns we won't use for this analysis. We already know the organization and dialect after we have selected the organization and collection. The xpaths aren't needed either.

# %%
CollectionConceptsDF.drop(['Collection','Dialect', 'XPath', 'DialectDefinition','DocumentLocation'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#                  Record                      Concept  \
# 0      dataset_3687.xml                      Unknown
# 1      dataset_3687.xml          Metadata Identifier
# 2      dataset_3687.xml            Metadata Language
# 3      dataset_3687.xml                      Unknown
# 4      dataset_3687.xml                      Unknown
# 5      dataset_3687.xml                      Unknown
# 6      dataset_3687.xml                Resource Type
# 7      dataset_3687.xml                      Unknown
# 8      dataset_3687.xml             Metadata Contact
# 9      dataset_3687.xml       Metadata Modified Date
# 10     dataset_3687.xml               Metadata Dates
# 11     dataset_3687.xml   Metadata Standard Citation
# 12     dataset_3687.xml    Metadata Standard Version
# 13     dataset_3687.xml                      Unknown
# 14     dataset_3687.xml                      Unknown
# 15     dataset_3687.xml      Publication Information
# 16     dataset_3687.xml                     Abstract
# 17     dataset_3687.xml              Acknowledgement
# 18     dataset_3687.xml              Acknowledgement
# 19     dataset_3687.xml              Resource Status
# 20     dataset_3687.xml             Resource Contact
# 21     dataset_3687.xml    Resource Update Frequency
# 22     dataset_3687.xml                      Unknown
# 23     dataset_3687.xml                Theme Keyword
# 24     dataset_3687.xml                      Keyword
# 25     dataset_3687.xml                Theme Keyword
# 26     dataset_3687.xml                      Keyword
# 27     dataset_3687.xml                Theme Keyword
# 28     dataset_3687.xml                      Keyword
# 29     dataset_3687.xml                Theme Keyword
# ...                 ...                          ...
# 58769  dataset_3826.xml                      Unknown
# 58770  dataset_3826.xml                      Unknown
# 58771  dataset_3826.xml                      Unknown
# 58772  dataset_3826.xml         Cited Resource Title
# 58773  dataset_3826.xml                      Unknown
# 58774  dataset_3826.xml               Responsibility
# 58775  dataset_3826.xml                      Unknown
# 58776  dataset_3826.xml  Related Resource Identifier
# 58777  dataset_3826.xml                      Unknown
# 58778  dataset_3826.xml                      Unknown
# 58779  dataset_3826.xml                      Unknown
# 58780  dataset_3826.xml                      Unknown
# 58781  dataset_3826.xml                      Unknown
# 58782  dataset_3826.xml         Cited Resource Title
# 58783  dataset_3826.xml                      Unknown
# 58784  dataset_3826.xml         Cited Resource Title
# 58785  dataset_3826.xml                      Unknown
# 58786  dataset_3826.xml         Cited Resource Title
# 58787  dataset_3826.xml                      Unknown
# 58788  dataset_3826.xml          Platform Short Name
# 58789  dataset_3826.xml                      Unknown
# 58790  dataset_3826.xml                      Unknown
# 58791  dataset_3826.xml                      Unknown
# 58792  dataset_3826.xml                      Unknown
# 58793  dataset_3826.xml                      Unknown
# 58794  dataset_3826.xml                      Unknown
# 58795  dataset_3826.xml                      Unknown
# 58796  dataset_3826.xml         Cited Resource Title
# 58797  dataset_3826.xml                      Unknown
# 58798  dataset_3826.xml               Responsibility
#
#                                                                                                                                                                                                        Content
# 0                                                                                                                  http://www.isotc211.org/2005/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd
# 1                                                                                                                                                                       http://lod.bco-dmo.org/id/dataset/3687
# 2                                                                                                                                                                                                     eng; USA
# 3                                                                                                                                                                                                         utf8
# 4                                                                                                                         http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_CharacterSetCode
# 5                                                                                                                                                                                                         utf8
# 6                                                                                                                                                                                                      dataset
# 7                                                                                  Highest level of data collection, from a common set of sensors or instrumentation, usually within the same research project
# 8      Biological and Chemical Oceanography Data Management Office (BCO-DMO) Unavailable 508-289-2009 WHOI MS#36 Woods Hole MA 02543 USA info@bco-dmo.org http://www.bco-dmo.org Monday - Friday 8:00am - 5...
# 9                                                                                                                                                                                                   2012-08-01
# 10                                                                                                                                                                                                  2012-08-01
# 11                                                                                                             ISO 19115-2 Geographic Information - Metadata - Part 2: Extensions for Imagery and Gridded Data
# 12                                                                                                                                                                                         ISO 19115-2:2009(E)
# 13                                                                                                                                     https://www.ngdc.noaa.gov/docucomp/895cc120-95ed-11e0-aa80-0800200c9a66
# 14                                                                                                                                                                                     WGS 84 / World Mercator
# 15     GT11 - CTD - GT-C Bottle from the U.S. GEOTRACES NAT project of the U.S. GEOTRACES program 2013-01-30 publication Dr Edward A. Boyle Massachusetts Institute of Technology principalInvestigator doc...
# 16     CTD - GT-C Bottle Dataset Description: &lt;p&gt;CTD bottle data from GT-C (GEOTRACES Carousel) for GT11 Transect&lt;/p&gt;&lt;p&gt;&amp;nbsp;&lt;/p&gt; Acquisition Description: &lt;p&gt;Refer to &...
# 17                                                       Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926423 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926423
# 18                                                       Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926092 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926092
# 19                                                                                                                                                                                                   completed
# 20            Dr Edward A. Boyle Massachusetts Institute of Technology 617-253-3388 Chemical Oceanography, Trace Metal Group MIT E25-619, 45 Carleton St Cambridge MA 02142 USA eaboyle@mit.edu pointOfContact
# 21                                                                                                                                                                                                    asNeeded
# 22                                                                                                                                                                            Dataset Version: 30 January 2013
# 23                                                                                                                                                                                                 cruise_part
# 24                                                                                                                                                                                                 cruise_part
# 25                                                                                                                                                                                                  dataset_id
# 26                                                                                                                                                                                                  dataset_id
# 27                                                                                                                                                                                                  dataset_id
# 28                                                                                                                                                                                                  dataset_id
# 29                                                                                                                                                                                                     station
# ...                                                                                                                                                                                                        ...
# 58769                                                                                                                                                                                                  unknown
# 58770                                                                                                                         http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 58771                                                                                                                                                                                                completed
# 58772                                                                                                                                                                                                 KN199-04
# 58773                                                                                                                                                                                                  unknown
# 58774                      Dr William J. Jenkins Woods Hole Oceanographic Institution http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/Cruise_Report_for_Knorr_199_Final_v3.pdf Report describing KN199-04
# 58775                                                                                                                                                                                         Cruise: KN204-01
# 58776                                                                                                                                                                                                 KN204-01
# 58777                                                                                               http://www.ngdc.noaa.gov/metadata/published/xsd/schema/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 58778                                                                                                                                                                                                completed
# 58779                                                                                          http://www.ngdc.noaa.gov/metadata/published/xsd/schema/resources/Codelist/gmxCodelists.xml#MI_OperationTypeCode
# 58780                                                                                                                                                                                                     real
# 58781                                                                                                                                                                                             inapplicable
# 58782                                                                                                                                                                                                R/V Knorr
# 58783                                                                                                                                                                                                  unknown
# 58784                                                                                                                                                                           Community Standard Description
# 58785                                                                                                                                                                                                  unknown
# 58786                                                                                                                                                     International Council for the Exploration of the Sea
# 58787                                                                                                                                                                                                  unknown
# 58788                                                                                                                                                                                                R/V Knorr
# 58789                                                                                                                                                                                                   vessel
# 58790                                                                                                                                                             http://lod.bco-dmo.org/id/platform/53994.rdf
# 58791                                                                                                                                                                                                R/V Knorr
# 58792                                                                                                                                                                                                onRequest
# 58793                                                                                                                                                                                                  unknown
# 58794                                                                                                                         http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 58795                                                                                                                                                                                                completed
# 58796                                                                                                                                                                                                 KN204-01
# 58797                                                                                                                                                                                                  unknown
# 58798                                         Dr Edward A. Boyle Massachusetts Institute of Technology http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/STS_Prelim_GT11_Doc.pdf Report describing KN204-01
#
# [58799 rows x 3 columns]

# %% [markdown]
# ### Now that we have the data we want, what are the understood concepts that exist in the collection?

# %%
ConceptVerticals=CollectionConceptsDF.Concept.unique()
Verticals=ConceptVerticals.tolist()
Verticals
# Out:
# ['Unknown',
#  'Metadata Identifier',
#  'Metadata Language',
#  'Resource Type',
#  'Metadata Contact',
#  'Metadata Modified Date',
#  'Metadata Dates',
#  'Metadata Standard Citation',
#  'Metadata Standard Version',
#  'Publication Information',
#  'Abstract',
#  'Acknowledgement',
#  'Resource Status',
#  'Resource Contact',
#  'Resource Update Frequency',
#  'Theme Keyword',
#  'Keyword',
#  'Keyword Type',
#  'Keyword Vocabulary',
#  'Keyword Vocabulary Citation',
#  'Instrument Keyword',
#  'Place Keyword',
#  'Rights',
#  'Association',
#  'Resource Language',
#  'Topic Category',
#  'Geographic Description',
#  'Temporal Extent',
#  'Feature Catalogue Citation',
#  'VariableType',
#  'Attribute Label',
#  'DataType',
#  'Attribute Definition',
#  'Units',
#  'Distribution Contact',
#  'URL',
#  'Product Link',
#  'Data Quality Scope',
#  'Resource Lineage',
#  'Reprocessing Plan Note',
#  'Responsibility',
#  'Instrument',
#  'Related Resource Identifier',
#  'Cited Resource Title',
#  'Platform Short Name',
#  'Spatial Extent']

# %% [markdown]
# ### Create function that allows us to call up metadata vertical content for a concept

# %%
def ConceptVerticalTable(Concept):
    global VerticalTable
    VerticalTable = CollectionConceptsDF[CollectionConceptsDF.Concept == Concept]
    return VerticalTable

# %% [markdown]
# ### Create a dropdown using the function that allows us to create a dataframe of the concept you want as a metadata vertical.

# %%
interact(ConceptVerticalTable, Concept=Verticals)
# Out:
#                    Record          Concept                Content
# 611      dataset_3687.xml  Temporal Extent             2013-01-30
# 2684     dataset_3933.xml  Temporal Extent             2014-02-21
# 3030   dataset_647580.xml  Temporal Extent  2013-10-29 2013-12-16
# 3393     dataset_4074.xml  Temporal Extent             2013-11-08
# 3813   dataset_637784.xml  Temporal Extent             2016-04-15
# 4120     dataset_3862.xml  Temporal Extent             2013-01-22
# 4432   dataset_648030.xml  Temporal Extent  2013-10-28 2013-12-17
# 4861   dataset_643213.xml  Temporal Extent             2016-07-11
# 5629     dataset_3865.xml  Temporal Extent             2014-09-16
# 6988     dataset_4001.xml  Temporal Extent             2013-11-05
# 7373     dataset_3850.xml  Temporal Extent             2013-06-21
# 7790   dataset_647606.xml  Temporal Extent  2013-10-28 2013-12-17
# 8148     dataset_3486.xml  Temporal Extent             2011-07-25
# 8445     dataset_3825.xml  Temporal Extent             2013-03-05
# 8822   dataset_472814.xml  Temporal Extent             2013-12-10
# 9214     dataset_3664.xml  Temporal Extent             2012-06-05
# 9500     dataset_3859.xml  Temporal Extent             2013-03-05
# 9851   dataset_641044.xml  Temporal Extent  2013-10-29 2013-12-17
# 10233    dataset_3508.xml  Temporal Extent             2011-07-26
# 10483    dataset_3822.xml  Temporal Extent             2013-10-14
# 10780    dataset_3672.xml  Temporal Extent             2012-06-19
# 11029    dataset_3917.xml  Temporal Extent             2013-06-14
# 11675    dataset_3519.xml  Temporal Extent             2013-02-13
# 13099    dataset_3848.xml  Temporal Extent             2013-03-01
# 13492  dataset_650340.xml  Temporal Extent             2016-06-29
# 13797    dataset_3510.xml  Temporal Extent             2011-07-29
# 14079    dataset_3846.xml  Temporal Extent             2015-01-20
# 14675    dataset_3841.xml  Temporal Extent             2014-03-10
# 15402  dataset_647909.xml  Temporal Extent  2013-11-04 2013-12-15
# 16149    dataset_3517.xml  Temporal Extent             2013-02-13
# ...                   ...              ...                    ...
# 47299    dataset_3671.xml  Temporal Extent             2013-01-30
# 47562    dataset_3914.xml  Temporal Extent             2013-11-05
# 47909    dataset_3830.xml  Temporal Extent             2013-01-03
# 48165    dataset_3842.xml  Temporal Extent             2013-01-25
# 48419    dataset_3514.xml  Temporal Extent             2011-07-29
# 48643  dataset_522810.xml  Temporal Extent             2014-10-30
# 48937    dataset_3839.xml  Temporal Extent             2013-03-14
# 49229    dataset_3513.xml  Temporal Extent             2011-07-29
# 49488    dataset_3845.xml  Temporal Extent             2013-11-05
# 49853    dataset_3870.xml  Temporal Extent             2014-08-08
# 50249  dataset_648753.xml  Temporal Extent             2016-06-14
# 50667    dataset_3521.xml  Temporal Extent             2013-03-14
# 51042  dataset_549122.xml  Temporal Extent  2010-10-01 2011-11-30
# 51522  dataset_522798.xml  Temporal Extent             2014-10-30
# 51803    dataset_3470.xml  Temporal Extent             2013-02-27
# 52184    dataset_3692.xml  Temporal Extent             2014-06-16
# 52713  dataset_639016.xml  Temporal Extent             2016-02-22
# 53111  dataset_522846.xml  Temporal Extent             2014-10-30
# 53445  dataset_642974.xml  Temporal Extent             2016-07-01
# 53898    dataset_3868.xml  Temporal Extent             2013-04-26
# 54319    dataset_4002.xml  Temporal Extent             2013-11-05
# 54720  dataset_643494.xml  Temporal Extent             2016-06-13
# 55218    dataset_3861.xml  Temporal Extent             2012-12-27
# 55783    dataset_3854.xml  Temporal Extent             2013-03-05
# 56311  dataset_648543.xml  Temporal Extent             2016-06-09
# 57208    dataset_3905.xml  Temporal Extent             2014-06-17
# 57553  dataset_644765.xml  Temporal Extent             2016-05-05
# 57938    dataset_3821.xml  Temporal Extent             2013-10-14
# 58235    dataset_3485.xml  Temporal Extent             2011-07-25
# 58516    dataset_3826.xml  Temporal Extent             2013-11-05
#
# [117 rows x 3 columns]

# %% [markdown]
# ### Let's group the unique values in the content column and count them up.

# %%
VerticalTable.groupby('Content').size()
# Out:
# Content
# featureType    117
# instrument     103
# place          117
# service        117
# theme          117
# dtype: int64

# %% [markdown]
# ### Remove colons from the values so there are no Bokeh Label errors. Use Bokeh to plot a bar chart of the unique values.

# %%
data = VerticalTable.Content.str.replace(':','.')

p = Bar(data, 'Content', title="Vertical Value Occurance Count", legend=False)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="44d8ac05-8c40-4b90-9109-238e9bb46863"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("44d8ac05-8c40-4b90-9109-238e9bb46863").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("44d8ac05-8c40-4b90-9109-238e9bb46863");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '44d8ac05-8c40-4b90-9109-238e9bb46863' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f2aab340-cf6c-44b9-b7b4-315d669d4b4c":{"roots":{"references":[{"attributes":{"axis_label":"Content","formatter":{"id":"70cc0d94-d169-4250-849b-1c049931acc5","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"70b008fb-2729-4dcf-843d-77e9dc6c7b00","subtype":"Chart","type":"Plot"},"ticker":{"id":"495e24cb-4b3e-4c26-88aa-3c6f4c443761","type":"CategoricalTicker"}},"id":"56e6a995-5e43-4a0e-84c0-3846393fbb7c","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"b35123f6-6db5-42cb-9548-7a3a6a5324d9","type":"ColumnDataSource"},"glyph":{"id":"d65adc0e-3aa7-4b60-84ba-033eed65f06a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"47dc75e6-58bd-4bfa-a1ff-d30b0fa62cab","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["2014-12-12"],"chart_index":[{"Content":"2014-12-12"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"2014-12-12"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2014-12-12"],"y":[0.5]}},"id":"c661ddbc-38ea-44df-a0a7-d1edc5979cf2","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"08c782be-51e8-4d4d-bde8-bf30e69f9c75","type":"ColumnDataSource"},"glyph":{"id":"828e87f2-932e-462d-98e5-2eb8366c04e6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2d4b77b1-3626-4db9-a391-1f4215920a74","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6bf7d052-e302-4455-b5cf-0572bbb56f09","type":"ColumnDataSource"},"glyph":{"id":"5adcd32e-8cb7-4298-a1fb-7d28e2fd805d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f2ad9bd8-02a6-41a9-90cd-08a52a11f311","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"af9d9330-c977-470d-b258-23b9a4086bd4","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["2014-11-19"],"chart_index":[{"Content":"2014-11-19"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"2014-11-19"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2014-11-19"],"y":[0.5]}},"id":"117e778c-03fa-46ef-986e-7cc9ace1cb2c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["2014-08-08"],"chart_index":[{"Content":"2014-08-08"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"2014-08-08"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2014-08-08"],"y":[0.5]}},"id":"5ca9cacf-071d-4b25-ab6b-6e413607787e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e5d9b7a7-6f0e-480a-8ebe-70215d86c858","type":"ColumnDataSource"},"glyph":{"id":"af9d9330-c977-470d-b258-23b9a4086bd4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"98298d0c-18e5-40d7-bdc2-b180df61875a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["2013-04-26"],"chart_index":[{"Content":"2013-04-26"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":[{"Content":"2013-04-26"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2013-04-26"],"y":[0.5]}},"id":"6bf7d052-e302-4455-b5cf-0572bbb56f09","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["2010-10-16 2011-12-10"],"char ...

# %%
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith(".csv")]:
        print(os.path.join(dirpath, filename))
# Out:
# ../data/BCO-DMO/GeoTraces_ISO_data.csv
# ../data/DataOne/CDL_CSDGM_data.csv
# ../data/DataOne/CLOEBIRD_EML_data.csv
# ../data/DataOne/Dryad_Dryad_data.csv
# ../data/DataOne/EDACGSTORE_CSDGM_data.csv
# ../data/DataOne/EDORA_Mercury_data.csv
# ../data/DataOne/ESA_EML_data.csv
# ../data/DataOne/GLEON_EML_data.csv
# ../data/DataOne/GOA_EML_data.csv
# ../data/DataOne/IARC_Onedcx_data.csv
# ../data/DataOne/IOE_EML_data.csv
# ../data/DataOne/KNB_EML_data.csv
# ../data/DataOne/KUBI_EML_data.csv
# ../data/DataOne/LTER_EML_data.csv
# ../data/DataOne/LTER_EUROPE_EML_data.csv
# ../data/DataOne/NMEPSCOR_CSDGM_data.csv
# ../data/DataOne/ONEShare_EML_data.csv
# ../data/DataOne/ORNLDAAC_Mercury_data.csv
# ../data/DataOne/PISCO_EML_data.csv
# ../data/DataOne/RGD_Mercury_data.csv
# ../data/DataOne/SANPARKS_EML_data.csv
# ../data/DataOne/SEAD_CSDGM_data.csv
# ../data/DataOne/TERN_EML_data.csv
# ../data/DataOne/TFRI_EML_data.csv
# ../data/DataOne/US_MPC_Onedcx_data.csv
# ../data/DataOne/USANPN_EML_data.csv
# ../data/DataOne/USGSCSAS_BDP_data.csv
# ../data/DataOne/USGSCSAS_CSDGM_data.csv
# ../data/IEDA/ECL_DCITE_data.csv
# ../data/LTERthroughTime/LTER_2005_EML_data.csv
# ../data/LTERthroughTime/LTER_2006_EML_data.csv
# ../data/LTERthroughTime/LTER_2007_EML_data.csv
# ../data/LTERthroughTime/LTER_2008_EML_data.csv
# ../data/LTERthroughTime/LTER_2009_EML_data.csv
# ../data/LTERthroughTime/LTER_2010_EML_data.csv
# ../data/LTERthroughTime/LTER_2011_EML_data.csv
# ../data/LTERthroughTime/LTER_2012_EML_data.csv
# ../data/LTERthroughTime/LTER_2013_EML_data.csv
# ../data/LTERthroughTime/LTER_2014_EML_data.csv
# ../data/LTERthroughTime/LTER_2015_EML_data.csv
# ../data/LTERthroughTime/LTER_2016_EML_data.csv
# ../data/NASA/GES_DISC_DIF_data.csv
# ../data/NASA/GHRC_DIF_data.csv
# ../data/NASA/GHRC_ISO_data.csv
# ../data/NASA/LARC_DIF_data.csv
# ../data/NASA/LARC_ISO_data.csv
# ../data/NASA/NSIDC_DIF_data.csv
# ../data/NASA/NSIDC_ISO_data.csv
# ../data/NCAR/IIS_MODS_data.csv
# ../data/NCAR/RDA_RDA-CISL_data.csv
# ../data/ORNL/DAAC_Mercury_data.csv
# ../data/ORNL/NGEE_CSDGM_data.csv
# ../data/ORNL/OLI_ISO_data.csv
# ../data/ORNL/USGSC_CSDGM_data.csv
# ../data/USGS/OldScienceBase_CSDGM_data.csv
# ../data/USGS/ScienceBase_CSDGM_data.csv
