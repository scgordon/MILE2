# %% [markdown]
# ##  This notebook allows the user to look at all the content a specific concept contains, collection wide.

# %% [markdown]
# ### Read in a csv that the user selects by selecting the organization and collection.

# %%
import pandas as pd
pd.options.display.max_colwidth=2000
import os
from os import walk
import numpy as np
from ipykernel import kernelapp as app
from __future__ import print_function
from ipywidgets import *
import ipywidgets as widgets
from bokeh.charts import output_notebook, output_file, show, Bar, Scatter, Histogram, TimeSeries
from bokeh.plotting import figure
from bokeh.models import Range1d, HoverTool, ResizeTool
from bokeh.charts import defaults
from bokeh.models import Legend
defaults.width = 1200
defaults.height = 800
output_notebook()
#from ipywidgets import Button, Layout
#from glob import glob
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cc9a02f9-a0e1-4c06-be38-61e28cf68bd7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### query the directory for subdirectory names, return them in a list.

# %%
Organizations = []
for (dirpath, dirnames, filenames) in walk('../../ConceptMining/data/'):
    Organizations.extend(dirnames)
    break
Organizations
# Out:
# ['BCO-DMO',
#  'DataOne',
#  'IEDA',
#  'LTERthroughTime',
#  'NASA',
#  'NCAR',
#  'ORNL',
#  'USGS']

# %% [markdown]
# ### Create a function to populate a variable used to populate the list for the collection dropdown

# %%
def OrganizationChoices(Organization):
    global OrganizationChoice
    global Collections
    OrganizationChoice=os.path.join('../../ConceptMining/data',Organization)
    Collections=os.listdir(OrganizationChoice)

# %% [markdown]
# ### Choose the organization you want to look at by creating a dropdown with the function that identifies the organizations that have data.

# %%
interactive(OrganizationChoices, Organization=Organizations)

# %% [markdown]
# ### Function that reads the selected csv into a dataframe

# %%
def CollectionChoices(Collection):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(OrganizationChoice, Collection))
    return CollectionConceptsDF

# %% [markdown]
# ### Choose the CSV you want to examine

# %%
interactive(CollectionChoices, Collection=Collections)
# Out:
#      Collection Dialect      Record                            Concept  \
# 0           ECL   DCITE  100004.xml                           Abstract
# 1           ECL   DCITE  100004.xml                       Bounding Box
# 2           ECL   DCITE  100004.xml                   Contributor Name
# 3           ECL   DCITE  100004.xml                   Contributor Role
# 4           ECL   DCITE  100004.xml                Distribution Format
# 5           ECL   DCITE  100004.xml                         First Name
# 6           ECL   DCITE  100004.xml                            Keyword
# 7           ECL   DCITE  100004.xml                 Keyword Vocabulary
# 8           ECL   DCITE  100004.xml                          Last Name
# 9           ECL   DCITE  100004.xml                        Middle Name
# 10          ECL   DCITE  100004.xml                   Publication Date
# 11          ECL   DCITE  100004.xml                          Publisher
# 12          ECL   DCITE  100004.xml        Related Resource Identifier
# 13          ECL   DCITE  100004.xml    Resource Creation/Revision Date
# 14          ECL   DCITE  100004.xml                    Resource Format
# 15          ECL   DCITE  100004.xml                Resource Identifier
# 16          ECL   DCITE  100004.xml                Resource Identifier
# 17          ECL   DCITE  100004.xml           Resource Identifier Type
# 18          ECL   DCITE  100004.xml                  Resource Language
# 19          ECL   DCITE  100004.xml                     Resource Title
# 20          ECL   DCITE  100004.xml                      Resource Type
# 21          ECL   DCITE  100004.xml                   Resource Version
# 22          ECL   DCITE  100004.xml       Responsible Party Identifier
# 23          ECL   DCITE  100004.xml  Responsible Party Identifier Type
# 24          ECL   DCITE  100004.xml                             Rights
# 25          ECL   DCITE  100004.xml                     Spatial Extent
# 26          ECL   DCITE  100004.xml                     Spatial Extent
# 27          ECL   DCITE  100004.xml                      Theme Keyword
# 28          ECL   DCITE  100031.xml                           Abstract
# 29          ECL   DCITE  100031.xml     Author / Originator Identifier
# ...         ...     ...         ...                                ...
# 9011        ECL   DCITE  100592.xml                            Keyword
# 9012        ECL   DCITE  100592.xml                 Keyword Vocabulary
# 9013        ECL   DCITE  100592.xml                          Last Name
# 9014        ECL   DCITE  100592.xml                          Last Name
# 9015        ECL   DCITE  100592.xml                          Last Name
# 9016        ECL   DCITE  100592.xml                          Last Name
# 9017        ECL   DCITE  100592.xml                          Last Name
# 9018        ECL   DCITE  100592.xml                        Middle Name
# 9019        ECL   DCITE  100592.xml                        Middle Name
# 9020        ECL   DCITE  100592.xml                        Middle Name
# 9021        ECL   DCITE  100592.xml                        Middle Name
# 9022        ECL   DCITE  100592.xml                        Middle Name
# 9023        ECL   DCITE  100592.xml                   Publication Date
# 9024        ECL   DCITE  100592.xml                          Publisher
# 9025        ECL   DCITE  100592.xml        Related Resource Identifier
# 9026        ECL   DCITE  100592.xml    Resource Creation/Revision Date
# 9027        ECL   DCITE  100592.xml                    Resource Format
# 9028        ECL   DCITE  100592.xml                Resource Identifier
# 9029        ECL   DCITE  100592.xml                Resource Identifier
# 9030        ECL   DCITE  100592.xml           Resource Identifier Type
# 9031        ECL   DCITE  100592.xml                  Resource Language
# 9032        ECL   DCITE  100592.xml                     Resource Title
# 9033        ECL   DCITE  100592.xml                      Resource Type
# 9034        ECL   DCITE  100592.xml                   Resource Version
# 9035        ECL   DCITE  100592.xml       Responsible Party Identifier
# 9036        ECL   DCITE  100592.xml  Responsible Party Identifier Type
# 9037        ECL   DCITE  100592.xml                             Rights
# 9038        ECL   DCITE  100592.xml                     Spatial Extent
# 9039        ECL   DCITE  100592.xml                     Spatial Extent
# 9040        ECL   DCITE  100592.xml                      Theme Keyword
#
#                                                                           XPath  \
# 0               /resource/descriptions/description[@descriptionType='Abstract']
# 1                           /resource/geoLocations/geoLocation/geoLocationPlace
# 2                            /resource/contributors/contributor/contributorName
# 3                           /resource/contributors/contributor/@contributorType
# 4                                                      /resource/formats/format
# 5                                        /resource/creators/creator/creatorName
# 6                                                    /resource/subjects/subject
# 7                                     /resource/subjects/subject/@subjectScheme
# 8                                        /resource/creators/creator/creatorName
# 9                                        /resource/creators/creator/creatorName
# 10                                                    /resource/publicationYear
# 11                                                          /resource/publisher
# 12                               /resource/relatedIdentifiers/relatedIdentifier
# 13                                                         /resource/dates/date
# 14                                                     /resource/formats/format
# 15    /resource/identifier | /resource/alternateIdentifiers/alternateIdentifier
# 16    /resource/identifier | /resource/alternateIdentifiers/alternateIdentifier
# 17                                         /resource/identifier/@identifierType
# 18                                                           /resource/language
# 19                                                       /resource/titles/title
# 20                                  /resource/resourceType/@resourceTypeGeneral
# 21                                                            /resource/version
# 22                            /resource/contributors/contributor/nameIdentifier
# 23      /resource/contributors/contributor/nameIdentifier/@nameIdentifierScheme
# 24                                                  /resource/rightsList/rights
# 25                                           /resource/geoLocations/geoLocation
# 26                                           /resource/geoLocations/geoLocation
# 27                                                   /resource/subjects/subject
# 28              /resource/descriptions/description[@descriptionType='Abstract']
# 29              /resource/creators/creator/nameIdentifier/@nameIdentifierScheme
# ...                                                                         ...
# 9011                                                 /resource/subjects/subject
# 9012                                  /resource/subjects/subject/@subjectScheme
# 9013                                     /resource/creators/creator/creatorName
# 9014                                     /resource/creators/creator/creatorName
# 9015                                     /resource/creators/creator/creatorName
# 9016                                     /resource/creators/creator/creatorName
# 9017                                     /resource/creators/creator/creatorName
# 9018                                     /resource/creators/creator/creatorName
# 9019                                     /resource/creators/creator/creatorName
# 9020                                     /resource/creators/creator/creatorName
# 9021                                     /resource/creators/creator/creatorName
# 9022                                     /resource/creators/creator/creatorName
# 9023                                                  /resource/publicationYear
# 9024                                                        /resource/publisher
# 9025                             /resource/relatedIdentifiers/relatedIdentifier
# 9026                                                       /resource/dates/date
# 9027                                                   /resource/formats/format
# 9028  /resource/identifier | /resource/alternateIdentifiers/alternateIdentifier
# 9029  /resource/identifier | /resource/alternateIdentifiers/alternateIdentifier
# 9030                                       /resource/identifier/@identifierType
# 9031                                                         /resource/language
# 9032                                                     /resource/titles/title
# 9033                                /resource/resourceType/@resourceTypeGeneral
# 9034                                                          /resource/version
# 9035                          /resource/contributors/contributor/nameIdentifier
# 9036    /resource/contributors/contributor/nameIdentifier/@nameIdentifierScheme
# 9037                                                /resource/rightsList/rights
# 9038                                         /resource/geoLocations/geoLocation
# 9039                                         /resource/geoLocations/geoLocation
# 9040                                                 /resource/subjects/subject
#
#                                                                                                                                                                  Content
# 0     Analyses of volatile, major, and trace elements for a suite of glasses and melt inclusions from the 85 degrees E segment of the ultra-slow spreading Gakkel Ridge.
# 1                                                                                                                                              Gakkel Ridge Arctic Ocean
# 2                                                                                                                                                EarthChem Library (ECL)
# 3                                                                                                                                                                 Editor
# 4                                                                                                                                               application/vnd.ms-excel
# 5                                                                                                                                                           Shaw, Alison
# 6                                                                                                                                                           Geochemistry
# 7                                                                                                                                                                    ECL
# 8                                                                                                                                                           Shaw, Alison
# 9                                                                                                                                                           Shaw, Alison
# 10                                                                                                                                                                  2011
# 11                                                                                                                             Integrated Earth Data Applications (IEDA)
# 12                                                                                                                                            10.1016/j.epsl.2009.11.018
# 13                                                                                                                                                            2011-03-25
# 14                                                                                                                                              application/vnd.ms-excel
# 15                                                                                                                                                   10.1594/IEDA/100004
# 16                                                                                                                   http://www.earthchem.org/library/browse/view?id=124
# 17                                                                                                                                                                   DOI
# 18                                                                                                                                                                    en
# 19                                                                                                              Gakkel Ridge basalt melt inclusion and mineral chemistry
# 20                                                                                                                                                               Dataset
# 21                                                                                                                                                                   1.0
# 22                                                                                                                                                       10.17616/R3V644
# 23                                                                                                                                                                   DOI
# 24                                                                            Creative Commons Attribution-NonCommercial-Share Alike 3.0 United States [CC BY-NC-SA 3.0]
# 25                                                                                                                         \n      85.5945 85.1788 85.6263 85.5817\n
# 26                                                                                                                               \n      Gakkel Ridge Arctic Ocean\n
# 27                                                                                                                                                          Geochemistry
# 28                                                                Hydrothermal vent fluid geochemistry from the Medusa vent, collected during cruise AT15-17, March 2007
# 29                                                                                                                                                               GeoPass
# ...                                                                                                                                                                  ...
# 9011                                                                                                                                                      Chemistry:Rock
# 9012                                                                                                                                                                 ECL
# 9013                                                                                                                                                    Du Vivier, Alice
# 9014                                                                                                                                                        Selby, David
# 9015                                                                                                                                                         Condon, Dan
# 9016                                                                                                                                                       Takashima, R.
# 9017                                                                                                                                                           Nishi, H.
# 9018                                                                                                                                                    Du Vivier, Alice
# 9019                                                                                                                                                        Selby, David
# 9020                                                                                                                                                         Condon, Dan
# 9021                                                                                                                                                       Takashima, R.
# 9022                                                                                                                                                           Nishi, H.
# 9023                                                                                                                                                                2016
# 9024                                                                                                                           Integrated Earth Data Applications (IEDA)
# 9025                                                                                                                                          10.1016/j.epsl.2015.07.020
# 9026                                                                                                                                                          2016-06-01
# 9027                                                                                                                                                     application/zip
# 9028                                                                                                                                                 10.1594/IEDA/100592
# 9029                                                                                                                 http://www.earthchem.org/library/browse/view?id=941
# 9030                                                                                                                                                                 DOI
# 9031                                                                                                                                                                 eng
# 9032                                                                                    U-Pb Geochronology from five volcanic tuffs from the Yezo Group, Hokkaido, Japan
# 9033                                                                                                                                                          Collection
# 9034                                                                                                                                                                 1.0
# 9035                                                                                                                                                     10.17616/R3V644
# 9036                                                                                                                                                                 DOI
# 9037                                                                          Creative Commons Attribution-NonCommercial-Share Alike 3.0 United States [CC BY-NC-SA 3.0]
# 9038                                                                                                                         \n      43.244 142.927 43.244 142.927\n
# 9039                                                                                                                                  \n      Pacific Ocean, Japan\n
# 9040                                                                                                                                                      Chemistry:Rock
#
# [9041 rows x 6 columns]

# %% [markdown]
# ###  Let's get rid of the columns we won't use for this analysis. We already know the organization and dialect after we have selected the organization and collection. The xpaths aren't needed as they are the xpaths that were looked for and in many cases are relative rather than the actual location within the record itself. I now can change this to actual path, which I believe is more useful....

# %%
CollectionConceptsDF.drop(['Collection','Dialect', 'XPath'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#           Record                            Concept  \
# 0     100004.xml                           Abstract
# 1     100004.xml                       Bounding Box
# 2     100004.xml                   Contributor Name
# 3     100004.xml                   Contributor Role
# 4     100004.xml                Distribution Format
# 5     100004.xml                         First Name
# 6     100004.xml                            Keyword
# 7     100004.xml                 Keyword Vocabulary
# 8     100004.xml                          Last Name
# 9     100004.xml                        Middle Name
# 10    100004.xml                   Publication Date
# 11    100004.xml                          Publisher
# 12    100004.xml        Related Resource Identifier
# 13    100004.xml    Resource Creation/Revision Date
# 14    100004.xml                    Resource Format
# 15    100004.xml                Resource Identifier
# 16    100004.xml                Resource Identifier
# 17    100004.xml           Resource Identifier Type
# 18    100004.xml                  Resource Language
# 19    100004.xml                     Resource Title
# 20    100004.xml                      Resource Type
# 21    100004.xml                   Resource Version
# 22    100004.xml       Responsible Party Identifier
# 23    100004.xml  Responsible Party Identifier Type
# 24    100004.xml                             Rights
# 25    100004.xml                     Spatial Extent
# 26    100004.xml                     Spatial Extent
# 27    100004.xml                      Theme Keyword
# 28    100031.xml                           Abstract
# 29    100031.xml     Author / Originator Identifier
# ...          ...                                ...
# 9011  100592.xml                            Keyword
# 9012  100592.xml                 Keyword Vocabulary
# 9013  100592.xml                          Last Name
# 9014  100592.xml                          Last Name
# 9015  100592.xml                          Last Name
# 9016  100592.xml                          Last Name
# 9017  100592.xml                          Last Name
# 9018  100592.xml                        Middle Name
# 9019  100592.xml                        Middle Name
# 9020  100592.xml                        Middle Name
# 9021  100592.xml                        Middle Name
# 9022  100592.xml                        Middle Name
# 9023  100592.xml                   Publication Date
# 9024  100592.xml                          Publisher
# 9025  100592.xml        Related Resource Identifier
# 9026  100592.xml    Resource Creation/Revision Date
# 9027  100592.xml                    Resource Format
# 9028  100592.xml                Resource Identifier
# 9029  100592.xml                Resource Identifier
# 9030  100592.xml           Resource Identifier Type
# 9031  100592.xml                  Resource Language
# 9032  100592.xml                     Resource Title
# 9033  100592.xml                      Resource Type
# 9034  100592.xml                   Resource Version
# 9035  100592.xml       Responsible Party Identifier
# 9036  100592.xml  Responsible Party Identifier Type
# 9037  100592.xml                             Rights
# 9038  100592.xml                     Spatial Extent
# 9039  100592.xml                     Spatial Extent
# 9040  100592.xml                      Theme Keyword
#
#                                                                                                                                                                  Content
# 0     Analyses of volatile, major, and trace elements for a suite of glasses and melt inclusions from the 85 degrees E segment of the ultra-slow spreading Gakkel Ridge.
# 1                                                                                                                                              Gakkel Ridge Arctic Ocean
# 2                                                                                                                                                EarthChem Library (ECL)
# 3                                                                                                                                                                 Editor
# 4                                                                                                                                               application/vnd.ms-excel
# 5                                                                                                                                                           Shaw, Alison
# 6                                                                                                                                                           Geochemistry
# 7                                                                                                                                                                    ECL
# 8                                                                                                                                                           Shaw, Alison
# 9                                                                                                                                                           Shaw, Alison
# 10                                                                                                                                                                  2011
# 11                                                                                                                             Integrated Earth Data Applications (IEDA)
# 12                                                                                                                                            10.1016/j.epsl.2009.11.018
# 13                                                                                                                                                            2011-03-25
# 14                                                                                                                                              application/vnd.ms-excel
# 15                                                                                                                                                   10.1594/IEDA/100004
# 16                                                                                                                   http://www.earthchem.org/library/browse/view?id=124
# 17                                                                                                                                                                   DOI
# 18                                                                                                                                                                    en
# 19                                                                                                              Gakkel Ridge basalt melt inclusion and mineral chemistry
# 20                                                                                                                                                               Dataset
# 21                                                                                                                                                                   1.0
# 22                                                                                                                                                       10.17616/R3V644
# 23                                                                                                                                                                   DOI
# 24                                                                            Creative Commons Attribution-NonCommercial-Share Alike 3.0 United States [CC BY-NC-SA 3.0]
# 25                                                                                                                         \n      85.5945 85.1788 85.6263 85.5817\n
# 26                                                                                                                               \n      Gakkel Ridge Arctic Ocean\n
# 27                                                                                                                                                          Geochemistry
# 28                                                                Hydrothermal vent fluid geochemistry from the Medusa vent, collected during cruise AT15-17, March 2007
# 29                                                                                                                                                               GeoPass
# ...                                                                                                                                                                  ...
# 9011                                                                                                                                                      Chemistry:Rock
# 9012                                                                                                                                                                 ECL
# 9013                                                                                                                                                    Du Vivier, Alice
# 9014                                                                                                                                                        Selby, David
# 9015                                                                                                                                                         Condon, Dan
# 9016                                                                                                                                                       Takashima, R.
# 9017                                                                                                                                                           Nishi, H.
# 9018                                                                                                                                                    Du Vivier, Alice
# 9019                                                                                                                                                        Selby, David
# 9020                                                                                                                                                         Condon, Dan
# 9021                                                                                                                                                       Takashima, R.
# 9022                                                                                                                                                           Nishi, H.
# 9023                                                                                                                                                                2016
# 9024                                                                                                                           Integrated Earth Data Applications (IEDA)
# 9025                                                                                                                                          10.1016/j.epsl.2015.07.020
# 9026                                                                                                                                                          2016-06-01
# 9027                                                                                                                                                     application/zip
# 9028                                                                                                                                                 10.1594/IEDA/100592
# 9029                                                                                                                 http://www.earthchem.org/library/browse/view?id=941
# 9030                                                                                                                                                                 DOI
# 9031                                                                                                                                                                 eng
# 9032                                                                                    U-Pb Geochronology from five volcanic tuffs from the Yezo Group, Hokkaido, Japan
# 9033                                                                                                                                                          Collection
# 9034                                                                                                                                                                 1.0
# 9035                                                                                                                                                     10.17616/R3V644
# 9036                                                                                                                                                                 DOI
# 9037                                                                          Creative Commons Attribution-NonCommercial-Share Alike 3.0 United States [CC BY-NC-SA 3.0]
# 9038                                                                                                                         \n      43.244 142.927 43.244 142.927\n
# 9039                                                                                                                                  \n      Pacific Ocean, Japan\n
# 9040                                                                                                                                                      Chemistry:Rock
#
# [9041 rows x 3 columns]

# %% [markdown]
# ### Now that we have the data we want, what are the understood concepts that exist in the collection?

# %%
ConceptVerticals=CollectionConceptsDF.Concept.unique()
Verticals=ConceptVerticals.tolist()
Verticals
# Out:
# ['Abstract',
#  'Bounding Box',
#  'Contributor Name',
#  'Contributor Role',
#  'Distribution Format',
#  'First Name',
#  'Keyword',
#  'Keyword Vocabulary',
#  'Last Name',
#  'Middle Name',
#  'Publication Date',
#  'Publisher',
#  'Related Resource Identifier',
#  'Resource Creation/Revision Date',
#  'Resource Format',
#  'Resource Identifier',
#  'Resource Identifier Type',
#  'Resource Language',
#  'Resource Title',
#  'Resource Type',
#  'Resource Version',
#  'Responsible Party Identifier',
#  'Responsible Party Identifier Type',
#  'Rights',
#  'Spatial Extent',
#  'Theme Keyword',
#  'Author / Originator Identifier']

# %% [markdown]
# ### Create function that allows us to call up metadata vertical content for a concept

# %%
def ConceptVerticalTable(Concept):
    global VerticalTable
    VerticalTable = CollectionConceptsDF[CollectionConceptsDF.Concept == Concept]
    return VerticalTable

# %% [markdown]
# ### Create a dropdown using the function that allows us to create a dataframe of the concept you want as a metadata vertical.

# %%
interact(ConceptVerticalTable, Concept=Verticals)
# Out:
#           Record  Concept             Content
# 6     100004.xml  Keyword        Geochemistry
# 37    100031.xml  Keyword     Chemistry:Fluid
# 68    100032.xml  Keyword        Geochemistry
# 97    100033.xml  Keyword        Geochemistry
# 125   100034.xml  Keyword        Geochemistry
# 153   100035.xml  Keyword        Geochemistry
# 182   100036.xml  Keyword        Geochemistry
# 222   100037.xml  Keyword        Geochemistry
# 270   100038.xml  Keyword        Geochemistry
# 297   100039.xml  Keyword        Geochemistry
# 325   100040.xml  Keyword        Geochemistry
# 354   100041.xml  Keyword        Geochemistry
# 385   100042.xml  Keyword        Geochemistry
# 413   100043.xml  Keyword        Geochemistry
# 447   100044.xml  Keyword        Geochemistry
# 485   100045.xml  Keyword        Geochemistry
# 532   100046.xml  Keyword        Geochemistry
# 594   100047.xml  Keyword        Geochemistry
# 622   100048.xml  Keyword        Geochemistry
# 649   100049.xml  Keyword        Geochemistry
# 687   100050.xml  Keyword        Geochemistry
# 730   100051.xml  Keyword        Geochemistry
# 763   100052.xml  Keyword        Geochemistry
# 805   100053.xml  Keyword        Geochemistry
# 845   100054.xml  Keyword        Geochemistry
# 874   100055.xml  Keyword        Geochemistry
# 901   100056.xml  Keyword        Geochemistry
# 933   100057.xml  Keyword        Geochemistry
# 970   100058.xml  Keyword        Geochemistry
# 1016  100059.xml  Keyword        Geochemistry
# ...          ...      ...                 ...
# 8184  100563.xml  Keyword     Chemistry:Fluid
# 8219  100564.xml  Keyword     Chemistry:Fluid
# 8254  100565.xml  Keyword     Chemistry:Fluid
# 8288  100566.xml  Keyword     Chemistry:Fluid
# 8322  100567.xml  Keyword     Chemistry:Fluid
# 8355  100568.xml  Keyword  Chemistry:Sediment
# 8390  100569.xml  Keyword  Chemistry:Sediment
# 8425  100570.xml  Keyword  Chemistry:Sediment
# 8458  100573.xml  Keyword     Chemistry:Fluid
# 8459  100573.xml  Keyword       Chemistry:Gas
# 8491  100574.xml  Keyword           Chemistry
# 8492  100574.xml  Keyword      Chemistry:Rock
# 8526  100575.xml  Keyword       Chemistry:Gas
# 8527  100575.xml  Keyword               Other
# 8564  100576.xml  Keyword  Chemistry:Sediment
# 8592  100577.xml  Keyword  Chemistry:Sediment
# 8624  100578.xml  Keyword  Chemistry:Sediment
# 8655  100579.xml  Keyword  Chemistry:Sediment
# 8686  100580.xml  Keyword  Chemistry:Sediment
# 8716  100581.xml  Keyword  Chemistry:Sediment
# 8749  100582.xml  Keyword       Chemistry:Gas
# 8785  100583.xml  Keyword      Chemistry:Rock
# 8814  100584.xml  Keyword      Chemistry:Rock
# 8843  100585.xml  Keyword       Geochronology
# 8878  100586.xml  Keyword  Chemistry:Sediment
# 8915  100587.xml  Keyword      Chemistry:Rock
# 8943  100588.xml  Keyword      Chemistry:Rock
# 8975  100589.xml  Keyword      Chemistry:Rock
# 8976  100589.xml  Keyword          SampleInfo
# 9011  100592.xml  Keyword      Chemistry:Rock
#
# [322 rows x 3 columns]

# %% [markdown]
# ### Let's group the unique values in the content column and count them up.

# %%
VerticalTable.groupby('Content').size()
# Out:
# Content
# Chemistry                 10
# Chemistry:Fluid           47
# Chemistry:Gas             33
# Chemistry:Rock            65
# Chemistry:Sediment        20
# Geochemistry              69
# Geochronology              8
# Kinetics                   2
# Other                     38
# Petrography                4
# Petrology                  7
# Petrology:Experimental     2
# Petrology:Mineral          3
# SampleInfo                13
# SocialScience              1
# dtype: int64

# %% [markdown]
# ### Remove colons from the values so there are no Bokeh Label errors. Use Bokeh to plot a bar chart of the unique values.

# %%
data = VerticalTable.Content.str.replace(':','.')

p = Bar(data, 'Content', title="Vertical Value Occurance Count", legend=False)

output_file("bar.html")

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'bar.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ca0b887d-b312-4977-ac55-22f2d7cedf39"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ca0b887d-b312-4977-ac55-22f2d7cedf39").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ca0b887d-b312-4977-ac55-22f2d7cedf39");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ca0b887d-b312-4977-ac55-22f2d7cedf39' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2ec33b6a-c1a2-4b9e-8a7f-3c83fb5e7597":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["Chemistry.Rock"],"chart_index":[{"Content":"Chemistry.Rock"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[65.0],"label":[{"Content":"Chemistry.Rock"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Chemistry.Rock"],"y":[32.5]}},"id":"d0e3c5ca-cd2d-420e-8a9e-b26eeaddb844","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9cad2003-cea6-48dd-b0b9-0abd92a8b132","type":"ColumnDataSource"},"glyph":{"id":"12cb6c89-05b3-4359-ab75-31b5b64e0ff2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cd314e90-2cf7-4304-8c15-1008e3afbd3d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["Petrology.Mineral"],"chart_index":[{"Content":"Petrology.Mineral"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":[{"Content":"Petrology.Mineral"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Petrology.Mineral"],"y":[1.5]}},"id":"9cad2003-cea6-48dd-b0b9-0abd92a8b132","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"6eafa489-1373-40dd-bc53-4e0f0c3c9ad1","type":"ColumnDataSource"},"glyph":{"id":"ee6ad894-20c9-4a07-95a6-d0bf00b337aa","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8dadcb4a-e500-4d29-9fb5-f45795d168ff","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"399df09c-de83-47f1-8d7d-fc9cc6e84984","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"780edc41-8b63-42f1-bab7-51bc66c94b5c","subtype":"Chart","type":"Plot"},"ticker":{"id":"0b6d9040-d4cb-45c0-b36a-d86996f25e1a","type":"BasicTicker"}},"id":"80c2e4cb-5510-415a-a179-50c004739e76","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d6a841a-cebe-49e9-bcc7-d6bfcc50a78f","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["Chemistry.Gas"],"chart_index":[{"Content":"Chemistry.Gas"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[33.0],"label":[{"Content":"Chemistry.Gas"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Chemistry.Gas"],"y":[16.5]}},"id":"21d9d685-b3d2-4ec9-bc50-eb8f9796124e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d286f074-dedf-45ae-a70d-661d3d42205d","type":"ColumnDataSource"},"glyph":{"id":"d57e2d47-b812-4e64-9be9-24cf517ceb1b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4fddafd2-48bc-485c-be68-bf1c48bb320b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"21d9d685-b3d2-4ec9-bc50-eb8f9796124e","type":"ColumnDataSource"},"glyph":{"id":"1d6a841a-cebe-49e9-bcc7-d6bfcc50a78f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"04ce527f-e8f5-4502-bafd-3bb10d0c25b9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Content":["Chemistry.Fluid"],"chart_index":[{"Content":"Chemistry.Fluid"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[47.0],"label":[{"Content":"Chemistry.Fluid"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Chemistry.Fluid"],"y":[23.5]}},"id":"d286f074-dedf-45ae-a70d-6 ...
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: NASA/GCMD Instrument Keywords NASA GCMD User Support Office gcmduso@gcmd.gsfc.nasa.gov http://gcmd.nasa.gov/MailComments/MailComments.jsf?rcpt=gcmduso GCMD Feedback Form Have a Comment for the GCMD? information custodian http://gcmd.nasa.gov/Resources/valids/ GCMD Keywords Page This page describes the NASA GCMD Keywords, how to reference those keywords and provides download instructions. information custodian] [renderer: Chart(id='b15b37c3-01db-4970-8fd6-e8e467d239c6', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: NASA Global Change Master Directory, Goddard Space Flight Center Greenbelt MD 20771 USA gcmduso@gcmd.gsfc.nasa.gov http://gcmd.nasa.gov/Resources/valids/ http web browser NASA Global Change Master Directory (GCMD) Keyword Page This page describes the NASA GCMD Keywords, how to reference those keywords and provides download instructions. download http://gcmd.nasa.gov/MailComments/MailComments.jsf?rcpt=gcmduso] [renderer: Chart(id='c8a9f467-b999-4bdd-a251-b6a56b889b9d', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: 1978-01-01T00:00:00.000Z] [renderer: Chart(id='e84099c3-b624-4813-b4f6-f488d7f113d6', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: 1978-01-01T00:00:00.000Z] [renderer: Chart(id='3e405044-1040-416d-bd88-50ca5a3918c6', ...)]
# WARNING:/Applications/anaconda/lib/python3.6/site-packages/bokeh/core/validation/check.py:W-1003 (MALFORMED_CATEGORY_LABEL): Category labels cannot contain colons: [range:x_range] [first_value: 1978-01-01T00:00:00.000Z] [renderer: Chart(id='45ae3e5f-c3de-4d33-974e-5470698a04f1', ...)]
