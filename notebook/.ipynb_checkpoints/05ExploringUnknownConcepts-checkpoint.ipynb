# %% [markdown]
# ### This notebook allows the user to look at all the content that is not defined by the Evaluator service. The notebook uses the data prepared by the Evaluator service. It can be used to identify the improvements in the concept crosswalks the Evaluator is created from.

# %% [markdown]
# Import the python packages needed

# %%
import pandas as pd
import os
from os import walk
import fnmatch
from ipywidgets import *
import ipywidgets as widgets
pd.options.display.max_colwidth=200

# %% [markdown]
# 1. Query the data directory for evaluated data and use the results to populate a list
# 2. Function that reads the selected csv into a dataframe

# %%
# 1.
DataFiles=[]
for path, subdirectories, filenames in os.walk('../data/'):
    for filename in filenames:
        if fnmatch.fnmatch(filename, '*Evaluated*.csv.gz'):
            DataFiles.append(os.path.join(path,filename).split("../data/", 1)[-1])
# 2.    
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join('../data', DataFile), compression='gzip')
    return CollectionConceptsDF

# %% [markdown]
# ### Choose the data you want to examine.

# %%
#Choose the CSV you want to examine by using the list of csv in a dropdown menu and using the result in the DataChoices function.
interactive(DataChoices, DataFile=DataFiles)

# %%
#CollectionConceptsDF.drop(['Record','Collection','Dialect'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#                      Concept  \
# 0                   Abstract
# 1            Acknowledgement
# 2            Acknowledgement
# 3                    Address
# 4                    Address
# 5                    Address
# 6                    Address
# 7                    Address
# 8             AssociatedDIFs
# 9             AssociatedDIFs
# 10               Association
# 11               Association
# 12      Attribute Definition
# 13      Attribute Definition
# 14      Attribute Definition
# 15      Attribute Definition
# 16      Attribute Definition
# 17      Attribute Definition
# 18      Attribute Definition
# 19      Attribute Definition
# 20      Attribute Definition
# 21      Attribute Definition
# 22      Attribute Definition
# 23      Attribute Definition
# 24      Attribute Definition
# 25      Attribute Definition
# 26      Attribute Definition
# 27      Attribute Definition
# 28      Attribute Definition
# 29           Attribute Label
# ...                      ...
# 133489               Unknown
# 133490               Unknown
# 133491               Unknown
# 133492               Unknown
# 133493               Unknown
# 133494               Unknown
# 133495               Unknown
# 133496               Unknown
# 133497               Unknown
# 133498               Unknown
# 133499               Unknown
# 133500               Unknown
# 133501               Unknown
# 133502               Unknown
# 133503               Unknown
# 133504               Unknown
# 133505               Unknown
# 133506               Unknown
# 133507               Unknown
# 133508               Unknown
# 133509               Unknown
# 133510               Unknown
# 133511               Unknown
# 133512               Unknown
# 133513               Unknown
# 133514               Unknown
# 133515               Unknown
# 133516               Unknown
# 133517               Unknown
# 133518               Unknown
#
#                                                                                                                                                                                                         Content  \
# 0       Nanomolar concentrations of PO4, NO3, NO2 (surface) Dataset Description: &lt;p&gt;Nanomolar concentrations of PO4, NO3, NO2 - Surface Transects.&lt;/p&gt;&lt;p&gt;Please note that some US GEOTRACE...
# 1                                                         Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926423 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926423
# 2                                                         Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926092 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926092
# 3                                                                                                                                                                                                    WHOI MS#36
# 4                                                                                                                                         Department of Ocean, Earth, and Atmospheric Sciences 4500 Elkhorn Ave
# 5                                                                                                                                                                                                    WHOI MS#36
# 6                                                                                                                                                                                                    WHOI MS#36
# 7                                                                                                                                                                                                    WHOI MS#36
# 8                                                                                                                                                                                                U.S. GEOTRACES
# 9                                                                                                                                                                                            U.S. GEOTRACES NAT
# 10      U.S. GEOTRACES http://www.geotraces.org/ U.S. GEOTRACES GEOTRACES is a SCOR sponsored program; and funding for program infrastructure development is provided by the U.S. National Science Foundatio...
# 11      U.S. GEOTRACES North Atlantic Transect http://www.geotraces.org/ U.S. GEOTRACES North Atlantic Transect http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/GEOTRACES_Atl_stas.jpg U.S. GEOTRACES N...
# 12                                                           PI-supplied Description: Official cruise identifier e.g. KN199-04 = R/V Knorr cruise number 199-04.; General Description: cruise designation; name
# 13      PI-supplied Description: date (GMT); General Description: date; generally reported in GMT as YYYYMMDD (year; month; day); also as MMDD (month; day); EqPac dates are local Hawaii time NERC Descript...
# 14      PI-supplied Description: time (GMT); General Description: Time GMT defined as HHMM; time of day; generally reported in GMT as HHMM (hours and minutes) but may also be HH.H (decimal hours) or HHMMS...
# 15      PI-supplied Description: Station latitude (South is negative); General Description: latitude, in decimal degrees, North is positive, negative denotes South; Reported in some datasets as degrees, m...
# 16      PI-supplied Description: Station longitude (West is negative); General Description: longitude, in decimal degrees, East is positive, negative denotes West; Reported in some datsets as degrees, min...
# 17      PI-supplied Description: Identifying number of a GeoFish tow, numbered consecutively within a cruise. PI-supplied values were identical to those in the intermediate US GEOTRACES master file.Origin...
# 18      PI-supplied Description: Unique identifiers for ALL vertical profile samples (and surface fish samples when we arrive on station, or depart).; General Description: dataset_id: a unique combination...
# 19                              PI-supplied Description: PO4: phosphate (reactive - or ortho-phosphate); General Description: Orthophosphate, (phosphate, reactive phosphorus) µM (micromolar) or °g-at PO4-P/l
# 20      PI-supplied Description: PO4 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); General Description: Data flag. Multiple uses whic...
# 21                                                                                                            PI-supplied Description: NO3: Nitrate = (Nitrate+nitrite) - nitrite; General Description: Nitrate
# 22      PI-supplied Description: NO3 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); General Description: Data flag. Multiple uses whic...
# 23      PI-supplied Description: NO2: Nitrite; General Description: Nitrite NERC Description: The phase is described as unknown to indicate that there is no information on whether the determination was on...
# 24      PI-supplied Description: NO2 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); General Description: Data flag. Multiple uses whic...
# 25                                                                                   PI-supplied Description: Remarks; General Description: operation performed and/or sampling method for given sampling event
# 26      PI-supplied Description: Unique identifying number for US GEOTRACES sampling events; ranges from 2001 to 2225 for KN199-04 events and from 3001 to 3282 for KN204-01 events. Values were added from ...
# 27      PI-supplied Description: Unique identifying number for US GEOTRACES samples; ranges from 5033 to 6078 for KN199-04 and from 6112 to 8148 for KN204-01.Values were added from the intermediate US GEO...
# 28      PI-supplied Description: Date/Time (UTC) formatted to ISO8601. T indicates start of time string; Z indicates UTC. Calculated from the original date and time fields.; General Description: Date/Time...
# 29                                                                                                                                                                                                    cruise_id
# ...                                                                                                                                                                                                         ...
# 133489                                                                                                                                                                                                   Cruise
# 133490                                                                                                                                                                                                onRequest
# 133491                                                                                                                                                                                                  unknown
# 133492                                                                                                                                                                                    Dr William J. Jenkins
# 133493                                                                                                                                                               http://lod.bco-dmo.org/id/person/50745.rdf
# 133494                                                                                                                                                                                                onRequest
# 133495                                                                                                                                                                     Woods Hole Oceanographic Institution
# 133496                                                                                                                                                              http://lod.bco-dmo.org/id/affiliation/2.rdf
# 133497                                                                                                                                                                                              Affiliation
# 133498                                                                                                                                                                                                onRequest
# 133499                                                                                                            http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/Cruise_Report_for_Knorr_199_Final_v3.pdf
# 133500                                                                                                                                                                               Report describing KN199-04
# 133501                                                                                                                             http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#CI_RoleCode
# 133502                                                                                                                                                                                    principalInvestigator
# 133503                                                                                                                                                                                         Cruise: KN199-05
# 133504                                                                                                                                                                                                 KN199-05
# 133505                                                                                                                                                           http://lod.bco-dmo.org/id/deployment/58142.rdf
# 133506                                                                                                                                                                                                 KN199-05
# 133507                                                                                                                                                           http://lod.bco-dmo.org/id/deployment/58142.rdf
# 133508                                                                                                                                                                                         Cruise: KN204-01
# 133509                                                                                                                                                                                                 KN204-01
# 133510                                                                                                                                                           http://lod.bco-dmo.org/id/deployment/58786.rdf
# 133511                                                                                                                                                                                                 KN204-01
# 133512                                                                                                                                                           http://lod.bco-dmo.org/id/deployment/58786.rdf
# 133513                                                                                                                                                                                       Dr Edward A. Boyle
# 133514                                                                                                                                                               http://lod.bco-dmo.org/id/person/50984.rdf
# 133515                                                                                                                                                                    Massachusetts Institute of Technology
# 133516                                                                                                                                                            http://lod.bco-dmo.org/id/affiliation/222.rdf
# 133517                                                                                                                             http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/STS_Prelim_GT11_Doc.pdf
# 133518                                                                                                                                                                               Report describing KN204-01
#
#                     Record  \
# 0         dataset_3470.xml
# 1         dataset_3470.xml
# 2         dataset_3470.xml
# 3         dataset_3470.xml
# 4         dataset_3470.xml
# 5         dataset_3470.xml
# 6         dataset_3470.xml
# 7         dataset_3470.xml
# 8         dataset_3470.xml
# 9         dataset_3470.xml
# 10        dataset_3470.xml
# 11        dataset_3470.xml
# 12        dataset_3470.xml
# 13        dataset_3470.xml
# 14        dataset_3470.xml
# 15        dataset_3470.xml
# 16        dataset_3470.xml
# 17        dataset_3470.xml
# 18        dataset_3470.xml
# 19        dataset_3470.xml
# 20        dataset_3470.xml
# 21        dataset_3470.xml
# 22        dataset_3470.xml
# 23        dataset_3470.xml
# 24        dataset_3470.xml
# 25        dataset_3470.xml
# 26        dataset_3470.xml
# 27        dataset_3470.xml
# 28        dataset_3470.xml
# 29        dataset_3470.xml
# ...                    ...
# 133489  dataset_651138.xml
# 133490  dataset_651138.xml
# 133491  dataset_651138.xml
# 133492  dataset_651138.xml
# 133493  dataset_651138.xml
# 133494  dataset_651138.xml
# 133495  dataset_651138.xml
# 133496  dataset_651138.xml
# 133497  dataset_651138.xml
# 133498  dataset_651138.xml
# 133499  dataset_651138.xml
# 133500  dataset_651138.xml
# 133501  dataset_651138.xml
# 133502  dataset_651138.xml
# 133503  dataset_651138.xml
# 133504  dataset_651138.xml
# 133505  dataset_651138.xml
# 133506  dataset_651138.xml
# 133507  dataset_651138.xml
# 133508  dataset_651138.xml
# 133509  dataset_651138.xml
# 133510  dataset_651138.xml
# 133511  dataset_651138.xml
# 133512  dataset_651138.xml
# 133513  dataset_651138.xml
# 133514  dataset_651138.xml
# 133515  dataset_651138.xml
# 133516  dataset_651138.xml
# 133517  dataset_651138.xml
# 133518  dataset_651138.xml
#
#                                                                                                                XPath
# 0                                                                                       /identificationInfo/abstract
# 1                                                                                         /identificationInfo/credit
# 2                                                                                         /identificationInfo/credit
# 3                                                                         /contact/contactInfo/address/deliveryPoint
# 4                                               /identificationInfo/pointOfContact/contactInfo/address/deliveryPoint
# 5                      /contentInfo/featureCatalogueCitation/citedResponsibleParty/contactInfo/address/deliveryPoint
# 6                                 /distributionInfo/distributor/distributorContact/contactInfo/address/deliveryPoint
# 7                                                     /metadataMaintenance/contact/contactInfo/address/deliveryPoint
# 8                                                /identificationInfo/aggregationInfo/aggregateDataSetIdentifier/code
# 9                                                /identificationInfo/aggregationInfo/aggregateDataSetIdentifier/code
# 10                                                                              /identificationInfo/aggregationInfo/
# 11                                                                              /identificationInfo/aggregationInfo/
# 12                                                                                 /contentInfo/dimension/descriptor
# 13                                                                                 /contentInfo/dimension/descriptor
# 14                                                                                 /contentInfo/dimension/descriptor
# 15                                                                                 /contentInfo/dimension/descriptor
# 16                                                                                 /contentInfo/dimension/descriptor
# 17                                                                                 /contentInfo/dimension/descriptor
# 18                                                                                 /contentInfo/dimension/descriptor
# 19                                                                                 /contentInfo/dimension/descriptor
# 20                                                                                 /contentInfo/dimension/descriptor
# 21                                                                                 /contentInfo/dimension/descriptor
# 22                                                                                 /contentInfo/dimension/descriptor
# 23                                                                                 /contentInfo/dimension/descriptor
# 24                                                                                 /contentInfo/dimension/descriptor
# 25                                                                                 /contentInfo/dimension/descriptor
# 26                                                                                 /contentInfo/dimension/descriptor
# 27                                                                                 /contentInfo/dimension/descriptor
# 28                                                                                 /contentInfo/dimension/descriptor
# 29                                                        /contentInfo/dimension/sequenceIdentifier/MemberName/aName
# ...                                                                                                              ...
# 133489                                     /acquisitionInformation/operation/plan/citation/title/Anchor/@xlink:title
# 133490                                   /acquisitionInformation/operation/plan/citation/title/Anchor/@xlink:actuate
# 133491                                           /acquisitionInformation/operation/plan/citation/date/@gco:nilReason
# 133492                   /acquisitionInformation/operation/plan/citation/citedResponsibleParty/individualName/Anchor
# 133493       /acquisitionInformation/operation/plan/citation/citedResponsibleParty/individualName/Anchor/@xlink:href
# 133494    /acquisitionInformation/operation/plan/citation/citedResponsibleParty/individualName/Anchor/@xlink:actuate
# 133495                 /acquisitionInformation/operation/plan/citation/citedResponsibleParty/organisationName/Anchor
# 133496     /acquisitionInformation/operation/plan/citation/citedResponsibleParty/organisationName/Anchor/@xlink:href
# 133497    /acquisitionInformation/operation/plan/citation/citedResponsibleParty/organisationName/Anchor/@xlink:title
# 133498  /acquisitionInformation/operation/plan/citation/citedResponsibleParty/organisationName/Anchor/@xlink:actuate
# 133499  /acquisitionInformation/operation/plan/citation/citedResponsibleParty/contactInfo/onlineResource/linkage/URL
# 133500  /acquisitionInformation/operation/plan/citation/citedResponsibleParty/contactInfo/onlineResource/description
# 133501                          /acquisitionInformation/operation/plan/citation/citedResponsibleParty/role/@codeList
# 133502                     /acquisitionInformation/operation/plan/citation/citedResponsibleParty/role/@codeListValue
# 133503                                                                 /acquisitionInformation/operation/description
# 133504                                                      /acquisitionInformation/operation/identifier/code/Anchor
# 133505                                          /acquisitionInformation/operation/identifier/code/Anchor/@xlink:href
# 133506                                                  /acquisitionInformation/operation/plan/citation/title/Anchor
# 133507                                      /acquisitionInformation/operation/plan/citation/title/Anchor/@xlink:href
# 133508                                                                 /acquisitionInformation/operation/description
# 133509                                                      /acquisitionInformation/operation/identifier/code/Anchor
# 133510                                          /acquisitionInformation/operation/identifier/code/Anchor/@xlink:href
# 133511                                                  /acquisitionInformation/operation/plan/citation/title/Anchor
# 133512                                      /acquisitionInformation/operation/plan/citation/title/Anchor/@xlink:href
# 133513                   /acquisitionInformation/operation/plan/citation/citedResponsibleParty/individualName/Anchor
# 133514       /acquisitionInformation/operation/plan/citation/citedResponsibleParty/individualName/Anchor/@xlink:href
# 133515                 /acquisitionInformation/operation/plan/citation/citedResponsibleParty/organisationName/Anchor
# 133516     /acquisitionInformation/operation/plan/citation/citedResponsibleParty/organisationName/Anchor/@xlink:href
# 133517  /acquisitionInformation/operation/plan/citation/citedResponsibleParty/contactInfo/onlineResource/linkage/URL
# 133518  /acquisitionInformation/operation/plan/citation/citedResponsibleParty/contactInfo/onlineResource/description
#
# [133519 rows x 4 columns]

# %% [markdown]
# Create a slice of the dataframe that contains just rows where Unknown is in the Concept Column.

# %%
UnknownTableDF = CollectionConceptsDF[CollectionConceptsDF.Concept == "Unknown"]
UnknownTableDF
# Out:
#      Collection Dialect              Record  Concept  \
# 0     LTER_2013     EML  00087-metadata.xml  Unknown
# 1     LTER_2013     EML  00087-metadata.xml  Unknown
# 2     LTER_2013     EML  00087-metadata.xml  Unknown
# 8     LTER_2013     EML  00087-metadata.xml  Unknown
# 52    LTER_2013     EML  00087-metadata.xml  Unknown
# 55    LTER_2013     EML  00087-metadata.xml  Unknown
# 58    LTER_2013     EML  00087-metadata.xml  Unknown
# 60    LTER_2013     EML  00087-metadata.xml  Unknown
# 61    LTER_2013     EML  00087-metadata.xml  Unknown
# 62    LTER_2013     EML  00087-metadata.xml  Unknown
# 63    LTER_2013     EML  00087-metadata.xml  Unknown
# 64    LTER_2013     EML  00087-metadata.xml  Unknown
# 65    LTER_2013     EML  00087-metadata.xml  Unknown
# 66    LTER_2013     EML  00087-metadata.xml  Unknown
# 67    LTER_2013     EML  00087-metadata.xml  Unknown
# 68    LTER_2013     EML  00087-metadata.xml  Unknown
# 69    LTER_2013     EML  00087-metadata.xml  Unknown
# 70    LTER_2013     EML  00087-metadata.xml  Unknown
# 71    LTER_2013     EML  00087-metadata.xml  Unknown
# 72    LTER_2013     EML  00087-metadata.xml  Unknown
# 73    LTER_2013     EML  00087-metadata.xml  Unknown
# 74    LTER_2013     EML  00087-metadata.xml  Unknown
# 75    LTER_2013     EML  00058-metadata.xml  Unknown
# 76    LTER_2013     EML  00058-metadata.xml  Unknown
# 77    LTER_2013     EML  00058-metadata.xml  Unknown
# 124   LTER_2013     EML  00058-metadata.xml  Unknown
# 125   LTER_2013     EML  00058-metadata.xml  Unknown
# 126   LTER_2013     EML  00058-metadata.xml  Unknown
# 127   LTER_2013     EML  00058-metadata.xml  Unknown
# 128   LTER_2013     EML  00058-metadata.xml  Unknown
# ...         ...     ...                 ...      ...
# 8645  LTER_2013     EML  00063-metadata.xml  Unknown
# 8646  LTER_2013     EML  00063-metadata.xml  Unknown
# 8647  LTER_2013     EML  00063-metadata.xml  Unknown
# 8648  LTER_2013     EML  00063-metadata.xml  Unknown
# 8649  LTER_2013     EML  00063-metadata.xml  Unknown
# 8650  LTER_2013     EML  00049-metadata.xml  Unknown
# 8651  LTER_2013     EML  00049-metadata.xml  Unknown
# 8652  LTER_2013     EML  00049-metadata.xml  Unknown
# 8658  LTER_2013     EML  00049-metadata.xml  Unknown
# 8686  LTER_2013     EML  00049-metadata.xml  Unknown
# 8689  LTER_2013     EML  00049-metadata.xml  Unknown
# 8692  LTER_2013     EML  00049-metadata.xml  Unknown
# 8694  LTER_2013     EML  00049-metadata.xml  Unknown
# 8695  LTER_2013     EML  00049-metadata.xml  Unknown
# 8696  LTER_2013     EML  00049-metadata.xml  Unknown
# 8697  LTER_2013     EML  00049-metadata.xml  Unknown
# 8698  LTER_2013     EML  00049-metadata.xml  Unknown
# 8699  LTER_2013     EML  00049-metadata.xml  Unknown
# 8700  LTER_2013     EML  00049-metadata.xml  Unknown
# 8701  LTER_2013     EML  00049-metadata.xml  Unknown
# 8702  LTER_2013     EML  00049-metadata.xml  Unknown
# 8703  LTER_2013     EML  00096-metadata.xml  Unknown
# 8704  LTER_2013     EML  00096-metadata.xml  Unknown
# 8705  LTER_2013     EML  00096-metadata.xml  Unknown
# 8706  LTER_2013     EML  00096-metadata.xml  Unknown
# 8712  LTER_2013     EML  00096-metadata.xml  Unknown
# 8747  LTER_2013     EML  00096-metadata.xml  Unknown
# 8748  LTER_2013     EML  00096-metadata.xml  Unknown
# 8751  LTER_2013     EML  00096-metadata.xml  Unknown
# 8752  LTER_2013     EML  00096-metadata.xml  Unknown
#
#                                                                                                                                                        Content  \
# 0                                                                                                                                         knb-lter-arc.10422.4
# 1                                                                                                                                                          knb
# 2                                                                      eml://ecoinformatics.org/eml-2.1.0 http://nis.lternet.edu/schemas/EML/eml-2.1.0/eml.xsd
# 8                                                                                                                             20102012_CSASN_PointTransects.04
# 52                                                                                                                           20102012_CSASN_PointTransects.csv
# 55                                                                                                                           20102012_CSASN_PointTransects.csv
# 58          http://metacat.lternet.edu/das/dataAccessServlet?docid=knb-lter-arc.10422&urlTail=csasn/ChangingSeasonality/data/20102012_CSASN_PointTransects.csv
# 60                                                                                                                                                         196
# 61                                                                                                                          20102012_CSASN_PointTransects.xlsx
# 62                                                                                               An excel file that has worksheets with the metadata and data.
# 63                                                                                                                                                    document
# 64                                                                                                                          20102012_CSASN_PointTransects.xlsx
# 65                                                                                                                                             Microsoft Excel
# 66                                                                                                                                                    document
# 67     http://metacat.lternet.edu/das/dataAccessServlet?docid=knb-lter-arc.10422&urlTail=csasn/ChangingSeasonality/xlsfiles/20102012_CSASN_PointTransects.xlsx
# 68                                                                                                                                        Microsoft Excel file
# 69                                                                                                                                                     percent
# 70                                                                                                                                                           1
# 71                                                                                                                                                     percent
# 72                                                                                                                                                         NaN
# 73                                                                                                                                               dimensionless
# 74                                                                                                      ratio of two quantities as percent composition (1:100)
# 75                                                                                                                                          knb-lter-pie.257.1
# 76                                                                                                                                                         knb
# 77                                                                     eml://ecoinformatics.org/eml-2.1.0 http://nis.lternet.edu/schemas/EML/eml-2.1.0/eml.xsd
# 124                                                                                                                               GIS_ip30_info_anderson1_1971
# 125   This layer shows land use for the Ipswich Study area, based upon MassGIS classification and grouped in accordance with the Anderson: Level I convention.
# 126                                                                                                                           GIS_ip30_info_anderson1_1971.zip
# 127                                                                                                                                                        zip
# 128                                                                              http://pie-lter.ecosystems.mbl.edu/files/gis/GIS_ip30_info_anderson1_1971.zip
# ...                                                                                                                                                        ...
# 8645                                                                                                                                                         1
# 8646                                                                                                                     microEinsteinPerMeterSquaredPerSecond
# 8647                                                                                                                                                       NaN
# 8648                                                                                                                                               illuminance
# 8649                                                                    micromoles (1E-06 moles of photons) per square meter per second (radiant flux density)
# 8650                                                                                                                                      knb-lter-arc.10467.1
# 8651                                                                                                                                                       knb
# 8652                                                                   eml://ecoinformatics.org/eml-2.1.0 http://nis.lternet.edu/schemas/EML/eml-2.1.0/eml.xsd
# 8658                                                                                                                                        IM2_GT01dot02_temp
# 8686                                                                                                                             20092012_GT_IM2_GT01dot02.csv
# 8689                                                                                                                             20092012_GT_IM2_GT01dot02.csv
# 8692                     http://metacat.lternet.edu/das/dataAccessServlet?docid=knb-lter-arc.10467&urlTail=thermokarst/soil/data/20092012_GT_IM2_GT01dot02.csv
# 8694                                                                                                                                                     27313
# 8695                                                                                                                            20092012_GT_IM2_GT01dot02.xlsx
# 8696                                                                                             An excel file that has worksheets with the metadata and data.
# 8697                                                                                                                                                  document
# 8698                                                                                                                            20092012_GT_IM2_GT01dot02.xlsx
# 8699                                                                                                                                           Microsoft Excel
# 8700                                                                                                                                                  document
# 8701                http://metacat.lternet.edu/das/dataAccessServlet?docid=knb-lter-arc.10467&urlTail=thermokarst/soil/xlsfiles/20092012_GT_IM2_GT01dot02.xlsx
# 8702                                                                                                                                      Microsoft Excel file
# 8703                                                                                                                                         knb-lter-mcm.74.1
# 8704                                                                                                                                                    system
# 8705                                                                                                                                                       knb
# 8706                                                                   eml://ecoinformatics.org/eml-2.1.0 http://nis.lternet.edu/schemas/EML/eml-2.1.0/eml.xsd
# 8712                                                                                                                                                ADCP-ID.74
# 8747                                                                                                        LIMNO_ANCILLARY_ADCP_Units_And_Column_Descriptions
# 8748                                                                                                        LIMNO_ANCILLARY_ADCP_Units_And_Column_Descriptions
# 8751                                            http://mcmlter.org/queries/limno_adcp_results.jsp?begDate=09/09/2009&endDate=05/05/2010&minDepth=0&maxDepth=15
# 8752                                                                                                                                                  download
#
#                                                                                       XPath  \
# 0                                                                       /eml:eml/@packageId
# 1                                                                          /eml:eml/@system
# 2                                                              /eml:eml/@xsi:schemaLocation
# 8                                                      /eml:eml/dataset/alternateIdentifier
# 52                                                    /eml:eml/dataset/dataTable/entityName
# 55                                           /eml:eml/dataset/dataTable/physical/objectName
# 58                              /eml:eml/dataset/dataTable/physical/distribution/online/url
# 60                                               /eml:eml/dataset/dataTable/numberOfRecords
# 61                                                  /eml:eml/dataset/otherEntity/entityName
# 62                                           /eml:eml/dataset/otherEntity/entityDescription
# 63                                             /eml:eml/dataset/otherEntity/physical/@scope
# 64                                         /eml:eml/dataset/otherEntity/physical/objectName
# 65      /eml:eml/dataset/otherEntity/physical/dataFormat/externallyDefinedFormat/formatName
# 66                                /eml:eml/dataset/otherEntity/physical/distribution/@scope
# 67                            /eml:eml/dataset/otherEntity/physical/distribution/online/url
# 68                                                  /eml:eml/dataset/otherEntity/entityType
# 69                                   /eml:eml/additionalMetadata/metadata/unitList/unit/@id
# 70                       /eml:eml/additionalMetadata/metadata/unitList/unit/@multiplierToSI
# 71                                 /eml:eml/additionalMetadata/metadata/unitList/unit/@name
# 72                             /eml:eml/additionalMetadata/metadata/unitList/unit/@parentSI
# 73                             /eml:eml/additionalMetadata/metadata/unitList/unit/@unitType
# 74                           /eml:eml/additionalMetadata/metadata/unitList/unit/description
# 75                                                                      /eml:eml/@packageId
# 76                                                                         /eml:eml/@system
# 77                                                             /eml:eml/@xsi:schemaLocation
# 124                                               /eml:eml/dataset/spatialRaster/entityName
# 125                                        /eml:eml/dataset/spatialRaster/entityDescription
# 126                                      /eml:eml/dataset/spatialRaster/physical/objectName
# 127   /eml:eml/dataset/spatialRaster/physical/dataFormat/externallyDefinedFormat/formatName
# 128                         /eml:eml/dataset/spatialRaster/physical/distribution/online/url
# ...                                                                                     ...
# 8645                     /eml:eml/additionalMetadata/metadata/unitList/unit/@multiplierToSI
# 8646                               /eml:eml/additionalMetadata/metadata/unitList/unit/@name
# 8647                           /eml:eml/additionalMetadata/metadata/unitList/unit/@parentSI
# 8648                           /eml:eml/additionalMetadata/metadata/unitList/unit/@unitType
# 8649                         /eml:eml/additionalMetadata/metadata/unitList/unit/description
# 8650                                                                    /eml:eml/@packageId
# 8651                                                                       /eml:eml/@system
# 8652                                                           /eml:eml/@xsi:schemaLocation
# 8658                                                   /eml:eml/dataset/alternateIdentifier
# 8686                                                  /eml:eml/dataset/dataTable/entityName
# 8689                                         /eml:eml/dataset/dataTable/physical/objectName
# 8692                            /eml:eml/dataset/dataTable/physical/distribution/online/url
# 8694                                             /eml:eml/dataset/dataTable/numberOfRecords
# 8695                                                /eml:eml/dataset/otherEntity/entityName
# 8696                                         /eml:eml/dataset/otherEntity/entityDescription
# 8697                                           /eml:eml/dataset/otherEntity/physical/@scope
# 8698                                       /eml:eml/dataset/otherEntity/physical/objectName
# 8699    /eml:eml/dataset/otherEntity/physical/dataFormat/externallyDefinedFormat/formatName
# 8700                              /eml:eml/dataset/otherEntity/physical/distribution/@scope
# 8701                          /eml:eml/dataset/otherEntity/physical/distribution/online/url
# 8702                                                /eml:eml/dataset/otherEntity/entityType
# 8703                                                                    /eml:eml/@packageId
# 8704                                                                        /eml:eml/@scope
# 8705                                                                       /eml:eml/@system
# 8706                                                           /eml:eml/@xsi:schemaLocation
# 8712                                                             /eml:eml/dataset/shortName
# 8747                                                  /eml:eml/dataset/dataTable/entityName
# 8748                                         /eml:eml/dataset/dataTable/physical/objectName
# 8751                            /eml:eml/dataset/dataTable/physical/distribution/online/url
# 8752                  /eml:eml/dataset/dataTable/physical/distribution/online/url/@function
#
#      DialectDefinition
# 0            Undefined
# 1            Undefined
# 2            Undefined
# 8            Undefined
# 52           Undefined
# 55           Undefined
# 58           Undefined
# 60           Undefined
# 61           Undefined
# 62           Undefined
# 63           Undefined
# 64           Undefined
# 65           Undefined
# 66           Undefined
# 67           Undefined
# 68           Undefined
# 69           Undefined
# 70           Undefined
# 71           Undefined
# 72           Undefined
# 73           Undefined
# 74           Undefined
# 75           Undefined
# 76           Undefined
# 77           Undefined
# 124          Undefined
# 125          Undefined
# 126          Undefined
# 127          Undefined
# 128          Undefined
# ...                ...
# 8645         Undefined
# 8646         Undefined
# 8647         Undefined
# 8648         Undefined
# 8649         Undefined
# 8650         Undefined
# 8651         Undefined
# 8652         Undefined
# 8658         Undefined
# 8686         Undefined
# 8689         Undefined
# 8692         Undefined
# 8694         Undefined
# 8695         Undefined
# 8696         Undefined
# 8697         Undefined
# 8698         Undefined
# 8699         Undefined
# 8700         Undefined
# 8701         Undefined
# 8702         Undefined
# 8703         Undefined
# 8704         Undefined
# 8705         Undefined
# 8706         Undefined
# 8712         Undefined
# 8747         Undefined
# 8748         Undefined
# 8751         Undefined
# 8752         Undefined
#
# [3704 rows x 7 columns]

# %% [markdown]
# ## Select a specific XPath and look at all of the examples in the collection

# %% [markdown]
# Create a unique list of XPaths

# %%
XPathVerticals=UnknownTableDF.XPath.unique()
Verticals=XPathVerticals.tolist()
Verticals
# Out:
# ['/gmi:MI_Metadata/@xsi:schemaLocation',
#  '/gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode',
#  '/gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode/@codeList',
#  '/gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode/@codeListValue',
#  '/gmi:MI_Metadata/gmd:hierarchyLevelName/gco:CharacterString',
#  '/gmi:MI_Metadata/gmd:referenceSystemInfo/@xlink:href',
#  '/gmi:MI_Metadata/gmd:referenceSystemInfo/@xlink:title',
#  '/gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString',
#  '/gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:extent/gmd:EX_Extent/@id',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmd:MD_FeatureCatalogueDescription/gmd:includedWithDataset/gco:Boolean',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:attributeDescription/gco:RecordType',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/@xlink:href',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/@xlink:title',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/@xlink:actuate',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/gco:MemberName/gco:attributeType/@xlink:href',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/gco:MemberName/gco:attributeType/@xlink:title',
#  '/gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/gco:MemberName/gco:attributeType/@xlink:actuate',
#  '/gmi:MI_Metadata/gmd:metadataMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceAndUpdateFrequency/gmd:MD_MaintenanceFrequencyCode',
#  '/gmi:MI_Metadata/gmd:metadataMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceAndUpdateFrequency/gmd:MD_MaintenanceFrequencyCode/@codeList',
#  '/gmi:MI_Metadata/gmd:metadataMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceAndUpdateFrequency/gmd:MD_MaintenanceFrequencyCode/@codeListValue',
#  '/gmi:MI_Metadata/gmd:metadataMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceAndUpdateFrequency/gmd:MD_MaintenanceFrequencyCode/@codeSpace',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:description/gco:CharacterString',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:status/gmd:MD_ProgressCode/@codeList',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:status/gmd:MD_ProgressCode/@codeListValue',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:type/gmi:MI_OperationTypeCode/@codeList',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:type/gmi:MI_OperationTypeCode/@codeListValue',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:parentOperation/@gco:nilReason',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:citation/gmd:CI_Citation/gmd:date/@gco:nilReason',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifier/gmd:MD_Identifier/gmd:authority/gmd:CI_Citation/gmd:date/@gco:nilReason',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor/@xlink:href',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor/@xlink:title',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:description/gmx:Anchor/@xlink:actuate',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:instrument/@gco:nilReason',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_ProgressCode/@codeList',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_ProgressCode/@codeListValue',
#  '/gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_Citation/gmd:date/@gco:nilReason']

# %% [markdown]
# Create a function that uses a specific XPath to create a new dataframe of just rows with the selected XPath.

# %%
def ConceptVerticalTable(XPath):
    global VerticalTable
    VerticalTable = UnknownTableDF[UnknownTableDF.XPath == XPath]
    return VerticalTable
VerticalTable
# Out:
#        Concept                            Content  \
# 22     Unknown      Dataset Version: 19 June 2012
# 243    Unknown   Dataset Version: 30 January 2013
# 472    Unknown   Dataset Version: 30 January 2013
# 693    Unknown   Dataset Version: 30 January 2013
# 3266   Unknown                 Dataset Version: 3
# 3829   Unknown   Dataset Version: 29 January 2013
# 3980   Unknown   Dataset Version: 30 January 2013
# 4381   Unknown   Dataset Version: 30 January 2013
# 4792   Unknown   Dataset Version: 30 January 2013
# 5020   Unknown       Dataset Version: 14 Oct 2013
# 5351   Unknown       Dataset Version: 14 Oct 2013
# 5689   Unknown  Dataset Version: 26 November 2013
# 6035   Unknown     Dataset Version: 10 March 2016
# 6362   Unknown       Dataset Version: 20 Dec 2012
# 6706   Unknown       Dataset Version: 28 Dec 2012
# 7122   Unknown       Dataset Version: 24 Dec 2012
# 7511   Unknown        Dataset Version: 2012-12-31
# 7950   Unknown   Dataset Version: 03 January 2013
# 8201   Unknown       Dataset Version: 24 Dec 2012
# 8536   Unknown                Dataset Version: 8b
# 8941   Unknown       Dataset Version: 31 Dec 2012
# 9329   Unknown       Dataset Version: 31 Dec 2012
# 9738   Unknown    Dataset Version: 9 January 2013
# 10078  Unknown   Dataset Version: 04 January 2013
# 10373  Unknown   Dataset Version: 04 January 2013
# 10703  Unknown                 Dataset Version: 4
# 11131  Unknown     Dataset Version: 10 March 2014
# 11991  Unknown       Dataset Version: 25 Jan 2013
# 12269  Unknown        Dataset Version: 2015-02-04
# 12791  Unknown                 Dataset Version: 5
# 13244  Unknown       Dataset Version: 22 Oct 2013
# 13614  Unknown       Dataset Version: 20 Jan 2015
# 14133  Unknown                Dataset Version: 4b
# 14926  Unknown       Dataset Version: 07 Jan 2013
# 15340  Unknown       Dataset Version: 07 Jan 2013
# 15788  Unknown       Dataset Version: 07 Jan 2013
# 16197  Unknown        Dataset Version: 2012-01-10
# 16753  Unknown       Dataset Version: 31 Dec 2012
# 17158  Unknown        Dataset Version: 2013.01.14
# 17479  Unknown       Dataset Version: 30 Jan 2013
# 19181  Unknown       Dataset Version: 01 Jan 2013
# 19512  Unknown       Dataset Version: 21 Jan 2013
# 19926  Unknown  Dataset Version: 27 December 2012
# 20508  Unknown        Dataset Version: 2013-01-21
# 20803  Unknown       Dataset Version: 30 Jan 2013
# 22382  Unknown       Dataset Version: 22 Jan 2013
# 22698  Unknown      Dataset Version: 16 Sept 2014
#
#                                                                                                                                                                  XPath  \
# 22     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 243    /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 472    /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 693    /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 3266   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 3829   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 3980   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 4381   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 4792   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 5020   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 5351   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 5689   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 6035   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 6362   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 6706   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 7122   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 7511   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 7950   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 8201   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 8536   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 8941   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 9329   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 9738   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 10078  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 10373  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 10703  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 11131  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 11991  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 12269  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 12791  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 13244  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 13614  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 14133  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 14926  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 15340  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 15788  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 16197  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 16753  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 17158  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 17479  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 19181  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 19512  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 19926  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 20508  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 20803  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 22382  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
# 22698  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:resourceMaintenance/gmd:MD_MaintenanceInformation/gmd:maintenanceNote/gco:CharacterString
#
#       DialectDefinition
# 22            Undefined
# 243           Undefined
# 472           Undefined
# 693           Undefined
# 3266          Undefined
# 3829          Undefined
# 3980          Undefined
# 4381          Undefined
# 4792          Undefined
# 5020          Undefined
# 5351          Undefined
# 5689          Undefined
# 6035          Undefined
# 6362          Undefined
# 6706          Undefined
# 7122          Undefined
# 7511          Undefined
# 7950          Undefined
# 8201          Undefined
# 8536          Undefined
# 8941          Undefined
# 9329          Undefined
# 9738          Undefined
# 10078         Undefined
# 10373         Undefined
# 10703         Undefined
# 11131         Undefined
# 11991         Undefined
# 12269         Undefined
# 12791         Undefined
# 13244         Undefined
# 13614         Undefined
# 14133         Undefined
# 14926         Undefined
# 15340         Undefined
# 15788         Undefined
# 16197         Undefined
# 16753         Undefined
# 17158         Undefined
# 17479         Undefined
# 19181         Undefined
# 19512         Undefined
# 19926         Undefined
# 20508         Undefined
# 20803         Undefined
# 22382         Undefined
# 22698         Undefined

# %% [markdown]
# Create a dropdown that selects from the list of unique XPaths and uses the result in the ConceptVerticalTable function

# %%
interactive(ConceptVerticalTable,XPath=Verticals)

# %% [markdown]
# Let me know if you can identify any concepts!
