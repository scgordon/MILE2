# %% [markdown]
# ##  This notebook allows the user to refine the data.csv created in Metadata2Data by the Evaluator service. The resulting csv can be copied into a Recommedations Analysis Dashboard to analyze the collection for recommendation completeness for about 30 different Earth and Space Science communities recommendations.

# %% [markdown]
# Import needed python packages

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipywidgets import *
import ipywidgets as widgets

# %% [markdown]
# Create a list of data.csv that are in the MILE2 repository

# %%
DataFiles=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith(".csv")]:
        DataFiles.extend([os.path.join(dirpath, filename)])
DataFiles
# Out:
# ['../data/BCO-DMO/GeoTraces_ISO_data.csv',
#  '../data/DataONE/CDL_CSDGM_data.csv',
#  '../data/DataONE/CLOEBIRD_EML_data.csv',
#  '../data/DataONE/Dryad_Dryad_data.csv',
#  '../data/DataONE/EDACGSTORE_CSDGM_data.csv',
#  '../data/DataONE/EDORA_Mercury_data.csv',
#  '../data/DataONE/ESA_EML_data.csv',
#  '../data/DataONE/GLEON_EML_data.csv',
#  '../data/DataONE/GOA_EML_data.csv',
#  '../data/DataONE/IARC_Onedcx_data.csv',
#  '../data/DataONE/IOE_EML_data.csv',
#  '../data/DataONE/KNB_EML_data.csv',
#  '../data/DataONE/KUBI_EML_data.csv',
#  '../data/DataONE/LTER_EML_data.csv',
#  '../data/DataONE/LTER_EUROPE_EML_data.csv',
#  '../data/DataONE/NMEPSCOR_CSDGM_data.csv',
#  '../data/DataONE/ONEShare_EML_data.csv',
#  '../data/DataONE/ORNLDAAC_Mercury_data.csv',
#  '../data/DataONE/PISCO_EML_data.csv',
#  '../data/DataONE/RGD_Mercury_data.csv',
#  '../data/DataONE/SANPARKS_EML_data.csv',
#  '../data/DataONE/SEAD_CSDGM_data.csv',
#  '../data/DataONE/TERN_EML_data.csv',
#  '../data/DataONE/TFRI_EML_data.csv',
#  '../data/DataONE/US_MPC_Onedcx_data.csv',
#  '../data/DataONE/USANPN_EML_data.csv',
#  '../data/DataONE/USGSCSAS_BDP_data.csv',
#  '../data/DataONE/USGSCSAS_CSDGM_data.csv',
#  '../data/IEDA/ECL_DCITE_data.csv',
#  '../data/IEDA/MarineGeoscienceDataSystem_ISO_data.csv',
#  '../data/LTERthroughTime/LTER_2005_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2006_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2007_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2008_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2009_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2010_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2011_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2012_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2013_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2014_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2015_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2016_EML_data.csv',
#  '../data/NASA/GES_DISC_DIF_data.csv',
#  '../data/NASA/GHRC_DIF_data.csv',
#  '../data/NASA/GHRC_ISO_data.csv',
#  '../data/NASA/LARC_DIF_data.csv',
#  '../data/NASA/LARC_ISO_data.csv',
#  '../data/NASA/NSIDC_DIF_data.csv',
#  '../data/NASA/NSIDC_ISO_data.csv',
#  '../data/NCAR/IIS_MODS_data.csv',
#  '../data/NCAR/RDA_RDA-CISL_data.csv',
#  '../data/ORNL/DAAC_Mercury_data.csv',
#  '../data/ORNL/NGEE_CSDGM_data.csv',
#  '../data/ORNL/OLI_ISO_data.csv',
#  '../data/ORNL/USGSC_CSDGM_data.csv',
#  '../data/USGS/OldScienceBase_CSDGM_data.csv',
#  '../data/USGS/ScienceBase_CSDGM_data.csv']

# %% [markdown]
# Create a function that allows us to import the csv contents into a dataframe.

# %%
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(DataFile))
    return CollectionConceptsDF

# %% [markdown]
# Create dropdown to select csv

# %%
interactive(DataChoices,DataFile=DataFiles)

# %% [markdown]
# Drop the columns we don't need in the RAD

# %%
CollectionConceptsDF.drop(['XPath','Content','DialectDefinition'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#      Collection Dialect  \
# 0          NGEE   CSDGM
# 1          NGEE   CSDGM
# 2          NGEE   CSDGM
# 3          NGEE   CSDGM
# 4          NGEE   CSDGM
# 5          NGEE   CSDGM
# 6          NGEE   CSDGM
# 7          NGEE   CSDGM
# 8          NGEE   CSDGM
# 9          NGEE   CSDGM
# 10         NGEE   CSDGM
# 11         NGEE   CSDGM
# 12         NGEE   CSDGM
# 13         NGEE   CSDGM
# 14         NGEE   CSDGM
# 15         NGEE   CSDGM
# 16         NGEE   CSDGM
# 17         NGEE   CSDGM
# 18         NGEE   CSDGM
# 19         NGEE   CSDGM
# 20         NGEE   CSDGM
# 21         NGEE   CSDGM
# 22         NGEE   CSDGM
# 23         NGEE   CSDGM
# 24         NGEE   CSDGM
# 25         NGEE   CSDGM
# 26         NGEE   CSDGM
# 27         NGEE   CSDGM
# 28         NGEE   CSDGM
# 29         NGEE   CSDGM
# ...         ...     ...
# 2500       NGEE   CSDGM
# 2501       NGEE   CSDGM
# 2502       NGEE   CSDGM
# 2503       NGEE   CSDGM
# 2504       NGEE   CSDGM
# 2505       NGEE   CSDGM
# 2506       NGEE   CSDGM
# 2507       NGEE   CSDGM
# 2508       NGEE   CSDGM
# 2509       NGEE   CSDGM
# 2510       NGEE   CSDGM
# 2511       NGEE   CSDGM
# 2512       NGEE   CSDGM
# 2513       NGEE   CSDGM
# 2514       NGEE   CSDGM
# 2515       NGEE   CSDGM
# 2516       NGEE   CSDGM
# 2517       NGEE   CSDGM
# 2518       NGEE   CSDGM
# 2519       NGEE   CSDGM
# 2520       NGEE   CSDGM
# 2521       NGEE   CSDGM
# 2522       NGEE   CSDGM
# 2523       NGEE   CSDGM
# 2524       NGEE   CSDGM
# 2525       NGEE   CSDGM
# 2526       NGEE   CSDGM
# 2527       NGEE   CSDGM
# 2528       NGEE   CSDGM
# 2529       NGEE   CSDGM
#
#                                                                                                                       Record  \
# 0     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 1     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 2     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 3     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 4     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 5     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 6     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 7     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 8     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 9     ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 10    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 11    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 12    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 13    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 14    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 15    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 16    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 17    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 18    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 19    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 20    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 21    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 22    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 23    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 24    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 25    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 26    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 27    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 28    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# 29    ftp___ngee.ornl.gov_data_outgoing_metadata_Active_Layer_Soil_Carbon_and_Nitrogen_Mineralization_Barrow_Alaska_2012.xml
# ...                                                                                                                      ...
# 2500                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2501                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2502                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2503                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2504                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2505                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2506                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2507                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2508                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2509                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2510                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2511                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2512                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2513                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2514                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2515                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2516                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2517                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2518                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2519                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2520                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2521                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2522                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2523                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2524                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2525                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2526                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2527                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2528                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
# 2529                         ftp___ngee.ornl.gov_data_outgoing_metadata_Time_lapse_photography_at_BEO_Barrow_Alaska_2014.xml
#
#                            Concept
# 0                          Unknown
# 1                Resource Citation
# 2                         Abstract
# 3                          Purpose
# 4                  Temporal Extent
# 5                  Resource Status
# 6                             Site
# 7                     Bounding Box
# 8                   Spatial Extent
# 9                    Place Keyword
# 10                         Keyword
# 11                   Place Keyword
# 12                         Keyword
# 13                   Place Keyword
# 14                         Keyword
# 15                   Place Keyword
# 16                         Keyword
# 17                   Place Keyword
# 18                         Keyword
# 19                   Place Keyword
# 20                         Keyword
# 21                   Place Keyword
# 22                         Keyword
# 23                         Unknown
# 24              Keyword Vocabulary
# 25                    Keyword Type
# 26                   Theme Keyword
# 27                         Keyword
# 28                   Theme Keyword
# 29                         Keyword
# ...                            ...
# 2500                       Keyword
# 2501                 Place Keyword
# 2502                       Keyword
# 2503                 Place Keyword
# 2504                       Keyword
# 2505                 Place Keyword
# 2506                       Keyword
# 2507            Keyword Vocabulary
# 2508                  Keyword Type
# 2509            Keyword Vocabulary
# 2510                  Keyword Type
# 2511            Keyword Vocabulary
# 2512                  Keyword Type
# 2513            Keyword Vocabulary
# 2514                  Keyword Type
# 2515                        Rights
# 2516   Resource Access Constraints
# 2517              Resource Contact
# 2518                       Unknown
# 2519             Quality Statement
# 2520  Resource Quality Description
# 2521         Resource Distribution
# 2522        Metadata Modified Date
# 2523              Metadata Contact
# 2524             Metadata Language
# 2525    Metadata Standard Citation
# 2526     Metadata Standard Version
# 2527                       Unknown
# 2528                       Unknown
# 2529                       Unknown
#
# [2530 rows x 4 columns]

# %% [markdown]
# Remove duplicate rows to increase processing speed in Excel.

# %%
ConceptsDF=CollectionConceptsDF.drop_duplicates()

# %% [markdown]
# Create a new csv with just the information we want in it

# %%
ConceptsDF.to_csv('../data/dataForRAD.csv', mode = 'w', index=False)

# %% [markdown]
# Links to open dataForRAD.csv and the RAD ready for data entry. Copy the cells in the data table we created and paste onto the data worksheet. Then switch to the dashboard worksheet and select the recommendation you are interested in evaluating the metadata with.

# %% [markdown]
# [My data table](../data/dataForRAD.csv)
#
# [Recommendations Analysis Dashboard](../RAD/RAD.xlsx)
