# %% [markdown]
# ##  This notebook allows the user to refine the data.csv created in Metadata2Data by the Evaluator service. The resulting csv can be copy pasted into a Recommedations Analysis Dashboard to analyze the collection for recommendation completeness.

# %% [markdown]
# Import needed python packages

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipywidgets import *
import ipywidgets as widgets

# %% [markdown]
# Create a list of data.csv that are in the MILE2 repository

# %%
DataFiles=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith(".csv")]:
        DataFiles.extend([os.path.join(dirpath, filename)])
DataFiles
# Out:
# ['../data/data.csv',
#  '../data/dataForRAD.csv',
#  '../data/BCO-DMO/GeoTraces_ISO_data.csv',
#  '../data/DataONE/CDL_CSDGM_data.csv',
#  '../data/DataONE/CLOEBIRD_EML_data.csv',
#  '../data/DataONE/Dryad_Dryad_data.csv',
#  '../data/DataONE/EDACGSTORE_CSDGM_data.csv',
#  '../data/DataONE/EDORA_Mercury_data.csv',
#  '../data/DataONE/ESA_EML_data.csv',
#  '../data/DataONE/GLEON_EML_data.csv',
#  '../data/DataONE/GOA_EML_data.csv',
#  '../data/DataONE/IARC_Onedcx_data.csv',
#  '../data/DataONE/IOE_EML_data.csv',
#  '../data/DataONE/KNB_EML_data.csv',
#  '../data/DataONE/KUBI_EML_data.csv',
#  '../data/DataONE/LTER_EML_data.csv',
#  '../data/DataONE/LTER_EUROPE_EML_data.csv',
#  '../data/DataONE/NMEPSCOR_CSDGM_data.csv',
#  '../data/DataONE/ONEShare_EML_data.csv',
#  '../data/DataONE/ORNLDAAC_Mercury_data.csv',
#  '../data/DataONE/PISCO_EML_data.csv',
#  '../data/DataONE/RGD_Mercury_data.csv',
#  '../data/DataONE/SANPARKS_EML_data.csv',
#  '../data/DataONE/SEAD_CSDGM_data.csv',
#  '../data/DataONE/TERN_EML_data.csv',
#  '../data/DataONE/TFRI_EML_data.csv',
#  '../data/DataONE/US_MPC_Onedcx_data.csv',
#  '../data/DataONE/USANPN_EML_data.csv',
#  '../data/DataONE/USGSCSAS_BDP_data.csv',
#  '../data/DataONE/USGSCSAS_CSDGM_data.csv',
#  '../data/IEDA/ECL_DCITE_data.csv',
#  '../data/LTERthroughTime/LTER_2005_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2006_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2007_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2008_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2009_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2010_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2011_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2012_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2013_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2014_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2015_EML_data.csv',
#  '../data/LTERthroughTime/LTER_2016_EML_data.csv',
#  '../data/NASA/GES_DISC_DIF_data.csv',
#  '../data/NASA/GHRC_DIF_data.csv',
#  '../data/NASA/GHRC_ISO_data.csv',
#  '../data/NASA/LARC_DIF_data.csv',
#  '../data/NASA/LARC_ISO_data.csv',
#  '../data/NASA/NSIDC_DIF_data.csv',
#  '../data/NASA/NSIDC_ISO_data.csv',
#  '../data/NCAR/IIS_MODS_data.csv',
#  '../data/NCAR/RDA_RDA-CISL_data.csv',
#  '../data/ORNL/DAAC_Mercury_data.csv',
#  '../data/ORNL/NGEE_CSDGM_data.csv',
#  '../data/ORNL/OLI_ISO_data.csv',
#  '../data/ORNL/USGSC_CSDGM_data.csv',
#  '../data/USGS/OldScienceBase_CSDGM_data.csv',
#  '../data/USGS/ScienceBase_CSDGM_data.csv']

# %% [markdown]
# Create a function that allows us to import the csv contents into a dataframe.

# %%
def DataChoices(DataFile):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(DataFile))
    return CollectionConceptsDF

# %% [markdown]
# Create dropdown to select csv

# %%
interactive(DataChoices,DataFile=DataFiles)
# Out:
#       Collection Dialect              Record                           Concept
# 0            CDL   CSDGM  02509-metadata.xml                 Resource Citation
# 1            CDL   CSDGM  02509-metadata.xml                          Abstract
# 2            CDL   CSDGM  02509-metadata.xml                           Purpose
# 3            CDL   CSDGM  02509-metadata.xml                           Unknown
# 4            CDL   CSDGM  02509-metadata.xml                           Unknown
# 5            CDL   CSDGM  02509-metadata.xml                   Resource Status
# 6            CDL   CSDGM  02509-metadata.xml                      Bounding Box
# 7            CDL   CSDGM  02509-metadata.xml                    Spatial Extent
# 8            CDL   CSDGM  02509-metadata.xml                Keyword Vocabulary
# 9            CDL   CSDGM  02509-metadata.xml                      Keyword Type
# 10           CDL   CSDGM  02509-metadata.xml                     Theme Keyword
# 11           CDL   CSDGM  02509-metadata.xml                           Keyword
# 12           CDL   CSDGM  02509-metadata.xml                     Theme Keyword
# 13           CDL   CSDGM  02509-metadata.xml                           Keyword
# 14           CDL   CSDGM  02509-metadata.xml                     Theme Keyword
# 15           CDL   CSDGM  02509-metadata.xml                           Keyword
# 16           CDL   CSDGM  02509-metadata.xml          Place Keyword Vocabulary
# 17           CDL   CSDGM  02509-metadata.xml                     Place Keyword
# 18           CDL   CSDGM  02509-metadata.xml                           Keyword
# 19           CDL   CSDGM  02509-metadata.xml                     Place Keyword
# 20           CDL   CSDGM  02509-metadata.xml                           Keyword
# 21           CDL   CSDGM  02509-metadata.xml                     Place Keyword
# 22           CDL   CSDGM  02509-metadata.xml                           Keyword
# 23           CDL   CSDGM  02509-metadata.xml                            Rights
# 24           CDL   CSDGM  02509-metadata.xml       Resource Access Constraints
# 25           CDL   CSDGM  02509-metadata.xml                            Rights
# 26           CDL   CSDGM  02509-metadata.xml          Resource Use Constraints
# 27           CDL   CSDGM  02509-metadata.xml                  Resource Contact
# 28           CDL   CSDGM  02509-metadata.xml                           Unknown
# 29           CDL   CSDGM  02509-metadata.xml                 Quality Statement
# ...          ...     ...                 ...                               ...
# 10845        CDL   CSDGM  02758-metadata.xml                     Theme Keyword
# 10846        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10847        CDL   CSDGM  02758-metadata.xml          Place Keyword Vocabulary
# 10848        CDL   CSDGM  02758-metadata.xml                     Place Keyword
# 10849        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10850        CDL   CSDGM  02758-metadata.xml                     Place Keyword
# 10851        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10852        CDL   CSDGM  02758-metadata.xml                     Place Keyword
# 10853        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10854        CDL   CSDGM  02758-metadata.xml                            Rights
# 10855        CDL   CSDGM  02758-metadata.xml       Resource Access Constraints
# 10856        CDL   CSDGM  02758-metadata.xml                            Rights
# 10857        CDL   CSDGM  02758-metadata.xml          Resource Use Constraints
# 10858        CDL   CSDGM  02758-metadata.xml                  Resource Contact
# 10859        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10860        CDL   CSDGM  02758-metadata.xml                 Quality Statement
# 10861        CDL   CSDGM  02758-metadata.xml      Resource Quality Description
# 10862        CDL   CSDGM  02758-metadata.xml                Spatial Resolution
# 10863        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10864        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10865        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10866        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10867        CDL   CSDGM  02758-metadata.xml  Entity and Attribute Information
# 10868        CDL   CSDGM  02758-metadata.xml            Metadata Modified Date
# 10869        CDL   CSDGM  02758-metadata.xml                    Metadata Dates
# 10870        CDL   CSDGM  02758-metadata.xml       Future Metadata Review Date
# 10871        CDL   CSDGM  02758-metadata.xml                  Metadata Contact
# 10872        CDL   CSDGM  02758-metadata.xml                 Metadata Language
# 10873        CDL   CSDGM  02758-metadata.xml        Metadata Standard Citation
# 10874        CDL   CSDGM  02758-metadata.xml         Metadata Standard Version
#
# [10875 rows x 4 columns]

# %% [markdown]
# Drop the columns we don't need

# %%
CollectionConceptsDF.drop(['XPath','Content','DialectDefinition','DocumentLocation'], axis=1, inplace=True)
CollectionConceptsDF
# Out:
#       Collection Dialect              Record                           Concept
# 0            CDL   CSDGM  02509-metadata.xml                 Resource Citation
# 1            CDL   CSDGM  02509-metadata.xml                          Abstract
# 2            CDL   CSDGM  02509-metadata.xml                           Purpose
# 3            CDL   CSDGM  02509-metadata.xml                           Unknown
# 4            CDL   CSDGM  02509-metadata.xml                           Unknown
# 5            CDL   CSDGM  02509-metadata.xml                   Resource Status
# 6            CDL   CSDGM  02509-metadata.xml                      Bounding Box
# 7            CDL   CSDGM  02509-metadata.xml                    Spatial Extent
# 8            CDL   CSDGM  02509-metadata.xml                Keyword Vocabulary
# 9            CDL   CSDGM  02509-metadata.xml                      Keyword Type
# 10           CDL   CSDGM  02509-metadata.xml                     Theme Keyword
# 11           CDL   CSDGM  02509-metadata.xml                           Keyword
# 12           CDL   CSDGM  02509-metadata.xml                     Theme Keyword
# 13           CDL   CSDGM  02509-metadata.xml                           Keyword
# 14           CDL   CSDGM  02509-metadata.xml                     Theme Keyword
# 15           CDL   CSDGM  02509-metadata.xml                           Keyword
# 16           CDL   CSDGM  02509-metadata.xml          Place Keyword Vocabulary
# 17           CDL   CSDGM  02509-metadata.xml                     Place Keyword
# 18           CDL   CSDGM  02509-metadata.xml                           Keyword
# 19           CDL   CSDGM  02509-metadata.xml                     Place Keyword
# 20           CDL   CSDGM  02509-metadata.xml                           Keyword
# 21           CDL   CSDGM  02509-metadata.xml                     Place Keyword
# 22           CDL   CSDGM  02509-metadata.xml                           Keyword
# 23           CDL   CSDGM  02509-metadata.xml                            Rights
# 24           CDL   CSDGM  02509-metadata.xml       Resource Access Constraints
# 25           CDL   CSDGM  02509-metadata.xml                            Rights
# 26           CDL   CSDGM  02509-metadata.xml          Resource Use Constraints
# 27           CDL   CSDGM  02509-metadata.xml                  Resource Contact
# 28           CDL   CSDGM  02509-metadata.xml                           Unknown
# 29           CDL   CSDGM  02509-metadata.xml                 Quality Statement
# ...          ...     ...                 ...                               ...
# 10845        CDL   CSDGM  02758-metadata.xml                     Theme Keyword
# 10846        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10847        CDL   CSDGM  02758-metadata.xml          Place Keyword Vocabulary
# 10848        CDL   CSDGM  02758-metadata.xml                     Place Keyword
# 10849        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10850        CDL   CSDGM  02758-metadata.xml                     Place Keyword
# 10851        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10852        CDL   CSDGM  02758-metadata.xml                     Place Keyword
# 10853        CDL   CSDGM  02758-metadata.xml                           Keyword
# 10854        CDL   CSDGM  02758-metadata.xml                            Rights
# 10855        CDL   CSDGM  02758-metadata.xml       Resource Access Constraints
# 10856        CDL   CSDGM  02758-metadata.xml                            Rights
# 10857        CDL   CSDGM  02758-metadata.xml          Resource Use Constraints
# 10858        CDL   CSDGM  02758-metadata.xml                  Resource Contact
# 10859        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10860        CDL   CSDGM  02758-metadata.xml                 Quality Statement
# 10861        CDL   CSDGM  02758-metadata.xml      Resource Quality Description
# 10862        CDL   CSDGM  02758-metadata.xml                Spatial Resolution
# 10863        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10864        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10865        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10866        CDL   CSDGM  02758-metadata.xml                           Unknown
# 10867        CDL   CSDGM  02758-metadata.xml  Entity and Attribute Information
# 10868        CDL   CSDGM  02758-metadata.xml            Metadata Modified Date
# 10869        CDL   CSDGM  02758-metadata.xml                    Metadata Dates
# 10870        CDL   CSDGM  02758-metadata.xml       Future Metadata Review Date
# 10871        CDL   CSDGM  02758-metadata.xml                  Metadata Contact
# 10872        CDL   CSDGM  02758-metadata.xml                 Metadata Language
# 10873        CDL   CSDGM  02758-metadata.xml        Metadata Standard Citation
# 10874        CDL   CSDGM  02758-metadata.xml         Metadata Standard Version
#
# [10875 rows x 4 columns]

# %% [markdown]
# Remove duplicate rows to increase processing speed in Excel.

# %%
ConceptsDF=CollectionConceptsDF.drop_duplicates()

# %% [markdown]
# Create a new csv with just the information we want in it

# %%
ConceptsDF.to_csv('../data/dataForRAD.csv', mode = 'w', index=False)

# %% [markdown]
# Link to open dataForRAD.csv

# %% [markdown]
# [my data](../data/dataForRAD.csv)
