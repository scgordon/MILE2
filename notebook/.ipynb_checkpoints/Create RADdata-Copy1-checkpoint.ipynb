# %% [markdown]
# ##  This notebook allows the user to select XML collections and run a transform on them that produces a simple CSV containing for each concept, known or unknown, the Collection, Dialect, Record, Concept, Content, Xpath location, and dialect definition. This data can be used in a variety of analyses including RAD and QuickE as well as Concept Verticals.

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
from ipywidgets import *
import ipywidgets as widgets

# %% [markdown]
# Define a function to create a new directory if desired for Organization and Collection. Otherwise use dropdowns of existing directories.

# %% [markdown]
# Define a function that creates a dropdown using a list of dialect codes to populate the Dialect

# %%
cd ../script
# Out:
# /Users/scgordon/MILE2/script

# %%
# !./UseRosetta.sh $Organization $Collection $Dialect
# Out:
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[2]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[2]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[2]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# Recoverable error
#   XTRE0540: Ambiguous rule match for
#   /gmi:MI_Metadata/gmd:distributionInfo[1]/gmd:MD_Distribution[1]/gmd:transferOptions[1]/gmd:MD_DigitalTransferOptions[1]/gmd:onLine[1]/gmd:CI_OnlineResource[1]/gmd:linkage[1]/gmd:URL[1]
# Matches both "document-node()//element(Q{http://www.isotc211.org/2005/gmd}MD_DigitalTransferOptions)/element(Q{http://www.isotc211.org/2005/gmd}onLine)/element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 48023 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# and "document-node()//element(Q{http://www.isotc211.org/2005/gmd}CI_OnlineResource)/element(Q{http://www.isotc211.org/2005/gmd}linkage)/element(Q{http://www.isotc211.org/2005/gmd}URL)" on line 21734 of file:/Users/scgordon/Crosswalks/Rosetta/Rosetta.xsl
# No more warnings will be displayed

# %%
HDFconceptsDF.drop(['XPath','Content'], axis=1, inplace=True)
HDFconceptsDF
# Out:
#       Collection Dialect              Record                           Concept
# 0            CDL   CSDGM  02509-metadata.xml                          Abstract
# 1            CDL   CSDGM  02509-metadata.xml              Attribute Definition
# 2            CDL   CSDGM  02509-metadata.xml       Attribute Definition Source
# 3            CDL   CSDGM  02509-metadata.xml                   Attribute Label
# 4            CDL   CSDGM  02509-metadata.xml                    Attribute List
# 5            CDL   CSDGM  02509-metadata.xml                            Author
# 6            CDL   CSDGM  02509-metadata.xml               Author / Originator
# 7            CDL   CSDGM  02509-metadata.xml                      Bounding Box
# 8            CDL   CSDGM  02509-metadata.xml             Easternmost Longitude
# 9            CDL   CSDGM  02509-metadata.xml            Entity Type Definition
# 10           CDL   CSDGM  02509-metadata.xml     Entity Type Definition Source
# 11           CDL   CSDGM  02509-metadata.xml                 Entity Type Label
# 12           CDL   CSDGM  02509-metadata.xml  Entity and Attribute Information
# 13           CDL   CSDGM  02509-metadata.xml       Future Metadata Review Date
# 14           CDL   CSDGM  02509-metadata.xml                           Keyword
# 15           CDL   CSDGM  02509-metadata.xml                           Keyword
# 16           CDL   CSDGM  02509-metadata.xml                           Keyword
# 17           CDL   CSDGM  02509-metadata.xml                           Keyword
# 18           CDL   CSDGM  02509-metadata.xml                           Keyword
# 19           CDL   CSDGM  02509-metadata.xml                           Keyword
# 20           CDL   CSDGM  02509-metadata.xml                      Keyword Type
# 21           CDL   CSDGM  02509-metadata.xml                Keyword Vocabulary
# 22           CDL   CSDGM  02509-metadata.xml                 Lineage Statement
# 23           CDL   CSDGM  02509-metadata.xml                       Maintenance
# 24           CDL   CSDGM  02509-metadata.xml                  Metadata Contact
# 25           CDL   CSDGM  02509-metadata.xml                    Metadata Dates
# 26           CDL   CSDGM  02509-metadata.xml                 Metadata Language
# 27           CDL   CSDGM  02509-metadata.xml            Metadata Modified Date
# 28           CDL   CSDGM  02509-metadata.xml        Metadata Standard Citation
# 29           CDL   CSDGM  02509-metadata.xml         Metadata Standard Version
# ...          ...     ...                 ...                               ...
# 17470        CDL   CSDGM  02758-metadata.xml                 Process Step Time
# 17471        CDL   CSDGM  02758-metadata.xml                         Processor
# 17472        CDL   CSDGM  02758-metadata.xml              Project Website Link
# 17473        CDL   CSDGM  02758-metadata.xml                  Publication Date
# 17474        CDL   CSDGM  02758-metadata.xml                         Publisher
# 17475        CDL   CSDGM  02758-metadata.xml                Publisher Location
# 17476        CDL   CSDGM  02758-metadata.xml                           Purpose
# 17477        CDL   CSDGM  02758-metadata.xml                 Quality Statement
# 17478        CDL   CSDGM  02758-metadata.xml       Resource Access Constraints
# 17479        CDL   CSDGM  02758-metadata.xml                 Resource Citation
# 17480        CDL   CSDGM  02758-metadata.xml                  Resource Contact
# 17481        CDL   CSDGM  02758-metadata.xml   Resource Creation/Revision Date
# 17482        CDL   CSDGM  02758-metadata.xml                  Resource Lineage
# 17483        CDL   CSDGM  02758-metadata.xml      Resource Quality Description
# 17484        CDL   CSDGM  02758-metadata.xml                   Resource Status
# 17485        CDL   CSDGM  02758-metadata.xml                    Resource Title
# 17486        CDL   CSDGM  02758-metadata.xml         Resource Update Frequency
# 17487        CDL   CSDGM  02758-metadata.xml          Resource Use Constraints
# 17488        CDL   CSDGM  02758-metadata.xml             Resource on-line Link
# 17489        CDL   CSDGM  02758-metadata.xml                            Rights
# 17490        CDL   CSDGM  02758-metadata.xml                            Rights
# 17491        CDL   CSDGM  02758-metadata.xml                   Source Citation
# 17492        CDL   CSDGM  02758-metadata.xml             Southernmost Latitude
# 17493        CDL   CSDGM  02758-metadata.xml                    Spatial Extent
# 17494        CDL   CSDGM  02758-metadata.xml                Spatial Resolution
# 17495        CDL   CSDGM  02758-metadata.xml                     Theme Keyword
# 17496        CDL   CSDGM  02758-metadata.xml                     Theme Keyword
# 17497        CDL   CSDGM  02758-metadata.xml                     Theme Keyword
# 17498        CDL   CSDGM  02758-metadata.xml                               URL
# 17499        CDL   CSDGM  02758-metadata.xml             Westernmost Longitude
#
# [17500 rows x 4 columns]

# %%
Records=HDFconceptsDF.Record.unique()
RecordList=Records.tolist()
RecordList
# Out:
# ['02509-metadata.xml',
#  '02510-metadata.xml',
#  '02511-metadata.xml',
#  '02512-metadata.xml',
#  '02513-metadata.xml',
#  '02514-metadata.xml',
#  '02515-metadata.xml',
#  '02516-metadata.xml',
#  '02517-metadata.xml',
#  '02518-metadata.xml',
#  '02519-metadata.xml',
#  '02520-metadata.xml',
#  '02521-metadata.xml',
#  '02522-metadata.xml',
#  '02523-metadata.xml',
#  '02524-metadata.xml',
#  '02525-metadata.xml',
#  '02526-metadata.xml',
#  '02527-metadata.xml',
#  '02528-metadata.xml',
#  '02529-metadata.xml',
#  '02530-metadata.xml',
#  '02531-metadata.xml',
#  '02532-metadata.xml',
#  '02533-metadata.xml',
#  '02534-metadata.xml',
#  '02535-metadata.xml',
#  '02536-metadata.xml',
#  '02537-metadata.xml',
#  '02538-metadata.xml',
#  '02539-metadata.xml',
#  '02540-metadata.xml',
#  '02541-metadata.xml',
#  '02542-metadata.xml',
#  '02543-metadata.xml',
#  '02544-metadata.xml',
#  '02545-metadata.xml',
#  '02546-metadata.xml',
#  '02547-metadata.xml',
#  '02548-metadata.xml',
#  '02549-metadata.xml',
#  '02550-metadata.xml',
#  '02551-metadata.xml',
#  '02552-metadata.xml',
#  '02553-metadata.xml',
#  '02554-metadata.xml',
#  '02555-metadata.xml',
#  '02556-metadata.xml',
#  '02557-metadata.xml',
#  '02558-metadata.xml',
#  '02559-metadata.xml',
#  '02560-metadata.xml',
#  '02561-metadata.xml',
#  '02562-metadata.xml',
#  '02563-metadata.xml',
#  '02564-metadata.xml',
#  '02565-metadata.xml',
#  '02566-metadata.xml',
#  '02567-metadata.xml',
#  '02568-metadata.xml',
#  '02569-metadata.xml',
#  '02570-metadata.xml',
#  '02571-metadata.xml',
#  '02572-metadata.xml',
#  '02573-metadata.xml',
#  '02574-metadata.xml',
#  '02575-metadata.xml',
#  '02576-metadata.xml',
#  '02577-metadata.xml',
#  '02578-metadata.xml',
#  '02579-metadata.xml',
#  '02580-metadata.xml',
#  '02581-metadata.xml',
#  '02582-metadata.xml',
#  '02583-metadata.xml',
#  '02584-metadata.xml',
#  '02585-metadata.xml',
#  '02586-metadata.xml',
#  '02587-metadata.xml',
#  '02588-metadata.xml',
#  '02589-metadata.xml',
#  '02590-metadata.xml',
#  '02591-metadata.xml',
#  '02592-metadata.xml',
#  '02593-metadata.xml',
#  '02594-metadata.xml',
#  '02595-metadata.xml',
#  '02596-metadata.xml',
#  '02597-metadata.xml',
#  '02598-metadata.xml',
#  '02599-metadata.xml',
#  '02600-metadata.xml',
#  '02601-metadata.xml',
#  '02602-metadata.xml',
#  '02603-metadata.xml',
#  '02604-metadata.xml',
#  '02605-metadata.xml',
#  '02606-metadata.xml',
#  '02607-metadata.xml',
#  '02608-metadata.xml',
#  '02609-metadata.xml',
#  '02610-metadata.xml',
#  '02611-metadata.xml',
#  '02612-metadata.xml',
#  '02613-metadata.xml',
#  '02614-metadata.xml',
#  '02615-metadata.xml',
#  '02616-metadata.xml',
#  '02617-metadata.xml',
#  '02618-metadata.xml',
#  '02619-metadata.xml',
#  '02620-metadata.xml',
#  '02621-metadata.xml',
#  '02622-metadata.xml',
#  '02623-metadata.xml',
#  '02624-metadata.xml',
#  '02625-metadata.xml',
#  '02626-metadata.xml',
#  '02627-metadata.xml',
#  '02628-metadata.xml',
#  '02629-metadata.xml',
#  '02630-metadata.xml',
#  '02631-metadata.xml',
#  '02632-metadata.xml',
#  '02633-metadata.xml',
#  '02634-metadata.xml',
#  '02635-metadata.xml',
#  '02636-metadata.xml',
#  '02637-metadata.xml',
#  '02638-metadata.xml',
#  '02639-metadata.xml',
#  '02640-metadata.xml',
#  '02641-metadata.xml',
#  '02642-metadata.xml',
#  '02643-metadata.xml',
#  '02644-metadata.xml',
#  '02645-metadata.xml',
#  '02646-metadata.xml',
#  '02647-metadata.xml',
#  '02648-metadata.xml',
#  '02649-metadata.xml',
#  '02650-metadata.xml',
#  '02651-metadata.xml',
#  '02652-metadata.xml',
#  '02653-metadata.xml',
#  '02654-metadata.xml',
#  '02655-metadata.xml',
#  '02656-metadata.xml',
#  '02657-metadata.xml',
#  '02658-metadata.xml',
#  '02659-metadata.xml',
#  '02660-metadata.xml',
#  '02661-metadata.xml',
#  '02662-metadata.xml',
#  '02663-metadata.xml',
#  '02664-metadata.xml',
#  '02665-metadata.xml',
#  '02666-metadata.xml',
#  '02667-metadata.xml',
#  '02668-metadata.xml',
#  '02669-metadata.xml',
#  '02670-metadata.xml',
#  '02671-metadata.xml',
#  '02672-metadata.xml',
#  '02673-metadata.xml',
#  '02674-metadata.xml',
#  '02675-metadata.xml',
#  '02676-metadata.xml',
#  '02677-metadata.xml',
#  '02678-metadata.xml',
#  '02679-metadata.xml',
#  '02680-metadata.xml',
#  '02681-metadata.xml',
#  '02682-metadata.xml',
#  '02683-metadata.xml',
#  '02684-metadata.xml',
#  '02685-metadata.xml',
#  '02686-metadata.xml',
#  '02687-metadata.xml',
#  '02688-metadata.xml',
#  '02689-metadata.xml',
#  '02690-metadata.xml',
#  '02691-metadata.xml',
#  '02692-metadata.xml',
#  '02693-metadata.xml',
#  '02694-metadata.xml',
#  '02695-metadata.xml',
#  '02696-metadata.xml',
#  '02697-metadata.xml',
#  '02698-metadata.xml',
#  '02699-metadata.xml',
#  '02700-metadata.xml',
#  '02701-metadata.xml',
#  '02702-metadata.xml',
#  '02703-metadata.xml',
#  '02704-metadata.xml',
#  '02705-metadata.xml',
#  '02706-metadata.xml',
#  '02707-metadata.xml',
#  '02708-metadata.xml',
#  '02709-metadata.xml',
#  '02710-metadata.xml',
#  '02711-metadata.xml',
#  '02712-metadata.xml',
#  '02713-metadata.xml',
#  '02714-metadata.xml',
#  '02715-metadata.xml',
#  '02716-metadata.xml',
#  '02717-metadata.xml',
#  '02718-metadata.xml',
#  '02719-metadata.xml',
#  '02720-metadata.xml',
#  '02721-metadata.xml',
#  '02722-metadata.xml',
#  '02723-metadata.xml',
#  '02724-metadata.xml',
#  '02725-metadata.xml',
#  '02726-metadata.xml',
#  '02727-metadata.xml',
#  '02728-metadata.xml',
#  '02729-metadata.xml',
#  '02730-metadata.xml',
#  '02731-metadata.xml',
#  '02732-metadata.xml',
#  '02733-metadata.xml',
#  '02734-metadata.xml',
#  '02735-metadata.xml',
#  '02736-metadata.xml',
#  '02737-metadata.xml',
#  '02738-metadata.xml',
#  '02739-metadata.xml',
#  '02740-metadata.xml',
#  '02741-metadata.xml',
#  '02742-metadata.xml',
#  '02743-metadata.xml',
#  '02744-metadata.xml',
#  '02745-metadata.xml',
#  '02746-metadata.xml',
#  '02747-metadata.xml',
#  '02748-metadata.xml',
#  '02749-metadata.xml',
#  '02750-metadata.xml',
#  '02751-metadata.xml',
#  '02752-metadata.xml',
#  '02753-metadata.xml',
#  '02754-metadata.xml',
#  '02755-metadata.xml',
#  '02756-metadata.xml',
#  '02757-metadata.xml',
#  '02758-metadata.xml']

# %% [markdown]
# ### For each item in RecordList, check to see if a row that contains the item contains a list of concepts from a recommendation

# %%
for record in RecordList:
    test=HDFconceptsDF[HDFconceptsDF.isin({'Concept': ['Abstract','Keyword']})]
test
# Out:
#       Collection Dialect Record   Concept
# 0            NaN     NaN    NaN  Abstract
# 1            NaN     NaN    NaN       NaN
# 2            NaN     NaN    NaN       NaN
# 3            NaN     NaN    NaN       NaN
# 4            NaN     NaN    NaN       NaN
# 5            NaN     NaN    NaN       NaN
# 6            NaN     NaN    NaN       NaN
# 7            NaN     NaN    NaN       NaN
# 8            NaN     NaN    NaN       NaN
# 9            NaN     NaN    NaN       NaN
# 10           NaN     NaN    NaN       NaN
# 11           NaN     NaN    NaN       NaN
# 12           NaN     NaN    NaN       NaN
# 13           NaN     NaN    NaN       NaN
# 14           NaN     NaN    NaN   Keyword
# 15           NaN     NaN    NaN   Keyword
# 16           NaN     NaN    NaN   Keyword
# 17           NaN     NaN    NaN   Keyword
# 18           NaN     NaN    NaN   Keyword
# 19           NaN     NaN    NaN   Keyword
# 20           NaN     NaN    NaN       NaN
# 21           NaN     NaN    NaN       NaN
# 22           NaN     NaN    NaN       NaN
# 23           NaN     NaN    NaN       NaN
# 24           NaN     NaN    NaN       NaN
# 25           NaN     NaN    NaN       NaN
# 26           NaN     NaN    NaN       NaN
# 27           NaN     NaN    NaN       NaN
# 28           NaN     NaN    NaN       NaN
# 29           NaN     NaN    NaN       NaN
# ...          ...     ...    ...       ...
# 17470        NaN     NaN    NaN       NaN
# 17471        NaN     NaN    NaN       NaN
# 17472        NaN     NaN    NaN       NaN
# 17473        NaN     NaN    NaN       NaN
# 17474        NaN     NaN    NaN       NaN
# 17475        NaN     NaN    NaN       NaN
# 17476        NaN     NaN    NaN       NaN
# 17477        NaN     NaN    NaN       NaN
# 17478        NaN     NaN    NaN       NaN
# 17479        NaN     NaN    NaN       NaN
# 17480        NaN     NaN    NaN       NaN
# 17481        NaN     NaN    NaN       NaN
# 17482        NaN     NaN    NaN       NaN
# 17483        NaN     NaN    NaN       NaN
# 17484        NaN     NaN    NaN       NaN
# 17485        NaN     NaN    NaN       NaN
# 17486        NaN     NaN    NaN       NaN
# 17487        NaN     NaN    NaN       NaN
# 17488        NaN     NaN    NaN       NaN
# 17489        NaN     NaN    NaN       NaN
# 17490        NaN     NaN    NaN       NaN
# 17491        NaN     NaN    NaN       NaN
# 17492        NaN     NaN    NaN       NaN
# 17493        NaN     NaN    NaN       NaN
# 17494        NaN     NaN    NaN       NaN
# 17495        NaN     NaN    NaN       NaN
# 17496        NaN     NaN    NaN       NaN
# 17497        NaN     NaN    NaN       NaN
# 17498        NaN     NaN    NaN       NaN
# 17499        NaN     NaN    NaN       NaN
#
# [17500 rows x 4 columns]

# %%
for record in RecordList:
    RAD=HDFconceptsDF[(HDFconceptsDF['Record'] == record)&(HDFconceptsDF['Concept'] == 'Abstract')]
RAD
# Out:
#       Collection Dialect              Record   Concept
# 17430        CDL   CSDGM  02758-metadata.xml  Abstract

# %% [markdown]
# How to turn dataframe into Analysis sheet for a recommendation and recreate visualizations in Notebook, how to integrate awk script into Notebook, how to pass dataframes to other Notebooks.

# %% [markdown]
# How to upload files to server, how to recieve file from server

# %% [markdown]
# Install Anaconda with python 3.6
# Upload Metadata
# download result table as h5 file
# create dataframe
# create dataframe for RAD, give dropdown for collection occurance viz
# create dataframe for QuickE give dropdown for different Concept counts
# Create dataframe for Verticals give dropdown for different concepts
