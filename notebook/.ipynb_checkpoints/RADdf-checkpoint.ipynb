# %% [markdown]
# ## create a dataframe used to create all visualizations for that recommendation
#
#
#
# Function used to fill in the dataframe
# If the concept name and record name exist in a row of the dataDF return a one. If they do not exist, check to see if the concept is contained in the dialect using the dialectDF (use filepath to determine dialect). If yes, return zero. if not in dialect return negative one

# %% [markdown]
# Import as needed

# %%
import pandas as pd
import pixiedust
import holoviews as hv
import numpy as np

import os
from os import walk
import fnmatch
from ipywidgets import *
import ipywidgets as widgets

hv.__version__
# Out:
# 1.8.4

# %% [markdown]
# ### Select evaluation of a metadata collection and prepare it for analysis
# 1. Query the data directory for evaluated data and use the results to populate a list
# 2. Function that reads the selected csv into a dataframe

# %%
# 1.
DataFiles=[]
for path, subdirectories, filenames in os.walk('../data/'):
    for filename in filenames:
        if fnmatch.fnmatch(filename, '*Evaluated.csv'):
            DataFiles.append(os.path.join(path,filename).split("../data/", 1)[-1])
# 2.    
def DataChoices(DataFile):
    dataFile=DataFile
    EvaluatedMetadataDF= pd.read_csv(os.path.join('../data', DataFile))
    collectionDialect=dataFile.partition("/")[2].partition("_Evaluated.csv")[0]
    EvaluatedMetadataDF=EvaluatedMetadataDF.insert(1, 'Collection', collectionDialect)
    
    return EvaluatedMetadataDF
# 3.

# %% [markdown]
# read in the EvaluatedMetadata of the collection you want to analyze

# %%
interactive(DataChoices,DataFile=DataFiles)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
#collectionDialect=dataFile.partition("/")[2].partition("_Evaluated.csv")[0]
collectionDialect
# Out:
# 'GeoTraces_ISO'

# %% [markdown]
# Create a table with each record as a row of concept occurance counts. Each concept that occurs in the collection is a row.

# %%
#collectionDialect=dataFile.partition("/")[2].partition("_Evaluated.csv")[0]
group_name = EvaluatedMetadataDF.groupby(['Record', 'Concept'], as_index=False)
occuranceMatrix=group_name.size().unstack().reset_index()
occuranceMatrix=occuranceMatrix.fillna(0)
occuranceMatrix
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ea69184f4164> in <module>()
#       1 #collectionDialect=dataFile.partition("/")[2].partition("_Evaluated.csv")[0]
# ----> 2 group_name = EvaluatedMetadataDF.groupby(['Record', 'Concept'], as_index=False)
#       3 occuranceMatrix=group_name.size().unstack().reset_index()
#       4 occuranceMatrix=occuranceMatrix.fillna(0)
#       5 occuranceMatrix
#
# AttributeError: 'NoneType' object has no attribute 'groupby'

# %% [markdown]
# Sum up the collection concept occurance

# %%
occuranceSum=occuranceMatrix.sum()

occuranceSum
# Out:
# Concept
# Record                                       dataset_3470.xmldataset_3484.xmldataset_3485.x...
# Abstract                                                                                   117
# Acknowledgement                                                                            191
# Address                                                                                    592
# AssociatedDIFs                                                                             261
# Association                                                                                261
# Attribute Definition                                                                      4132
# Attribute Label                                                                           4385
# Author / Originator                                                                        125
# Bounding Box                                                                                88
# Cited Resource Identifier                                                                    2
# Cited Resource Title                                                                      1700
# City                                                                                       591
# Contact Instructions                                                                       468
# Country                                                                                    579
# Data Quality Scope                                                                         117
# DataType                                                                                  1954
# DimensionsName                                                                            4385
# Distribution Contact                                                                       117
# Easternmost Longitude                                                                       88
# Email                                                                                      589
# End Time                                                                                     9
# Enumerated Domain Value Definition Source                                                  571
# Fax                                                                                        468
# Feature Catalogue Citation                                                                 234
# First Name                                                                                 408
# Geographic Description                                                                     117
# Hours of Service                                                                           468
# Instrument                                                                                 268
# Instrument Keyword                                                                         268
#                                                                    ...
# Related Resource Identifier                                                                667
# Reprocessing Plan Note                                                                     117
# Resource Access Constraints                                                                234
# Resource Contact                                                                           125
# Resource Creation/Revision Date                                                            117
# Resource Identifier                                                                          2
# Resource Language                                                                          117
# Resource Lineage                                                                           117
# Resource Long Name                                                                         117
# Resource Status                                                                            117
# Resource Title                                                                             117
# Resource Type                                                                              117
# Resource Update Frequency                                                                  117
# Resource Use Constraints                                                                   117
# Responsibility                                                                            1962
# Rights                                                                                     117
# Role                                                                                       819
# Southernmost Latitude                                                                       88
# Spatial Extent                                                                              88
# Standard Name Vocabulary                                                                   571
# Start Time                                                                                   9
# Temporal Extent                                                                            117
# Theme Keyword                                                                             3106
# Topic Category                                                                             118
# URL                                                                                        116
# Units                                                                                     4385
# Unknown                                                                                  73002
# VariableType                                                                               117
# Web Page                                                                                   887
# Westernmost Longitude                                                                       88
# Length: 103, dtype: object

# %% [markdown]
# Count up how many records contain the concept.

# %%
occuranceCount=occuranceMatrix[occuranceMatrix!=0].count()

occuranceCount
# Out:
# Concept
# Record                                       117
# Abstract                                     117
# Acknowledgement                              115
# Address                                      117
# AssociatedDIFs                               117
# Association                                  117
# Attribute Definition                         117
# Attribute Label                              117
# Author / Originator                          117
# Bounding Box                                  88
# Cited Resource Identifier                      2
# Cited Resource Title                         117
# City                                         117
# Contact Instructions                         117
# Country                                      117
# Data Quality Scope                           117
# DataType                                     117
# DimensionsName                               117
# Distribution Contact                         117
# Easternmost Longitude                         88
# Email                                        117
# End Time                                       9
# Enumerated Domain Value Definition Source    117
# Fax                                          117
# Feature Catalogue Citation                   117
# First Name                                   117
# Geographic Description                       117
# Hours of Service                             117
# Instrument                                   103
# Instrument Keyword                           103
#                                             ...
# Related Resource Identifier                  117
# Reprocessing Plan Note                       117
# Resource Access Constraints                  117
# Resource Contact                             117
# Resource Creation/Revision Date              117
# Resource Identifier                            2
# Resource Language                            117
# Resource Lineage                             117
# Resource Long Name                           117
# Resource Status                              117
# Resource Title                               117
# Resource Type                                117
# Resource Update Frequency                    117
# Resource Use Constraints                     117
# Responsibility                               117
# Rights                                       117
# Role                                         117
# Southernmost Latitude                         88
# Spatial Extent                                88
# Standard Name Vocabulary                     117
# Start Time                                     9
# Temporal Extent                              117
# Theme Keyword                                117
# Topic Category                               117
# URL                                          116
# Units                                        117
# Unknown                                      117
# VariableType                                 117
# Web Page                                     117
# Westernmost Longitude                         88
# Length: 103, dtype: int64

# %%
del occuranceMatrix.column.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8bf4a7cc9b6b> in <module>()
# ----> 1 del occuranceMatrix.column.name
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
occuranceMatrix
# Out:
# Concept              Record  Abstract  Acknowledgement  Address  \
# 0          dataset_3470.xml       1.0              2.0      5.0
# 1          dataset_3484.xml       1.0              2.0      5.0
# 2          dataset_3485.xml       1.0              2.0      5.0
# 3          dataset_3486.xml       1.0              2.0      5.0
# 4          dataset_3508.xml       1.0              2.0      5.0
# 5          dataset_3510.xml       1.0              2.0      5.0
# 6          dataset_3513.xml       1.0              2.0      5.0
# 7          dataset_3514.xml       1.0              2.0      5.0
# 8          dataset_3515.xml       1.0              2.0      5.0
# 9          dataset_3516.xml       1.0              2.0      5.0
# 10         dataset_3517.xml       1.0              2.0      5.0
# 11         dataset_3518.xml       1.0              2.0      5.0
# 12         dataset_3519.xml       1.0              2.0      5.0
# 13         dataset_3520.xml       1.0              2.0      5.0
# 14         dataset_3521.xml       1.0              2.0      5.0
# 15         dataset_3659.xml       1.0              2.0      5.0
# 16         dataset_3662.xml       1.0              2.0      5.0
# 17         dataset_3664.xml       1.0              2.0      5.0
# 18         dataset_3671.xml       1.0              2.0      5.0
# 19         dataset_3672.xml       1.0              2.0      5.0
# 20         dataset_3673.xml       1.0              2.0      5.0
# 21         dataset_3674.xml       1.0              2.0      5.0
# 22         dataset_3687.xml       1.0              2.0      5.0
# 23         dataset_3692.xml       1.0              1.0      5.0
# 24         dataset_3696.xml       1.0              2.0      5.0
# 25         dataset_3698.xml       1.0              2.0      5.0
# 26         dataset_3699.xml       1.0              2.0      5.0
# 27         dataset_3746.xml       1.0              2.0      5.0
# 28         dataset_3821.xml       1.0              1.0      5.0
# 29         dataset_3822.xml       1.0              2.0      5.0
# ..                      ...       ...              ...      ...
# 87       dataset_549122.xml       1.0              1.0      5.0
# 88       dataset_558538.xml       1.0              2.0      5.0
# 89       dataset_637784.xml       1.0              2.0      5.0
# 90       dataset_639016.xml       1.0              0.0      5.0
# 91       dataset_639847.xml       1.0              3.0      6.0
# 92       dataset_641044.xml       1.0              1.0      5.0
# 93       dataset_642974.xml       1.0              1.0      5.0
# 94       dataset_643213.xml       1.0              2.0      5.0
# 95       dataset_643270.xml       1.0              1.0      5.0
# 96       dataset_643316.xml       1.0              2.0      5.0
# 97       dataset_643423.xml       1.0              1.0      5.0
# 98       dataset_643494.xml       1.0              2.0      5.0
# 99       dataset_643578.xml       1.0              2.0      5.0
# 100      dataset_643592.xml       1.0              2.0      5.0
# 101      dataset_643639.xml       1.0              1.0      5.0
# 102      dataset_643809.xml       1.0              1.0      5.0
# 103      dataset_644607.xml       1.0              1.0      5.0
# 104      dataset_644765.xml       1.0              1.0      5.0
# 105      dataset_646143.xml       1.0              1.0      5.0
# 106      dataset_646842.xml       1.0              1.0      5.0
# 107      dataset_647580.xml       1.0              1.0      5.0
# 108      dataset_647606.xml       1.0              1.0      5.0
# 109      dataset_647909.xml       1.0              1.0      5.0
# 110      dataset_648030.xml       1.0              1.0      5.0
# 111      dataset_648543.xml       1.0              3.0      6.0
# 111                  1.0           53.0             1.0  1.0   88.0    967.0
# 112                  1.0           18.0             1.0  1.0   29.0    567.0
# 113                  1.0           19.0             1.0  1.0   26.0    545.0
# 114                  1.0           21.0             1.0  1.0   30.0    552.0
# 115                  1.0           18.0             1.0  1.0   21.0    513.0
# 116                  1.0           16.0             1.0  1.0   42.0    661.0
#
# Concept  VariableType  Web Page  Westernmost Longitude
# 0                 1.0       7.0                    1.0
# 1                 1.0       7.0                    1.0
# 2                 1.0       7.0                    1.0
# 3                 1.0       7.0                    1.0
# 4                 1.0       7.0                    1.0
# 5                 1.0       7.0                    1.0
# 6                 1.0       7.0                    1.0
# 7                 1.0       7.0                    1.0
# 8                 1.0       7.0                    1.0
# 9                 1.0       7.0                    1.0
# 10                1.0       7.0                    1.0
# 11                1.0       7.0                    1.0
# 12                1.0       7.0                    1.0
# 13                1.0       7.0                    1.0
# 14                1.0       7.0                    1.0
# 15                1.0       7.0                    1.0
# 16                1.0       7.0                    1.0
# 17                1.0       7.0                    1.0
# 18                1.0       7.0                    1.0
# 19                1.0       7.0                    1.0
# 20                1.0       7.0                    1.0
# 21                1.0       7.0                    1.0
# 22                1.0       7.0                    0.0
# 23                1.0       8.0                    1.0
# 24                1.0       7.0                    1.0
# 25                1.0       7.0                    1.0
# 26                1.0       7.0                    1.0
# 27                1.0       7.0                    1.0
# 28                1.0       7.0                    1.0
# 29                1.0       7.0                    1.0
# ..                ...       ...                    ...
# 87                1.0       8.0                    1.0
# 88                1.0       7.0                    1.0
# 89                1.0       9.0                    0.0
# 90                1.0       7.0                    1.0
# 91                1.0       9.0                    0.0
# 92                1.0       8.0                    1.0
# 93                1.0       8.0                    0.0
# 94                1.0       8.0                    0.0
# 95                1.0       8.0                    1.0
# 96                1.0       8.0                    0.0
# 97                1.0       8.0                    0.0
# 98                1.0       8.0                    0.0
# 99                1.0       8.0                    0.0
# 100               1.0       8.0                    0.0
# 101               1.0       8.0                    1.0
# 102               1.0       8.0                    1.0
# 103               1.0       8.0                    0.0
# 104               1.0       8.0                    0.0
# 105               1.0       8.0                    0.0
# 106               1.0       7.0                    0.0
# 107               1.0       8.0                    0.0
# 108               1.0       8.0                    0.0
# 109               1.0       8.0                    0.0
# 110               1.0       8.0                    0.0
# 111               1.0       9.0                    0.0
# 112               1.0       8.0                    0.0
# 113               1.0       8.0                    0.0
# 114               1.0       7.0                    1.0
# 115               1.0       8.0                    0.0
# 116               1.0       9.0                    0.0
#
# [117 rows x 103 columns]

# %% [markdown]
# Combine the two tables and add a collection column

# %%
CollectionName=collectionDialect=dataFile.partition("/")[2].partition("_Evaluated.csv")[0]

# %%
result = pd.concat([occuranceSum, occuranceCount], axis=1).reset_index()
result.insert(1, 'Collection', CollectionName)
result.columns = ['Concept', 'Collection', 'ConceptCount', 'RecordCount']
result.at[0, 'ConceptCount'] = result.at[0, 'ConceptCount'].count('.xml')
result.at[0, 'Concept'] = 'Number of Records'
result
# Out:
#                                        Concept Collection ConceptCount  \
# 0                            Number of Records       2001          117
# 1                                     Abstract       2001          117
# 2                              Acknowledgement       2001          191
# 3                                      Address       2001          592
# 4                               AssociatedDIFs       2001          261
# 5                                  Association       2001          261
# 6                         Attribute Definition       2001         4132
# 7                              Attribute Label       2001         4385
# 8                          Author / Originator       2001          125
# 9                                 Bounding Box       2001           88
# 10                   Cited Resource Identifier       2001            2
# 11                        Cited Resource Title       2001         1700
# 12                                        City       2001          591
# 13                        Contact Instructions       2001          468
# 14                                     Country       2001          579
# 15                          Data Quality Scope       2001          117
# 16                                    DataType       2001         1954
# 17                              DimensionsName       2001         4385
# 18                        Distribution Contact       2001          117
# 19                       Easternmost Longitude       2001           88
# 20                                       Email       2001          589
# 21                                    End Time       2001            9
# 22   Enumerated Domain Value Definition Source       2001          571
# 23                                         Fax       2001          468
# 24                  Feature Catalogue Citation       2001          234
# 25                                  First Name       2001          408
# 26                      Geographic Description       2001          117
# 27                            Hours of Service       2001          468
# 28                                  Instrument       2001          268
# 29                          Instrument Keyword       2001          268
# ..                                         ...        ...          ...
# 73                 Related Resource Identifier       2001          667
# 74                      Reprocessing Plan Note       2001          117
# 75                 Resource Access Constraints       2001          234
# 76                            Resource Contact       2001          125
# 77             Resource Creation/Revision Date       2001          117
# 78                         Resource Identifier       2001            2
# 79                           Resource Language       2001          117
# 80                            Resource Lineage       2001          117
# 81                          Resource Long Name       2001          117
# 82                             Resource Status       2001          117
# 83                              Resource Title       2001          117
# 84                               Resource Type       2001          117
# 85                   Resource Update Frequency       2001          117
# 86                    Resource Use Constraints       2001          117
# 87                              Responsibility       2001         1962
# 88                                      Rights       2001          117
# 89                                        Role       2001          819
# 90                       Southernmost Latitude       2001           88
# 91                              Spatial Extent       2001           88
# 92                    Standard Name Vocabulary       2001          571
# 93                                  Start Time       2001            9
# 94                             Temporal Extent       2001          117
# 95                               Theme Keyword       2001         3106
# 96                              Topic Category       2001          118
# 97                                         URL       2001          116
# 98                                       Units       2001         4385
# 99                                     Unknown       2001        73002
# 100                               VariableType       2001          117
# 101                                   Web Page       2001          887
# 102                      Westernmost Longitude       2001           88
#
#      RecordCount
# 0            117
# 1            117
# 2            115
# 3            117
# 4            117
# 5            117
# 6            117
# 7            117
# 8            117
# 9             88
# 10             2
# 11           117
# 12           117
# 13           117
# 14           117
# 15           117
# 16           117
# 17           117
# 18           117
# 19            88
# 20           117
# 21             9
# 22           117
# 23           117
# 24           117
# 25           117
# 26           117
# 27           117
# 28           103
# 29           103
# ..           ...
# 73           117
# 74           117
# 75           117
# 76           117
# 77           117
# 78             2
# 79           117
# 80           117
# 81           117
# 82           117
# 83           117
# 84           117
# 85           117
# 86           117
# 87           117
# 88           117
# 89           117
# 90            88
# 91            88
# 92           117
# 93             9
# 94           117
# 95           117
# 96           117
# 97           116
# 98           117
# 99           117
# 100          117
# 101          117
# 102           88
#
# [103 rows x 4 columns]
