# %% [markdown]
# ### While the evaluator identifies and assigns a concept name to many geoscience metadata dialects, there is also much content that is not defined in the dialect. This notebook compares the output from KnownNodes.xsl and AllNodes.xsl to identify xpaths that do not have a dialect definition. It then appends the resulting dataframe to the KnownNodes dataframe. This gives a complete representation of the metadata.

# %% [markdown]
# Import the python packages needed

# %%
import pandas as pd

# %% [markdown]
# Read in the defined content for BCO-DMO's GeoTraces collection, written in the ISO dialect.

# %%
KnownNodesDF= pd.read_csv('../data/BCO-DMO/GeoTraces_ISO_dataKnown.csv')
KnownNodesDF
# Out:
#                    Record                          Concept  \
# 0        dataset_3470.xml                   Resource Title
# 1        dataset_3470.xml  Resource Creation/Revision Date
# 2        dataset_3470.xml                         Abstract
# 3        dataset_3470.xml                   Topic Category
# 4        dataset_3470.xml                    Theme Keyword
# 5        dataset_3470.xml                    Theme Keyword
# 6        dataset_3470.xml                    Theme Keyword
# 7        dataset_3470.xml                    Theme Keyword
# 8        dataset_3470.xml                    Theme Keyword
# 9        dataset_3470.xml                    Theme Keyword
# 10       dataset_3470.xml                    Theme Keyword
# 11       dataset_3470.xml                    Theme Keyword
# 12       dataset_3470.xml                    Theme Keyword
# 13       dataset_3470.xml                    Theme Keyword
# 14       dataset_3470.xml                    Theme Keyword
# 15       dataset_3470.xml                    Theme Keyword
# 16       dataset_3470.xml                    Theme Keyword
# 17       dataset_3470.xml                    Theme Keyword
# 18       dataset_3470.xml                    Theme Keyword
# 19       dataset_3470.xml                    Theme Keyword
# 20       dataset_3470.xml                    Theme Keyword
# 21       dataset_3470.xml                    Theme Keyword
# 22       dataset_3470.xml               Keyword Vocabulary
# 23       dataset_3470.xml               Keyword Vocabulary
# 24       dataset_3470.xml               Keyword Vocabulary
# 25       dataset_3470.xml               Keyword Vocabulary
# 26       dataset_3470.xml               Keyword Vocabulary
# 27       dataset_3470.xml                 Metadata Contact
# 28       dataset_3470.xml                 Resource Contact
# 29       dataset_3470.xml                             Role
# ...                   ...                              ...
# 71412  dataset_651138.xml                          Keyword
# 71413  dataset_651138.xml                          Keyword
# 71414  dataset_651138.xml                          Keyword
# 71415  dataset_651138.xml                          Keyword
# 71416  dataset_651138.xml                          Keyword
# 71417  dataset_651138.xml                          Keyword
# 71418  dataset_651138.xml                          Keyword
# 71419  dataset_651138.xml                          Keyword
# 71420  dataset_651138.xml                          Keyword
# 71421  dataset_651138.xml                          Keyword
# 71422  dataset_651138.xml                          Keyword
# 71423  dataset_651138.xml                          Keyword
# 71424  dataset_651138.xml                          Keyword
# 71425  dataset_651138.xml                          Keyword
# 71426  dataset_651138.xml                          Keyword
# 71427  dataset_651138.xml                          Keyword
# 71428  dataset_651138.xml                          Keyword
# 71429  dataset_651138.xml                          Keyword
# 71430  dataset_651138.xml                          Keyword
# 71431  dataset_651138.xml                          Keyword
# 71432  dataset_651138.xml                          Keyword
# 71433  dataset_651138.xml                          Keyword
# 71434  dataset_651138.xml                          Keyword
# 71435  dataset_651138.xml                          Keyword
# 71436  dataset_651138.xml                          Keyword
# 71437  dataset_651138.xml                          Keyword
# 71438  dataset_651138.xml                          Keyword
# 71439  dataset_651138.xml                          Keyword
# 71440  dataset_651138.xml                          Keyword
# 71441  dataset_651138.xml                          Keyword
#
#                                                    XPath  \
# 0      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 1      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 2      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 3      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 4      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 5      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 6      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 7      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 8      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 9      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 10     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 11     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 12     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 13     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 14     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 15     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 16     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 17     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 18     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 19     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 20     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 21     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 22     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 23     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 24     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 25     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 26     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 27                          /gmi:MI_Metadata/gmd:contact
# 28     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 29     /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# ...                                                  ...
# 71412  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71413  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71414  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71415  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71416  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71417  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71418  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71419  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71420  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71421  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71422  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71423  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71424  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71425  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71426  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71427  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71428  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71429  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71430  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71431  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71432  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71433  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71434  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71435  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71436  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71437  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71438  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71439  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71440  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 71441  /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
#
#                                                  Content
# 0      GT10 - Nanomolar Nutrients - Surface from the ...
# 1                                             2013-02-27
# 2      Nanomolar concentrations of PO4, NO3, NO2 (sur...
# 3                                                 oceans
# 4                                              cruise_id
# 5                                                   date
# 6                                                   time
# 7                                               latitude
# 8                                              longitude
# 9                                                 sample
# 10                                            dataset_id
# 11                                                   PO4
# 12                                                  flag
# 13                                                   NO3
# 14                                                  flag
# 15                                                   NO2
# 16                                                  flag
# 17                                 activity_and_comments
# 18                                                 event
# 19                                                sample
# 20                                      ISO_DateTime_UTC
# 21                                               GeoFish
# 22                                    None, User defined
# 23                           BCO-DMO Standard Parameters
# 24                          BCO-DMO Standard Instruments
# 25                                   Deployment Activity
# 26                                             Locations
# 27     Biological and Chemical Oceanography Data Mana...
# 28     Dr Gregory Cutter Old Dominion University 757-...
# 29                                        pointOfContact
# ...                                                  ...
# 71412                                   trace_metal_conc
# 71413                                   trace_metal_conc
# 71414                                   trace_metal_conc
# 71415                                   trace_metal_conc
# 71416                                   trace_metal_conc
# 71417                                   trace_metal_conc
# 71418                                   ISO_DateTime_UTC
# 71419                                             ICP-MS
# 71420                                             Bottle
# 71421                                            GeoFish
# 71422                Subtropical northern Atlantic Ocean
# 71423                                          cruise id
# 71424                                        cruise name
# 71425                                            station
# 71426                                               cast
# 71427                                                tow
# 71428                                           latitude
# 71429                                          longitude
# 71430                                              depth
# 71431                              sample identification
# 71432                                     water pressure
# 71433                          trace metal concentration
# 71434                                               flag
# 71435                                   ISO_DateTime_UTC
# 71436                                           KN199-04
# 71437                                           KN199-05
# 71438                                           KN204-01
# 71439       Inductively Coupled Plasma Mass Spectrometer
# 71440                   GO-FLO Teflon Trace Metal Bottle
# 71441                 GeoFish Towed near-Surface Sampler
#
# [71442 rows x 4 columns]

# %% [markdown]
# Read in all the content for BCO-DMO's GeoTraces collection, written in the ISO dialect.

# %%
AllNodesDF = pd.read_csv('../data/BCO-DMO/GeoTraces_ISO_dataAll.csv')
AllNodesDF
# Out:
#                     Record                                              XPath  \
# 0         dataset_3470.xml               /gmi:MI_Metadata/@xsi:schemaLocation
# 1         dataset_3470.xml  /gmi:MI_Metadata/gmd:fileIdentifier/gco:Charac...
# 2         dataset_3470.xml  /gmi:MI_Metadata/gmd:language/gco:CharacterString
# 3         dataset_3470.xml  /gmi:MI_Metadata/gmd:characterSet/gmd:MD_Chara...
# 4         dataset_3470.xml  /gmi:MI_Metadata/gmd:characterSet/gmd:MD_Chara...
# 5         dataset_3470.xml  /gmi:MI_Metadata/gmd:characterSet/gmd:MD_Chara...
# 6         dataset_3470.xml  /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_Sco...
# 7         dataset_3470.xml  /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_Sco...
# 8         dataset_3470.xml  /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_Sco...
# 9         dataset_3470.xml  /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_Sco...
# 10        dataset_3470.xml  /gmi:MI_Metadata/gmd:hierarchyLevelName/gco:Ch...
# 11        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 12        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 13        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 14        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 15        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 16        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 17        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 18        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 19        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 20        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 21        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 22        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 23        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 24        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 25        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 26        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 27        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 28        dataset_3470.xml  /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 29        dataset_3470.xml            /gmi:MI_Metadata/gmd:dateStamp/gco:Date
# ...                    ...                                                ...
# 117963  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117964  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117965  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117966  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117967  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117968  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117969  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117970  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117971  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117972  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117973  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117974  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117975  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117976  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117977  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117978  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117979  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117980  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117981  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117982  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117983  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117984  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117985  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117986  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117987  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117988  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117989  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117990  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117991  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117992  dataset_651138.xml  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
#
#                                                   Content
# 0       http://www.isotc211.org/2005/gmi http://www.ng...
# 1                  http://lod.bco-dmo.org/id/dataset/3470
# 2                                                eng; USA
# 3                                                    utf8
# 4       http://www.isotc211.org/2005/resources/Codelis...
# 5                                                    utf8
# 6                                                 dataset
# 7       http://www.isotc211.org/2005/resources/Codelis...
# 8                                                 dataset
# 9                                                     005
# 10      Highest level of data collection, from a commo...
# 11      Biological and Chemical Oceanography Data Mana...
# 12          http://lod.bco-dmo.org/id/affiliation/191.rdf
# 13                                              onRequest
# 14                                            Unavailable
# 15                                           508-289-2009
# 16                                             WHOI MS#36
# 17                                             Woods Hole
# 18                                                     MA
# 19                                                  02543
# 20                                                    USA
# 21                                       info@bco-dmo.org
# 22                                 http://www.bco-dmo.org
# 23                        Monday - Friday 8:00am - 5:00pm
# 24      For questions regarding this resource, please ...
# 25                                         pointOfContact
# 26      http://www.isotc211.org/2005/resources/Codelis...
# 27                                         pointOfContact
# 28                                                    007
# 29                                             2011-05-03
# ...                                                   ...
# 117963          http://lod.bco-dmo.org/id/authority/1.rdf
# 117964                                          onRequest
# 117965                                            unknown
# 117966                                          R/V Knorr
# 117967       http://lod.bco-dmo.org/id/platform/53994.rdf
# 117968                                               316N
# 117969                                          onRequest
# 117970                                             vessel
# 117971       http://lod.bco-dmo.org/id/platform/53994.rdf
# 117972                                          R/V Knorr
# 117973                                          onRequest
# 117974                                            unknown
# 117975  http://www.isotc211.org/2005/resources/Codelis...
# 117976                                          completed
# 117977                                           KN204-01
# 117978     http://lod.bco-dmo.org/id/deployment/58786.rdf
# 117979                                             Cruise
# 117980                                          onRequest
# 117981                                            unknown
# 117982                                 Dr Edward A. Boyle
# 117983         http://lod.bco-dmo.org/id/person/50984.rdf
# 117984                                          onRequest
# 117985              Massachusetts Institute of Technology
# 117986      http://lod.bco-dmo.org/id/affiliation/222.rdf
# 117987                                        Affiliation
# 117988                                          onRequest
# 117989  http://bcodata.whoi.edu/US_GEOTRACES/AtlanticS...
# 117990                         Report describing KN204-01
# 117991  http://www.isotc211.org/2005/resources/Codelis...
# 117992                              principalInvestigator
#
# [117993 rows x 3 columns]

# %% [markdown]
# Create a new dataframe from the rows in AllNodesDF that have an xpath that does not occur in KnownNodesDF then append it to the KnownNodesDF, creating ConceptIfKnownDF sorting by record and concept, then saving it to csv after dropping duplicates and filling in the null spaces in the Concept column with "Unknown"

# %%
UnknownNodesDF=AllNodesDF[(~AllNodesDF.XPath.isin(KnownNodesDF.XPath))]
ConceptIfKnownDF=pd.concat([KnownNodesDF,UnknownNodesDF], axis=0).sort_values(['Record', 'Concept'])
uniqueCIKDF=ConceptIfKnownDF.drop_duplicates().fillna('Unknown')
uniqueCIKDF.to_csv('../data/BCO-DMO/GeoTraces_ISO_Evaluated.csv', index=False)
uniqueCIKDF
# Out:
#                      Concept  \
# 2                   Abstract
# 261          Acknowledgement
# 262          Acknowledgement
# 80                   Address
# 81                   Address
# 82                   Address
# 83                   Address
# 84                   Address
# 243           AssociatedDIFs
# 244           AssociatedDIFs
# 164              Association
# 165              Association
# 197     Attribute Definition
# 198     Attribute Definition
# 199     Attribute Definition
# 200     Attribute Definition
# 201     Attribute Definition
# 202     Attribute Definition
# 203     Attribute Definition
# 204     Attribute Definition
# 205     Attribute Definition
# 206     Attribute Definition
# 207     Attribute Definition
# 208     Attribute Definition
# 209     Attribute Definition
# 210     Attribute Definition
# 211     Attribute Definition
# 212     Attribute Definition
# 213     Attribute Definition
# 180          Attribute Label
# ...                      ...
# 117883               Unknown
# 117884               Unknown
# 117885               Unknown
# 117886               Unknown
# 117887               Unknown
# 117888               Unknown
# 117889               Unknown
# 117890               Unknown
# 117891               Unknown
# 117892               Unknown
# 117893               Unknown
# 117894               Unknown
# 117895               Unknown
# 117896               Unknown
# 117897               Unknown
# 117898               Unknown
# 117899               Unknown
# 117930               Unknown
# 117931               Unknown
# 117944               Unknown
# 117945               Unknown
# 117946               Unknown
# 117977               Unknown
# 117978               Unknown
# 117982               Unknown
# 117983               Unknown
# 117985               Unknown
# 117986               Unknown
# 117989               Unknown
# 117990               Unknown
#
#                                                   Content              Record  \
# 2       Nanomolar concentrations of PO4, NO3, NO2 (sur...    dataset_3470.xml
# 261     Funding provided by NSF Ocean Sciences (NSF OC...    dataset_3470.xml
# 262     Funding provided by NSF Ocean Sciences (NSF OC...    dataset_3470.xml
# 80                                             WHOI MS#36    dataset_3470.xml
# 81      Department of Ocean, Earth, and Atmospheric Sc...    dataset_3470.xml
# 82                                             WHOI MS#36    dataset_3470.xml
# 83                                             WHOI MS#36    dataset_3470.xml
# 84                                             WHOI MS#36    dataset_3470.xml
# 243                                        U.S. GEOTRACES    dataset_3470.xml
# 244                                    U.S. GEOTRACES NAT    dataset_3470.xml
# 164     U.S. GEOTRACES http://www.geotraces.org/ U.S. ...    dataset_3470.xml
# 165     U.S. GEOTRACES North Atlantic Transect http://...    dataset_3470.xml
# 197     PI-supplied Description: Official cruise ident...    dataset_3470.xml
# 198     PI-supplied Description: date (GMT); General D...    dataset_3470.xml
# 199     PI-supplied Description: time (GMT); General D...    dataset_3470.xml
# 200     PI-supplied Description: Station latitude (Sou...    dataset_3470.xml
# 201     PI-supplied Description: Station longitude (We...    dataset_3470.xml
# 202     PI-supplied Description: Identifying number of...    dataset_3470.xml
# 203     PI-supplied Description: Unique identifiers fo...    dataset_3470.xml
# 204     PI-supplied Description: PO4: phosphate (react...    dataset_3470.xml
# 205     PI-supplied Description: PO4 Data Flag: Sample...    dataset_3470.xml
# 206     PI-supplied Description: NO3: Nitrate = (Nitra...    dataset_3470.xml
# 207     PI-supplied Description: NO3 Data Flag: Sample...    dataset_3470.xml
# 208     PI-supplied Description: NO2: Nitrite; General...    dataset_3470.xml
# 209     PI-supplied Description: NO2 Data Flag: Sample...    dataset_3470.xml
# 210     PI-supplied Description: Remarks; General Desc...    dataset_3470.xml
# 211     PI-supplied Description: Unique identifying nu...    dataset_3470.xml
# 212     PI-supplied Description: Unique identifying nu...    dataset_3470.xml
# 213     PI-supplied Description: Date/Time (UTC) forma...    dataset_3470.xml
# 180                                             cruise_id    dataset_3470.xml
# ...                                                   ...                 ...
# 117883                                             Cruise  dataset_651138.xml
# 117884                                          onRequest  dataset_651138.xml
# 117885                                            unknown  dataset_651138.xml
# 117886                              Dr William J. Jenkins  dataset_651138.xml
# 117887         http://lod.bco-dmo.org/id/person/50745.rdf  dataset_651138.xml
# 117888                                          onRequest  dataset_651138.xml
# 117889               Woods Hole Oceanographic Institution  dataset_651138.xml
# 117890        http://lod.bco-dmo.org/id/affiliation/2.rdf  dataset_651138.xml
# 117891                                        Affiliation  dataset_651138.xml
# 117892                                          onRequest  dataset_651138.xml
# 117893  http://bcodata.whoi.edu/US_GEOTRACES/AtlanticS...  dataset_651138.xml
# 117894                         Report describing KN199-04  dataset_651138.xml
# 117895  http://www.isotc211.org/2005/resources/Codelis...  dataset_651138.xml
# 117896                              principalInvestigator  dataset_651138.xml
# 117897                                   Cruise: KN199-05  dataset_651138.xml
# 117898                                           KN199-05  dataset_651138.xml
# 117899     http://lod.bco-dmo.org/id/deployment/58142.rdf  dataset_651138.xml
# 117930                                           KN199-05  dataset_651138.xml
# 117931     http://lod.bco-dmo.org/id/deployment/58142.rdf  dataset_651138.xml
# 117944                                   Cruise: KN204-01  dataset_651138.xml
# 117945                                           KN204-01  dataset_651138.xml
# 117946     http://lod.bco-dmo.org/id/deployment/58786.rdf  dataset_651138.xml
# 117977                                           KN204-01  dataset_651138.xml
# 117978     http://lod.bco-dmo.org/id/deployment/58786.rdf  dataset_651138.xml
# 117982                                 Dr Edward A. Boyle  dataset_651138.xml
# 117983         http://lod.bco-dmo.org/id/person/50984.rdf  dataset_651138.xml
# 117985              Massachusetts Institute of Technology  dataset_651138.xml
# 117986      http://lod.bco-dmo.org/id/affiliation/222.rdf  dataset_651138.xml
# 117989  http://bcodata.whoi.edu/US_GEOTRACES/AtlanticS...  dataset_651138.xml
# 117990                         Report describing KN204-01  dataset_651138.xml
#
#                                                     XPath
# 2       /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 261     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 262     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 80      /gmi:MI_Metadata/gmd:contact/gmd:CI_Responsibl...
# 81      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 82      /gmi:MI_Metadata/gmd:contentInfo/gmd:MD_Featur...
# 83      /gmi:MI_Metadata/gmd:distributionInfo/gmd:MD_D...
# 84      /gmi:MI_Metadata/gmd:metadataMaintenance/gmd:M...
# 243     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 244     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 164     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 165     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD...
# 197     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 198     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 199     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 200     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 201     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 202     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 203     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 204     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 205     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 206     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 207     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 208     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 209     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 210     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 211     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 212     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 213     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# 180     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_Covera...
# ...                                                   ...
# 117883  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117884  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117885  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117886  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117887  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117888  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117889  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117890  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117891  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117892  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117893  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117894  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117895  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117896  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117897  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117898  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117899  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117930  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117931  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117944  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117945  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117946  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117977  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117978  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117982  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117983  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117985  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117986  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117989  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
# 117990  /gmi:MI_Metadata/gmi:acquisitionInformation/gm...
#
# [133519 rows x 4 columns]

# %% [markdown]
# I noticed that some ISO dialect definitions create exact duplicate rows, so the next cell drops those from the dataframe and saves another version of the csv. To double check I reran using just saxon:path() for the absolute location and still had the same amount of reduction in rows, so it may be a better output. I'm not sure that there will be a need for it in dialects that use xpaths that resolve to the level of the content rather than a higher order element in the hierarchy.
