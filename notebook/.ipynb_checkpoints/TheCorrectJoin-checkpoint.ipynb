# %% [markdown]
# ### While the evaluator identifies and assigns a concept name to many geoscience metadata dialects, there is also much content that is not defined in the dialect. This notebook compares the output from KnownNodes.xsl and AllNodes.xsl to identify xpaths that do not have a dialect definition. It then appends the resulting dataframe to the KnownNodes dataframe. This gives a complete representation of the metadata.

# %% [markdown]
# Import the python packages needed

# %%
import pandas as pd

# %% [markdown]
# Read in the defined content for BCO-DMO's GeoTraces collection, written in the ISO dialect.

# %%
KnownNodesDF= pd.read_csv('../data/BCO-DMO/GeoTraces_ISO_dataKnown.csv')
KnownNodesDF
# Out:
#                    Record                          Concept  \
# 0        dataset_3470.xml                   Resource Title
# 1        dataset_3470.xml  Resource Creation/Revision Date
# 2        dataset_3470.xml                         Abstract
# 3        dataset_3470.xml                   Topic Category
# 4        dataset_3470.xml                    Theme Keyword
# 5        dataset_3470.xml                    Theme Keyword
# 6        dataset_3470.xml                    Theme Keyword
# 7        dataset_3470.xml                    Theme Keyword
# 8        dataset_3470.xml                    Theme Keyword
# 9        dataset_3470.xml                    Theme Keyword
# 10       dataset_3470.xml                    Theme Keyword
# 11       dataset_3470.xml                    Theme Keyword
# 12       dataset_3470.xml                    Theme Keyword
# 13       dataset_3470.xml                    Theme Keyword
# 14       dataset_3470.xml                    Theme Keyword
# 15       dataset_3470.xml                    Theme Keyword
# 16       dataset_3470.xml                    Theme Keyword
# 17       dataset_3470.xml                    Theme Keyword
# 18       dataset_3470.xml                    Theme Keyword
# 19       dataset_3470.xml                    Theme Keyword
# 20       dataset_3470.xml                    Theme Keyword
# 21       dataset_3470.xml                    Theme Keyword
# 22       dataset_3470.xml               Keyword Vocabulary
# 23       dataset_3470.xml               Keyword Vocabulary
# 24       dataset_3470.xml               Keyword Vocabulary
# 25       dataset_3470.xml               Keyword Vocabulary
# 26       dataset_3470.xml               Keyword Vocabulary
# 27       dataset_3470.xml                 Metadata Contact
# 28       dataset_3470.xml                 Resource Contact
# 29       dataset_3470.xml                             Role
# ...                   ...                              ...
# 71412  dataset_651138.xml                          Keyword
# 71413  dataset_651138.xml                          Keyword
# 71414  dataset_651138.xml                          Keyword
# 71415  dataset_651138.xml                          Keyword
# 71416  dataset_651138.xml                          Keyword
# 71417  dataset_651138.xml                          Keyword
# 71418  dataset_651138.xml                          Keyword
# 71419  dataset_651138.xml                          Keyword
# 71420  dataset_651138.xml                          Keyword
# 71421  dataset_651138.xml                          Keyword
# 71422  dataset_651138.xml                          Keyword
# 71423  dataset_651138.xml                          Keyword
# 71424  dataset_651138.xml                          Keyword
# 71425  dataset_651138.xml                          Keyword
# 71426  dataset_651138.xml                          Keyword
# 71427  dataset_651138.xml                          Keyword
# 71428  dataset_651138.xml                          Keyword
# 71429  dataset_651138.xml                          Keyword
# 71430  dataset_651138.xml                          Keyword
# 71431  dataset_651138.xml                          Keyword
# 71432  dataset_651138.xml                          Keyword
# 71433  dataset_651138.xml                          Keyword
# 71434  dataset_651138.xml                          Keyword
# 71435  dataset_651138.xml                          Keyword
# 71436  dataset_651138.xml                          Keyword
# 71437  dataset_651138.xml                          Keyword
# 71438  dataset_651138.xml                          Keyword
# 71439  dataset_651138.xml                          Keyword
# 71440  dataset_651138.xml                          Keyword
# 71441  dataset_651138.xml                          Keyword
#
#                                                                                                                                              XPath  \
# 0                                         /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:citation/gmd:CI_Citation/gmd:title
# 1            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:citation/gmd:CI_Citation/gmd:date/gmd:CI_Date/gmd:date/gco:Date
# 2                                                                   /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:abstract
# 3                                     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:topicCategory/gmd:MD_TopicCategoryCode
# 4                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 5                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 6                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 7                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 8                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 9                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 10                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 11                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 12                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 13                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 14                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 15                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 16                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 17                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 18                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 19                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 20                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 21                           /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 22     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:thesaurusName/gmd:CI_Citation
# 23     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:thesaurusName/gmd:CI_Citation
# 24     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:thesaurusName/gmd:CI_Citation
# 25     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:thesaurusName/gmd:CI_Citation
# 26     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:thesaurusName/gmd:CI_Citation
# 27                                                                                                                    /gmi:MI_Metadata/gmd:contact
# 28                                                            /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:pointOfContact
# 29                                                                   /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:role/gmd:CI_RoleCode
# ...                                                                                                                                            ...
# 71412                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71413                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71414                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71415                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71416                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71417                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71418                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71419                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71420                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71421                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71422                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71423                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71424                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71425                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71426                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71427                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71428                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71429                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71430                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71431                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71432                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71433                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71434                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71435                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71436                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71437                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71438                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71439                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71440                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
# 71441                        /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:descriptiveKeywords/gmd:MD_Keywords/gmd:keyword
#
#                                                                                                                                                      Content
# 0                                                     GT10 - Nanomolar Nutrients - Surface from the U.S. GEOTRACES NAT project of the U.S. GEOTRACES program
# 1                                                                                                                                                 2013-02-27
# 2      Nanomolar concentrations of PO4, NO3, NO2 (surface) Dataset Description: &lt;p&gt;Nanomolar concentrations of PO4, NO3, NO2 - Surface Transects.&l...
# 3                                                                                                                                                     oceans
# 4                                                                                                                                                  cruise_id
# 5                                                                                                                                                       date
# 6                                                                                                                                                       time
# 7                                                                                                                                                   latitude
# 8                                                                                                                                                  longitude
# 9                                                                                                                                                     sample
# 10                                                                                                                                                dataset_id
# 11                                                                                                                                                       PO4
# 12                                                                                                                                                      flag
# 13                                                                                                                                                       NO3
# 14                                                                                                                                                      flag
# 15                                                                                                                                                       NO2
# 16                                                                                                                                                      flag
# 17                                                                                                                                     activity_and_comments
# 18                                                                                                                                                     event
# 19                                                                                                                                                    sample
# 20                                                                                                                                          ISO_DateTime_UTC
# 21                                                                                                                                                   GeoFish
# 22                                                                                                                                        None, User defined
# 23                                                                                                                               BCO-DMO Standard Parameters
# 24                                                                                                                              BCO-DMO Standard Instruments
# 25                                                                                                                                       Deployment Activity
# 26                                                                                                                                                 Locations
# 27     Biological and Chemical Oceanography Data Management Office (BCO-DMO) Unavailable 508-289-2009 WHOI MS#36 Woods Hole MA 02543 USA info@bco-dmo.org...
# 28     Dr Gregory Cutter Old Dominion University 757-683-4929 Department of Ocean, Earth, and Atmospheric Sciences 4500 Elkhorn Ave Norfolk VA 23529-0276...
# 29                                                                                                                                            pointOfContact
# ...                                                                                                                                                      ...
# 71412                                                                                                                                       trace_metal_conc
# 71413                                                                                                                                       trace_metal_conc
# 71414                                                                                                                                       trace_metal_conc
# 71415                                                                                                                                       trace_metal_conc
# 71416                                                                                                                                       trace_metal_conc
# 71417                                                                                                                                       trace_metal_conc
# 71418                                                                                                                                       ISO_DateTime_UTC
# 71419                                                                                                                                                 ICP-MS
# 71420                                                                                                                                                 Bottle
# 71421                                                                                                                                                GeoFish
# 71422                                                                                                                    Subtropical northern Atlantic Ocean
# 71423                                                                                                                                              cruise id
# 71424                                                                                                                                            cruise name
# 71425                                                                                                                                                station
# 71426                                                                                                                                                   cast
# 71427                                                                                                                                                    tow
# 71428                                                                                                                                               latitude
# 71429                                                                                                                                              longitude
# 71430                                                                                                                                                  depth
# 71431                                                                                                                                  sample identification
# 71432                                                                                                                                         water pressure
# 71433                                                                                                                              trace metal concentration
# 71434                                                                                                                                                   flag
# 71435                                                                                                                                       ISO_DateTime_UTC
# 71436                                                                                                                                               KN199-04
# 71437                                                                                                                                               KN199-05
# 71438                                                                                                                                               KN204-01
# 71439                                                                                                           Inductively Coupled Plasma Mass Spectrometer
# 71440                                                                                                                       GO-FLO Teflon Trace Metal Bottle
# 71441                                                                                                                     GeoFish Towed near-Surface Sampler
#
# [71442 rows x 4 columns]

# %% [markdown]
# Read in all the content for BCO-DMO's GeoTraces collection, written in the ISO dialect.

# %%
AllNodesDF = pd.read_csv('../data/BCO-DMO/GeoTraces_ISO_dataAll.csv')
AllNodesDF
# Out:
#                     Record  \
# 0         dataset_3470.xml
# 1         dataset_3470.xml
# 2         dataset_3470.xml
# 3         dataset_3470.xml
# 4         dataset_3470.xml
# 5         dataset_3470.xml
# 6         dataset_3470.xml
# 7         dataset_3470.xml
# 8         dataset_3470.xml
# 9         dataset_3470.xml
# 10        dataset_3470.xml
# 11        dataset_3470.xml
# 12        dataset_3470.xml
# 13        dataset_3470.xml
# 14        dataset_3470.xml
# 15        dataset_3470.xml
# 16        dataset_3470.xml
# 17        dataset_3470.xml
# 18        dataset_3470.xml
# 19        dataset_3470.xml
# 20        dataset_3470.xml
# 21        dataset_3470.xml
# 22        dataset_3470.xml
# 23        dataset_3470.xml
# 24        dataset_3470.xml
# 25        dataset_3470.xml
# 26        dataset_3470.xml
# 27        dataset_3470.xml
# 28        dataset_3470.xml
# 29        dataset_3470.xml
# ...                    ...
# 117963  dataset_651138.xml
# 117964  dataset_651138.xml
# 117965  dataset_651138.xml
# 117966  dataset_651138.xml
# 117967  dataset_651138.xml
# 117968  dataset_651138.xml
# 117969  dataset_651138.xml
# 117970  dataset_651138.xml
# 117971  dataset_651138.xml
# 117972  dataset_651138.xml
# 117973  dataset_651138.xml
# 117974  dataset_651138.xml
# 117975  dataset_651138.xml
# 117976  dataset_651138.xml
# 117977  dataset_651138.xml
# 117978  dataset_651138.xml
# 117979  dataset_651138.xml
# 117980  dataset_651138.xml
# 117981  dataset_651138.xml
# 117982  dataset_651138.xml
# 117983  dataset_651138.xml
# 117984  dataset_651138.xml
# 117985  dataset_651138.xml
# 117986  dataset_651138.xml
# 117987  dataset_651138.xml
# 117988  dataset_651138.xml
# 117989  dataset_651138.xml
# 117990  dataset_651138.xml
# 117991  dataset_651138.xml
# 117992  dataset_651138.xml
#
#                                                                                                                                                         XPath  \
# 0                                                                                                                        /gmi:MI_Metadata/@xsi:schemaLocation
# 1                                                                                                     /gmi:MI_Metadata/gmd:fileIdentifier/gco:CharacterString
# 2                                                                                                           /gmi:MI_Metadata/gmd:language/gco:CharacterString
# 3                                                                                                   /gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode
# 4                                                                                         /gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode/@codeList
# 5                                                                                    /gmi:MI_Metadata/gmd:characterSet/gmd:MD_CharacterSetCode/@codeListValue
# 6                                                                                                        /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_ScopeCode
# 7                                                                                              /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_ScopeCode/@codeList
# 8                                                                                         /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_ScopeCode/@codeListValue
# 9                                                                                             /gmi:MI_Metadata/gmd:hierarchyLevel/gmd:MD_ScopeCode/@codeSpace
# 10                                                                                                /gmi:MI_Metadata/gmd:hierarchyLevelName/gco:CharacterString
# 11                                                                       /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:organisationName/gmx:Anchor
# 12                                                           /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:organisationName/gmx:Anchor/@xlink:href
# 13                                                        /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:organisationName/gmx:Anchor/@xlink:actuate
# 14               /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:phone/gmd:CI_Telephone/gmd:voice/gco:CharacterString
# 15           /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:phone/gmd:CI_Telephone/gmd:facsimile/gco:CharacterString
# 16       /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:deliveryPoint/gco:CharacterString
# 17                /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:city/gco:CharacterString
# 18      /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:administrativeArea/gco:Characte...
# 19          /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:postalCode/gco:CharacterString
# 20             /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:country/gco:CharacterString
# 21      /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:electronicMailAddress/gco:Chara...
# 22           /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:onlineResource/gmd:CI_OnlineResource/gmd:linkage/gmd:URL
# 23                                 /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:hoursOfService/gco:CharacterString
# 24                            /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:contactInstructions/gco:CharacterString
# 25                                                                              /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:role/gmd:CI_RoleCode
# 26                                                                    /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:role/gmd:CI_RoleCode/@codeList
# 27                                                               /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:role/gmd:CI_RoleCode/@codeListValue
# 28                                                                   /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:role/gmd:CI_RoleCode/@codeSpace
# 29                                                                                                                    /gmi:MI_Metadata/gmd:dateStamp/gco:Date
# ...                                                                                                                                                       ...
# 117963  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117964  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117965  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117966  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117967  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117968  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117969  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117970  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117971  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117972  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117973  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117974  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:instrume...
# 117975  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_Pr...
# 117976  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_Pr...
# 117977  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117978  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117979  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117980  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117981  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117982  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117983  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117984  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117985  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117986  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117987  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117988  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117989  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117990  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117991  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117992  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
#
#                                                                                                                             Content
# 0                                       http://www.isotc211.org/2005/gmi http://www.ngdc.noaa.gov/metadata/published/xsd/schema.xsd
# 1                                                                                            http://lod.bco-dmo.org/id/dataset/3470
# 2                                                                                                                          eng; USA
# 3                                                                                                                              utf8
# 4                                              http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_CharacterSetCode
# 5                                                                                                                              utf8
# 6                                                                                                                           dataset
# 7                                                     http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_ScopeCode
# 8                                                                                                                           dataset
# 9                                                                                                                               005
# 10      Highest level of data collection, from a common set of sensors or instrumentation, usually within the same research project
# 11                                                            Biological and Chemical Oceanography Data Management Office (BCO-DMO)
# 12                                                                                    http://lod.bco-dmo.org/id/affiliation/191.rdf
# 13                                                                                                                        onRequest
# 14                                                                                                                      Unavailable
# 15                                                                                                                     508-289-2009
# 16                                                                                                                       WHOI MS#36
# 17                                                                                                                       Woods Hole
# 18                                                                                                                               MA
# 19                                                                                                                            02543
# 20                                                                                                                              USA
# 21                                                                                                                 info@bco-dmo.org
# 22                                                                                                           http://www.bco-dmo.org
# 23                                                                                                  Monday - Friday 8:00am - 5:00pm
# 24                                    For questions regarding this resource, please contact BCO-DMO via the email address provided.
# 25                                                                                                                   pointOfContact
# 26                                                     http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#CI_RoleCode
# 27                                                                                                                   pointOfContact
# 28                                                                                                                              007
# 29                                                                                                                       2011-05-03
# ...                                                                                                                             ...
# 117963                                                                                    http://lod.bco-dmo.org/id/authority/1.rdf
# 117964                                                                                                                    onRequest
# 117965                                                                                                                      unknown
# 117966                                                                                                                    R/V Knorr
# 117967                                                                                 http://lod.bco-dmo.org/id/platform/53994.rdf
# 117968                                                                                                                         316N
# 117969                                                                                                                    onRequest
# 117970                                                                                                                       vessel
# 117971                                                                                 http://lod.bco-dmo.org/id/platform/53994.rdf
# 117972                                                                                                                    R/V Knorr
# 117973                                                                                                                    onRequest
# 117974                                                                                                                      unknown
# 117975                                             http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 117976                                                                                                                    completed
# 117977                                                                                                                     KN204-01
# 117978                                                                               http://lod.bco-dmo.org/id/deployment/58786.rdf
# 117979                                                                                                                       Cruise
# 117980                                                                                                                    onRequest
# 117981                                                                                                                      unknown
# 117982                                                                                                           Dr Edward A. Boyle
# 117983                                                                                   http://lod.bco-dmo.org/id/person/50984.rdf
# 117984                                                                                                                    onRequest
# 117985                                                                                        Massachusetts Institute of Technology
# 117986                                                                                http://lod.bco-dmo.org/id/affiliation/222.rdf
# 117987                                                                                                                  Affiliation
# 117988                                                                                                                    onRequest
# 117989                                                 http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/STS_Prelim_GT11_Doc.pdf
# 117990                                                                                                   Report describing KN204-01
# 117991                                                 http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#CI_RoleCode
# 117992                                                                                                        principalInvestigator
#
# [117993 rows x 3 columns]

# %% [markdown]
# Create a new dataframe from the rows in AllNodesDF that have an xpath that does not occur in KnownNodesDF then append it to the KnownNodesDF, creating ConceptIfKnownDF sorting by record and concept, then saving it to csv.

# %%
UnknownNodesDF=AllNodesDF[(~AllNodesDF.XPath.isin(KnownNodesDF.XPath))]
ConceptIfKnownDF=pd.concat([KnownNodesDF,UnknownNodesDF], axis=0).sort_values(['Record', 'Concept'])
ConceptIfKnownDF.to_csv('../data/BCO-DMO/data.csv', index=False)
ConceptIfKnownDF
# Out:
#                      Concept  \
# 2                   Abstract
# 261          Acknowledgement
# 262          Acknowledgement
# 80                   Address
# 81                   Address
# 82                   Address
# 83                   Address
# 84                   Address
# 243           AssociatedDIFs
# 244           AssociatedDIFs
# 164              Association
# 165              Association
# 197     Attribute Definition
# 198     Attribute Definition
# 199     Attribute Definition
# 200     Attribute Definition
# 201     Attribute Definition
# 202     Attribute Definition
# 203     Attribute Definition
# 204     Attribute Definition
# 205     Attribute Definition
# 206     Attribute Definition
# 207     Attribute Definition
# 208     Attribute Definition
# 209     Attribute Definition
# 210     Attribute Definition
# 211     Attribute Definition
# 212     Attribute Definition
# 213     Attribute Definition
# 180          Attribute Label
# ...                      ...
# 117963                   NaN
# 117964                   NaN
# 117965                   NaN
# 117966                   NaN
# 117967                   NaN
# 117968                   NaN
# 117969                   NaN
# 117970                   NaN
# 117971                   NaN
# 117972                   NaN
# 117973                   NaN
# 117974                   NaN
# 117975                   NaN
# 117976                   NaN
# 117977                   NaN
# 117978                   NaN
# 117979                   NaN
# 117980                   NaN
# 117981                   NaN
# 117982                   NaN
# 117983                   NaN
# 117984                   NaN
# 117985                   NaN
# 117986                   NaN
# 117987                   NaN
# 117988                   NaN
# 117989                   NaN
# 117990                   NaN
# 117991                   NaN
# 117992                   NaN
#
#                                                                                                                                                       Content  \
# 2       Nanomolar concentrations of PO4, NO3, NO2 (surface) Dataset Description: &lt;p&gt;Nanomolar concentrations of PO4, NO3, NO2 - Surface Transects.&l...
# 261     Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926423 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926423
# 262     Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926092 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926092
# 80                                                                                                                                                 WHOI MS#36
# 81                                                                                      Department of Ocean, Earth, and Atmospheric Sciences 4500 Elkhorn Ave
# 82                                                                                                                                                 WHOI MS#36
# 83                                                                                                                                                 WHOI MS#36
# 84                                                                                                                                                 WHOI MS#36
# 243                                                                                                                                            U.S. GEOTRACES
# 244                                                                                                                                        U.S. GEOTRACES NAT
# 164     U.S. GEOTRACES http://www.geotraces.org/ U.S. GEOTRACES GEOTRACES is a SCOR sponsored program; and funding for program infrastructure development ...
# 165     U.S. GEOTRACES North Atlantic Transect http://www.geotraces.org/ U.S. GEOTRACES North Atlantic Transect http://bcodata.whoi.edu/US_GEOTRACES/Atlan...
# 197        PI-supplied Description: Official cruise identifier e.g. KN199-04 = R/V Knorr cruise number 199-04.; General Description: cruise designation; name
# 198     PI-supplied Description: date (GMT); General Description: date; generally reported in GMT as YYYYMMDD (year; month; day); also as MMDD (month; day...
# 199     PI-supplied Description: time (GMT); General Description: Time GMT defined as HHMM; time of day; generally reported in GMT as HHMM (hours and minu...
# 200     PI-supplied Description: Station latitude (South is negative); General Description: latitude, in decimal degrees, North is positive, negative deno...
# 201     PI-supplied Description: Station longitude (West is negative); General Description: longitude, in decimal degrees, East is positive, negative deno...
# 202     PI-supplied Description: Identifying number of a GeoFish tow, numbered consecutively within a cruise. PI-supplied values were identical to those i...
# 203     PI-supplied Description: Unique identifiers for ALL vertical profile samples (and surface fish samples when we arrive on station, or depart).; Gen...
# 204     PI-supplied Description: PO4: phosphate (reactive - or ortho-phosphate); General Description: Orthophosphate, (phosphate, reactive phosphorus) µM ...
# 205     PI-supplied Description: PO4 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); ...
# 206                                                         PI-supplied Description: NO3: Nitrate = (Nitrate+nitrite) - nitrite; General Description: Nitrate
# 207     PI-supplied Description: NO3 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); ...
# 208     PI-supplied Description: NO2: Nitrite; General Description: Nitrite NERC Description: The phase is described as unknown to indicate that there is ...
# 209     PI-supplied Description: NO2 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); ...
# 210                                PI-supplied Description: Remarks; General Description: operation performed and/or sampling method for given sampling event
# 211     PI-supplied Description: Unique identifying number for US GEOTRACES sampling events; ranges from 2001 to 2225 for KN199-04 events and from 3001 to...
# 212     PI-supplied Description: Unique identifying number for US GEOTRACES samples; ranges from 5033 to 6078 for KN199-04 and from 6112 to 8148 for KN204...
# 213     PI-supplied Description: Date/Time (UTC) formatted to ISO8601. T indicates start of time string; Z indicates UTC. Calculated from the original dat...
# 180                                                                                                                                                 cruise_id
# ...                                                                                                                                                       ...
# 117963                                                                                                              http://lod.bco-dmo.org/id/authority/1.rdf
# 117964                                                                                                                                              onRequest
# 117965                                                                                                                                                unknown
# 117966                                                                                                                                              R/V Knorr
# 117967                                                                                                           http://lod.bco-dmo.org/id/platform/53994.rdf
# 117968                                                                                                                                                   316N
# 117969                                                                                                                                              onRequest
# 117970                                                                                                                                                 vessel
# 117971                                                                                                           http://lod.bco-dmo.org/id/platform/53994.rdf
# 117972                                                                                                                                              R/V Knorr
# 117973                                                                                                                                              onRequest
# 117974                                                                                                                                                unknown
# 117975                                                                       http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#MD_ProgressCode
# 117976                                                                                                                                              completed
# 117977                                                                                                                                               KN204-01
# 117978                                                                                                         http://lod.bco-dmo.org/id/deployment/58786.rdf
# 117979                                                                                                                                                 Cruise
# 117980                                                                                                                                              onRequest
# 117981                                                                                                                                                unknown
# 117982                                                                                                                                     Dr Edward A. Boyle
# 117983                                                                                                             http://lod.bco-dmo.org/id/person/50984.rdf
# 117984                                                                                                                                              onRequest
# 117985                                                                                                                  Massachusetts Institute of Technology
# 117986                                                                                                          http://lod.bco-dmo.org/id/affiliation/222.rdf
# 117987                                                                                                                                            Affiliation
# 117988                                                                                                                                              onRequest
# 117989                                                                           http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/STS_Prelim_GT11_Doc.pdf
# 117990                                                                                                                             Report describing KN204-01
# 117991                                                                           http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#CI_RoleCode
# 117992                                                                                                                                  principalInvestigator
#
#                     Record  \
# 2         dataset_3470.xml
# 261       dataset_3470.xml
# 262       dataset_3470.xml
# 80        dataset_3470.xml
# 81        dataset_3470.xml
# 82        dataset_3470.xml
# 83        dataset_3470.xml
# 84        dataset_3470.xml
# 243       dataset_3470.xml
# 244       dataset_3470.xml
# 164       dataset_3470.xml
# 165       dataset_3470.xml
# 197       dataset_3470.xml
# 198       dataset_3470.xml
# 199       dataset_3470.xml
# 200       dataset_3470.xml
# 201       dataset_3470.xml
# 202       dataset_3470.xml
# 203       dataset_3470.xml
# 204       dataset_3470.xml
# 205       dataset_3470.xml
# 206       dataset_3470.xml
# 207       dataset_3470.xml
# 208       dataset_3470.xml
# 209       dataset_3470.xml
# 210       dataset_3470.xml
# 211       dataset_3470.xml
# 212       dataset_3470.xml
# 213       dataset_3470.xml
# 180       dataset_3470.xml
# ...                    ...
# 117963  dataset_651138.xml
# 117964  dataset_651138.xml
# 117965  dataset_651138.xml
# 117966  dataset_651138.xml
# 117967  dataset_651138.xml
# 117968  dataset_651138.xml
# 117969  dataset_651138.xml
# 117970  dataset_651138.xml
# 117971  dataset_651138.xml
# 117972  dataset_651138.xml
# 117973  dataset_651138.xml
# 117974  dataset_651138.xml
# 117975  dataset_651138.xml
# 117976  dataset_651138.xml
# 117977  dataset_651138.xml
# 117978  dataset_651138.xml
# 117979  dataset_651138.xml
# 117980  dataset_651138.xml
# 117981  dataset_651138.xml
# 117982  dataset_651138.xml
# 117983  dataset_651138.xml
# 117984  dataset_651138.xml
# 117985  dataset_651138.xml
# 117986  dataset_651138.xml
# 117987  dataset_651138.xml
# 117988  dataset_651138.xml
# 117989  dataset_651138.xml
# 117990  dataset_651138.xml
# 117991  dataset_651138.xml
# 117992  dataset_651138.xml
#
#                                                                                                                                                         XPath
# 2                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:abstract
# 261                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:credit
# 262                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:credit
# 80                           /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:deliveryPoint
# 81      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:pointOfContact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:ad...
# 82      /gmi:MI_Metadata/gmd:contentInfo/gmd:MD_FeatureCatalogueDescription/gmd:featureCatalogueCitation/gmd:CI_Citation/gmd:citedResponsibleParty/gmd:CI_...
# 83      /gmi:MI_Metadata/gmd:distributionInfo/gmd:MD_Distribution/gmd:distributor/gmd:MD_Distributor/gmd:distributorContact/gmd:CI_ResponsibleParty/gmd:co...
# 84      /gmi:MI_Metadata/gmd:metadataMaintenance/gmd:MD_MaintenanceInformation/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:addr...
# 243     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation/gmd:aggregateDataSetIdentifier/g...
# 244     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation/gmd:aggregateDataSetIdentifier/g...
# 164                                         /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation
# 165                                         /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation
# 197                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 198                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 199                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 200                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 201                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 202                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 203                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 204                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 205                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 206                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 207                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 208                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 209                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 210                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 211                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 212                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 213                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 180                     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/gco:MemberName/gco:aName
# ...                                                                                                                                                       ...
# 117963  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117964  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117965  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117966  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117967  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117968  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117969  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:identifi...
# 117970  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117971  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117972  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117973  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:descript...
# 117974  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:platform/gmi:MI_Platform/gmi:instrume...
# 117975  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_Pr...
# 117976  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:status/gmd:MD_Pr...
# 117977  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117978  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117979  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117980  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117981  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117982  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117983  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117984  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117985  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117986  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117987  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117988  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117989  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117990  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117991  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117992  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
#
# [173682 rows x 4 columns]

# %% [markdown]
# I noticed that some ISO dialect definitions create exact duplicate rows, so the next cell drops those from the dataframe and saves another version of the csv. To double check I reran using just saxon:path() for the absolute location and still had the same amount of reduction in rows, so it may be a better output. I'm not sure that there will be a need for it in dialects that use xpaths that resolve to the level of the content rather than a higher order element in the hierarchy.

# %%
uniqueCIKDF=ConceptIfKnownDF.drop_duplicates()
uniqueCIKDF.to_csv('../data/BCO-DMO/data2.csv', index=False)
uniqueCIKDF
# Out:
#                      Concept  \
# 2                   Abstract
# 261          Acknowledgement
# 262          Acknowledgement
# 80                   Address
# 81                   Address
# 82                   Address
# 83                   Address
# 84                   Address
# 243           AssociatedDIFs
# 244           AssociatedDIFs
# 164              Association
# 165              Association
# 197     Attribute Definition
# 198     Attribute Definition
# 199     Attribute Definition
# 200     Attribute Definition
# 201     Attribute Definition
# 202     Attribute Definition
# 203     Attribute Definition
# 204     Attribute Definition
# 205     Attribute Definition
# 206     Attribute Definition
# 207     Attribute Definition
# 208     Attribute Definition
# 209     Attribute Definition
# 210     Attribute Definition
# 211     Attribute Definition
# 212     Attribute Definition
# 213     Attribute Definition
# 180          Attribute Label
# ...                      ...
# 117883                   NaN
# 117884                   NaN
# 117885                   NaN
# 117886                   NaN
# 117887                   NaN
# 117888                   NaN
# 117889                   NaN
# 117890                   NaN
# 117891                   NaN
# 117892                   NaN
# 117893                   NaN
# 117894                   NaN
# 117895                   NaN
# 117896                   NaN
# 117897                   NaN
# 117898                   NaN
# 117899                   NaN
# 117930                   NaN
# 117931                   NaN
# 117944                   NaN
# 117945                   NaN
# 117946                   NaN
# 117977                   NaN
# 117978                   NaN
# 117982                   NaN
# 117983                   NaN
# 117985                   NaN
# 117986                   NaN
# 117989                   NaN
# 117990                   NaN
#
#                                                                                                                                                       Content  \
# 2       Nanomolar concentrations of PO4, NO3, NO2 (surface) Dataset Description: &lt;p&gt;Nanomolar concentrations of PO4, NO3, NO2 - Surface Transects.&l...
# 261     Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926423 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926423
# 262     Funding provided by NSF Ocean Sciences (NSF OCE) Award Number: OCE-0926092 Award URL: http://www.nsf.gov/awardsearch/showAward.do?AwardNumber=0926092
# 80                                                                                                                                                 WHOI MS#36
# 81                                                                                      Department of Ocean, Earth, and Atmospheric Sciences 4500 Elkhorn Ave
# 82                                                                                                                                                 WHOI MS#36
# 83                                                                                                                                                 WHOI MS#36
# 84                                                                                                                                                 WHOI MS#36
# 243                                                                                                                                            U.S. GEOTRACES
# 244                                                                                                                                        U.S. GEOTRACES NAT
# 164     U.S. GEOTRACES http://www.geotraces.org/ U.S. GEOTRACES GEOTRACES is a SCOR sponsored program; and funding for program infrastructure development ...
# 165     U.S. GEOTRACES North Atlantic Transect http://www.geotraces.org/ U.S. GEOTRACES North Atlantic Transect http://bcodata.whoi.edu/US_GEOTRACES/Atlan...
# 197        PI-supplied Description: Official cruise identifier e.g. KN199-04 = R/V Knorr cruise number 199-04.; General Description: cruise designation; name
# 198     PI-supplied Description: date (GMT); General Description: date; generally reported in GMT as YYYYMMDD (year; month; day); also as MMDD (month; day...
# 199     PI-supplied Description: time (GMT); General Description: Time GMT defined as HHMM; time of day; generally reported in GMT as HHMM (hours and minu...
# 200     PI-supplied Description: Station latitude (South is negative); General Description: latitude, in decimal degrees, North is positive, negative deno...
# 201     PI-supplied Description: Station longitude (West is negative); General Description: longitude, in decimal degrees, East is positive, negative deno...
# 202     PI-supplied Description: Identifying number of a GeoFish tow, numbered consecutively within a cruise. PI-supplied values were identical to those i...
# 203     PI-supplied Description: Unique identifiers for ALL vertical profile samples (and surface fish samples when we arrive on station, or depart).; Gen...
# 204     PI-supplied Description: PO4: phosphate (reactive - or ortho-phosphate); General Description: Orthophosphate, (phosphate, reactive phosphorus) µM ...
# 205     PI-supplied Description: PO4 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); ...
# 206                                                         PI-supplied Description: NO3: Nitrate = (Nitrate+nitrite) - nitrite; General Description: Nitrate
# 207     PI-supplied Description: NO3 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); ...
# 208     PI-supplied Description: NO2: Nitrite; General Description: Nitrite NERC Description: The phase is described as unknown to indicate that there is ...
# 209     PI-supplied Description: NO2 Data Flag: Samples were measured in triplicate (flag=6); Samples out of linear calibration range for LWCC (flag=10); ...
# 210                                PI-supplied Description: Remarks; General Description: operation performed and/or sampling method for given sampling event
# 211     PI-supplied Description: Unique identifying number for US GEOTRACES sampling events; ranges from 2001 to 2225 for KN199-04 events and from 3001 to...
# 212     PI-supplied Description: Unique identifying number for US GEOTRACES samples; ranges from 5033 to 6078 for KN199-04 and from 6112 to 8148 for KN204...
# 213     PI-supplied Description: Date/Time (UTC) formatted to ISO8601. T indicates start of time string; Z indicates UTC. Calculated from the original dat...
# 180                                                                                                                                                 cruise_id
# ...                                                                                                                                                       ...
# 117883                                                                                                                                                 Cruise
# 117884                                                                                                                                              onRequest
# 117885                                                                                                                                                unknown
# 117886                                                                                                                                  Dr William J. Jenkins
# 117887                                                                                                             http://lod.bco-dmo.org/id/person/50745.rdf
# 117888                                                                                                                                              onRequest
# 117889                                                                                                                   Woods Hole Oceanographic Institution
# 117890                                                                                                            http://lod.bco-dmo.org/id/affiliation/2.rdf
# 117891                                                                                                                                            Affiliation
# 117892                                                                                                                                              onRequest
# 117893                                                          http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/Cruise_Report_for_Knorr_199_Final_v3.pdf
# 117894                                                                                                                             Report describing KN199-04
# 117895                                                                           http://www.isotc211.org/2005/resources/Codelist/gmxCodelists.xml#CI_RoleCode
# 117896                                                                                                                                  principalInvestigator
# 117897                                                                                                                                       Cruise: KN199-05
# 117898                                                                                                                                               KN199-05
# 117899                                                                                                         http://lod.bco-dmo.org/id/deployment/58142.rdf
# 117930                                                                                                                                               KN199-05
# 117931                                                                                                         http://lod.bco-dmo.org/id/deployment/58142.rdf
# 117944                                                                                                                                       Cruise: KN204-01
# 117945                                                                                                                                               KN204-01
# 117946                                                                                                         http://lod.bco-dmo.org/id/deployment/58786.rdf
# 117977                                                                                                                                               KN204-01
# 117978                                                                                                         http://lod.bco-dmo.org/id/deployment/58786.rdf
# 117982                                                                                                                                     Dr Edward A. Boyle
# 117983                                                                                                             http://lod.bco-dmo.org/id/person/50984.rdf
# 117985                                                                                                                  Massachusetts Institute of Technology
# 117986                                                                                                          http://lod.bco-dmo.org/id/affiliation/222.rdf
# 117989                                                                           http://bcodata.whoi.edu/US_GEOTRACES/AtlanticSection/STS_Prelim_GT11_Doc.pdf
# 117990                                                                                                                             Report describing KN204-01
#
#                     Record  \
# 2         dataset_3470.xml
# 261       dataset_3470.xml
# 262       dataset_3470.xml
# 80        dataset_3470.xml
# 81        dataset_3470.xml
# 82        dataset_3470.xml
# 83        dataset_3470.xml
# 84        dataset_3470.xml
# 243       dataset_3470.xml
# 244       dataset_3470.xml
# 164       dataset_3470.xml
# 165       dataset_3470.xml
# 197       dataset_3470.xml
# 198       dataset_3470.xml
# 199       dataset_3470.xml
# 200       dataset_3470.xml
# 201       dataset_3470.xml
# 202       dataset_3470.xml
# 203       dataset_3470.xml
# 204       dataset_3470.xml
# 205       dataset_3470.xml
# 206       dataset_3470.xml
# 207       dataset_3470.xml
# 208       dataset_3470.xml
# 209       dataset_3470.xml
# 210       dataset_3470.xml
# 211       dataset_3470.xml
# 212       dataset_3470.xml
# 213       dataset_3470.xml
# 180       dataset_3470.xml
# ...                    ...
# 117883  dataset_651138.xml
# 117884  dataset_651138.xml
# 117885  dataset_651138.xml
# 117886  dataset_651138.xml
# 117887  dataset_651138.xml
# 117888  dataset_651138.xml
# 117889  dataset_651138.xml
# 117890  dataset_651138.xml
# 117891  dataset_651138.xml
# 117892  dataset_651138.xml
# 117893  dataset_651138.xml
# 117894  dataset_651138.xml
# 117895  dataset_651138.xml
# 117896  dataset_651138.xml
# 117897  dataset_651138.xml
# 117898  dataset_651138.xml
# 117899  dataset_651138.xml
# 117930  dataset_651138.xml
# 117931  dataset_651138.xml
# 117944  dataset_651138.xml
# 117945  dataset_651138.xml
# 117946  dataset_651138.xml
# 117977  dataset_651138.xml
# 117978  dataset_651138.xml
# 117982  dataset_651138.xml
# 117983  dataset_651138.xml
# 117985  dataset_651138.xml
# 117986  dataset_651138.xml
# 117989  dataset_651138.xml
# 117990  dataset_651138.xml
#
#                                                                                                                                                         XPath
# 2                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:abstract
# 261                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:credit
# 262                                                                              /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:credit
# 80                           /gmi:MI_Metadata/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:address/gmd:CI_Address/gmd:deliveryPoint
# 81      /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:pointOfContact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:ad...
# 82      /gmi:MI_Metadata/gmd:contentInfo/gmd:MD_FeatureCatalogueDescription/gmd:featureCatalogueCitation/gmd:CI_Citation/gmd:citedResponsibleParty/gmd:CI_...
# 83      /gmi:MI_Metadata/gmd:distributionInfo/gmd:MD_Distribution/gmd:distributor/gmd:MD_Distributor/gmd:distributorContact/gmd:CI_ResponsibleParty/gmd:co...
# 84      /gmi:MI_Metadata/gmd:metadataMaintenance/gmd:MD_MaintenanceInformation/gmd:contact/gmd:CI_ResponsibleParty/gmd:contactInfo/gmd:CI_Contact/gmd:addr...
# 243     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation/gmd:aggregateDataSetIdentifier/g...
# 244     /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation/gmd:aggregateDataSetIdentifier/g...
# 164                                         /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation
# 165                                         /gmi:MI_Metadata/gmd:identificationInfo/gmd:MD_DataIdentification/gmd:aggregationInfo/gmd:MD_AggregateInformation
# 197                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 198                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 199                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 200                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 201                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 202                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 203                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 204                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 205                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 206                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 207                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 208                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 209                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 210                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 211                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 212                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 213                                                      /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:descriptor
# 180                     /gmi:MI_Metadata/gmd:contentInfo/gmi:MI_CoverageDescription/gmd:dimension/gmd:MD_Band/gmd:sequenceIdentifier/gco:MemberName/gco:aName
# ...                                                                                                                                                       ...
# 117883  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117884  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117885  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117886  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117887  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117888  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117889  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117890  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117891  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117892  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117893  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117894  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117895  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117896  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117897           /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:description/gco:CharacterString
# 117898  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:identifier/gmd:MD_Identifier/gmd:code...
# 117899  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:identifier/gmd:MD_Identifier/gmd:code...
# 117930  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117931  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117944           /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:description/gco:CharacterString
# 117945  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:identifier/gmd:MD_Identifier/gmd:code...
# 117946  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:identifier/gmd:MD_Identifier/gmd:code...
# 117977  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117978  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117982  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117983  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117985  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117986  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117989  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
# 117990  /gmi:MI_Metadata/gmi:acquisitionInformation/gmi:MI_AcquisitionInformation/gmi:operation/gmi:MI_Operation/gmi:plan/gmi:MI_Plan/gmi:citation/gmd:CI_...
#
# [133519 rows x 4 columns]
